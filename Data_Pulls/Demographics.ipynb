# %%
import pyspark
from pyspark import SparkConf
from pyspark.sql import SparkSession
from pyspark.sql import SQLContext
from pyspark.sql import functions as F
from pyspark.sql.functions import col, datediff, lit, to_date, when
from pyspark.sql.types import *
from os import walk
import json
import os
import sys
import datetime
import math

sys.path.append('../')
from Helper_Code.helpfull_functions import *
from Helper_Code.helper_variables import *
from Helper_Code.quality_checks import *

# %%
spark = get_spark_session("test", SparkConf())
# Out:
# WARNING: An illegal reflective access operation has occurred
# WARNING: Illegal reflective access by org.apache.spark.unsafe.Platform (file:/usr/local/lib/python3.9/dist-packages/pyspark/jars/spark-unsafe_2.12-3.2.1.jar) to constructor java.nio.DirectByteBuffer(long,int)
# WARNING: Please consider reporting this to the maintainers of org.apache.spark.unsafe.Platform
# WARNING: Use --illegal-access=warn to enable warnings of further illegal reflective access operations
# WARNING: All illegal access operations will be denied in a future release
# 22/07/13 14:36:46 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Using Spark's default log4j profile: org/apache/spark/log4j-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 22/07/13 14:36:48 WARN Utils: spark.executor.instances less than spark.dynamicAllocation.minExecutors is invalid, ignoring its setting, please update your configs.
# 22/07/13 14:36:49 WARN Utils: spark.executor.instances less than spark.dynamicAllocation.minExecutors is invalid, ignoring its setting, please update your configs.
# 22/07/13 14:36:49 WARN ExecutorAllocationManager: Dynamic allocation without a shuffle service is an experimental feature.

# %%
def numerical_column_selection(df, column, values):
    if len(values) == 2:
        return df.filter((col(column) >= lit(values[0])) & (col(column) <= lit(values[1])))
    else:
        return df.filter((col(column) == lit(values[0])))
    
def catagorical_column_selection(df, column, values):
    return df.filter(col(column).isin(values))


def datetime_column_selection(df, values):
    if len(values) == 2:
        return df.where((df.visit_start_datetime >= lit(values[0])) & (df.visit_start_datetime <= lit(values[1])))
    else:
        return df.where((df.visit_start_datetime == lit(values[0])))

# %%
def demographic_pull(spark, group_value, age = [], gender = [], race=[], ethnicity = [],
                     insurance = [], visit_date = [], visit_locaiton = {}, care_site = {},
                    rand_sample_size = 0):
    
    if group_value not in ['visit_occurrence_id', 'person_id']:
        raise BaseException("Invalid group_value. Options are visit_occurrence_id and person_id")
    
    visit_occurrence = merge_files("/home/jupyter/omop-ed-datapipeline/visit_occurrence", spark, show = False)    
    visit_length_columns = ['person_id', 'visit_occurrence_id', 'visit_start_datetime', 'visit_end_datetime']
    visit_length = visit_occurrence.select([col for col in visit_length_columns])
    visit_length=visit_length.withColumn('visit_length',col("visit_end_datetime").cast("long") - col('visit_start_datetime').cast("long"))
    
    print("Visit Data Loaded...")
    
    
    person = merge_files("/home/jupyter/omop-ed-datapipeline/person", spark, show = False)
    demographics_cols = ['person_id', 'birth_datetime', 'death_datetime', 'gender_source_value', 'race_source_value', 'ethnicity_source_value', 'care_site_id', 'location_id']
    demo = person.select([col for col in demographics_cols])
    
    print("Demographic Data Loaded...")
    
    payer_plan_period = merge_files("/home/jupyter/omop-ed-datapipeline/payer_plan_period", spark, show= False)
    insurance_columns = ['person_id', 'payer_plan_period_start_date', 'payer_plan_period_end_date', 'payer_source_value', 'plan_source_value']
    insurance_df = payer_plan_period.select([col for col in insurance_columns])
    insurance_df = insurance_df.withColumn("payer_plan_period_start_datetime",to_date("payer_plan_period_start_date"))\
                        .withColumn("payer_plan_period_end_datetime",to_date("payer_plan_period_end_date"))
    
    print("Insurance Data Loaded...")
    
    care_site_df = merge_files("/home/jupyter/omop-ed-datapipeline/care_site", spark, show = False)
    care_site_columns = ['care_site_id', 'care_site_name','care_site_source_value', 'place_of_service_source_value']
    care_site_df = care_site_df.select([col for col in care_site_columns])
    
    print("Care Site Data Loaded...")
    
    location = merge_files("/home/jupyter/omop-ed-datapipeline/location", spark, show = False)
    location_columns = ['location_id', 'address_1', 'city', 'state', 'zip', 'county', 'country']
    location = location.select([col for col in location_columns])
    
    print("Patient Locaiton Data Loaded...")
    
    if group_value == 'visit_occurrence_id':
        insurance_df = insurance_df.join(visit_length, insurance_df.person_id == visit_length.person_id)
        insurance_df = insurance_df.where((insurance_df.visit_start_datetime >= insurance_df.payer_plan_period_start_datetime) & (insurance_df.visit_end_datetime <= insurance_df.payer_plan_period_end_datetime))
        insurance_df = insurance_df.distinct()
        insurance_columns = ['visit_occurrence_id', 'payer_source_value', 'plan_source_value']
        insurance_df = insurance_df.select([col for col in insurance_columns])
        
        demo = demo.join(visit_length, on = "person_id", how = "outer")
        demo = demo.withColumn("age", math.floor(datediff(col("visit_start_datetime"),col("birth_datetime"))/365.25))
        demo = demo.select([col for col in ['person_id', 'birth_datetime', 'death_datetime', 'gender_source_value', 'race_source_value', 'ethnicity_source_value', 'age', 'care_site_id', 'location_id']])
        demo = demo.distinct()
        
        print("Age and Insurance Provider Identified Data Loaded...")        
        
        
    else:
        insurance_df = insurance_df.withColumn("payer_plan_period_start_datetime",to_date("payer_plan_period_start_date"))\
                        .withColumn("payer_plan_period_end_datetime",to_date("payer_plan_period_end_date"))
        
        insurance_df = insurance_df.join(insurance_df.groupBy('person_id').agg(F.max('payer_plan_period_start_datetime').alias('payer_plan_period_start_datetime')),on='payer_plan_period_start_datetime',how='leftsemi')
        insurance_columns = ['person_id', 'payer_source_value', 'plan_source_value']
        insurance_df = insurance_df.select([col for col in insurance_columns])
        
        now = datetime.datetime.now()
        demo = demo.withColumn("age", when(col("death_datetime").isNull(),math.floor(datediff(lit(now),col("birth_datetime"))/365.25))
              .otherwise(math.floor(datediff(col('death_datetime'),col("birth_datetime"))/365.25)))
        demo = demo.select([col for col in ['person_id', 'birth_datetime', 'death_datetime', 'gender_source_value', 'race_source_value', 'ethnicity_source_value', 'age', 'care_site_id', 'location_id']])
        demo = demo.distinct()
        
        print("Age and Insurance Provider Identified Data Loaded...")
        
    main_df = demo.join(visit_length, on = "person_id", how = "outer")
    print("Demographics and Visit Length Information Combined...")
    
    main_df = main_df.join(insurance_df, on=group_value, how = "outer")
    print("Added Insurance Information Information...")
    
    
    main_df = main_df.join(care_site_df, on='care_site_id', how = "outer")
    print("Added Care Site Information...")
    
    main_df = main_df.join(location, on='location_id', how = "outer")
    print("Added Patient Locaiton Information...")
    
    if rand_sample_size == 0:
        patient_number = main_df.count()
        rand_df = main_df.limit(patient_number)
    else:
        rand_df = main_df.limit(rand_sample_size)
    
    if age != []:
        main_df = numerical_column_selection(main_df, "age", age)
        print("Filtered Data for Age...")
        
    if gender != []:
        main_df = catagorical_column_selection(main_df, "gender_source_value", gender)
        print("Filtered Data for Gender...")
        
    if race != []:
        main_df = catagorical_column_selection(main_df, "race_source_value", race)
        print("Filtered Data for Race...")
        
    if b != []:
        main_df = catagorical_column_selection(main_df, "ethnicity_source_value", ethnicity)
        print("Filtered Data for Ethnicity...")
    
    if insurance != []:
        main_df = catagorical_column_selection(main_df, "plan_source_value", insurance)
        print("Filtered Data for Insurance...")
        
    if visit_date != []:
        main_df = datetime_column_selection(main_df, visit_date)
        print("Filtered Data for Visit Date...")
        
    if visit_locaiton != {}:
        for key in visit_location.keys():
            main_df = catagorical_column_selection(main_df, key, visit_location[key])
        print("Filtered Data for Care Site...")
            
    if care_site != {}:
        for key in care_site.keys():
            main_df = catagorical_column_selection(main_df, key, care_site[key])
        print("Filtered Data for Location...")
        
    return main_df, rand_df

# %%
main_df, rand_df = demographic_pull(spark, "visit_occurrence_id", age = [30,50], rand_sample_size= 1000)
# Out:
# (5229969, 17)
# Visit Data Loaded...
# (459280, 20)
# Demographic Data Loaded...
# (5818931, 23)
# Insurance Data Loaded...
# (2693, 6)
# Care Site Data Loaded...
# (398511, 11)
# Patient Locaiton Data Loaded...
# Age and Insurance Provider Identified Data Loaded...
# Demographics and Visit Length Information Combined...
# Added Insurance Information Information...
# Added Care Site Information...
# Added Patient Locaiton Information...
# Filtered Data for Age...

# %%
rand_df.show()
# Out:
# 22/07/13 14:27:01 WARN ExecutorPodsSnapshotsStoreImpl: Exception when notifying snapshot subscriber.
# io.fabric8.kubernetes.client.KubernetesClientException: Failure executing: POST at: https://kubernetes.default.svc.cluster.local/api/v1/namespaces/ke-decile-lab/pods. Message: Forbidden!Configured service account doesn't have access. Service account may have been revoked. pods "test-24844a81f7f2a509-exec-5" is forbidden: exceeded quota: ke-decile-lab-quota, requested: requests.cpu=2, used: requests.cpu=32, limited: requests.cpu=32.
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.requestFailure(OperationSupport.java:639)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.assertResponseCode(OperationSupport.java:576)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleResponse(OperationSupport.java:543)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleResponse(OperationSupport.java:504)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleCreate(OperationSupport.java:292)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.handleCreate(BaseOperation.java:893)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.create(BaseOperation.java:372)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.create(BaseOperation.java:86)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$requestNewExecutors$1(ExecutorPodsAllocator.scala:400)
# 	at scala.collection.immutable.Range.foreach$mVc$sp(Range.scala:158)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.requestNewExecutors(ExecutorPodsAllocator.scala:382)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$onNewSnapshots$36(ExecutorPodsAllocator.scala:346)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$onNewSnapshots$36$adapted(ExecutorPodsAllocator.scala:339)
# 	at scala.collection.mutable.ResizableArray.foreach(ResizableArray.scala:62)
# 	at scala.collection.mutable.ResizableArray.foreach$(ResizableArray.scala:55)
# 	at scala.collection.mutable.ArrayBuffer.foreach(ArrayBuffer.scala:49)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.onNewSnapshots(ExecutorPodsAllocator.scala:339)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3$adapted(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber.org$apache$spark$scheduler$cluster$k8s$ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber$$processSnapshotsInternal(ExecutorPodsSnapshotsStoreImpl.scala:138)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber.processSnapshots(ExecutorPodsSnapshotsStoreImpl.scala:126)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$$anon$1.run(ExecutorPodsSnapshotsStoreImpl.scala:90)
# 	at java.base/java.util.concurrent.Executors$RunnableAdapter.call(Unknown Source)
# 	at java.base/java.util.concurrent.FutureTask.run(Unknown Source)
# 	at java.base/java.util.concurrent.ScheduledThreadPoolExecutor$ScheduledFutureTask.run(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(Unknown Source)
# 	at java.base/java.lang.Thread.run(Unknown Source)
# 22/07/13 14:27:02 WARN ExecutorPodsSnapshotsStoreImpl: Exception when notifying snapshot subscriber.
# io.fabric8.kubernetes.client.KubernetesClientException: Failure executing: POST at: https://kubernetes.default.svc.cluster.local/api/v1/namespaces/ke-decile-lab/pods. Message: Forbidden!Configured service account doesn't have access. Service account may have been revoked. pods "test-24844a81f7f2a509-exec-6" is forbidden: exceeded quota: ke-decile-lab-quota, requested: requests.cpu=2, used: requests.cpu=32, limited: requests.cpu=32.
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.requestFailure(OperationSupport.java:639)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.assertResponseCode(OperationSupport.java:576)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleResponse(OperationSupport.java:543)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleResponse(OperationSupport.java:504)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleCreate(OperationSupport.java:292)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.handleCreate(BaseOperation.java:893)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.create(BaseOperation.java:372)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.create(BaseOperation.java:86)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$requestNewExecutors$1(ExecutorPodsAllocator.scala:400)
# 	at scala.collection.immutable.Range.foreach$mVc$sp(Range.scala:158)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.requestNewExecutors(ExecutorPodsAllocator.scala:382)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$onNewSnapshots$36(ExecutorPodsAllocator.scala:346)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$onNewSnapshots$36$adapted(ExecutorPodsAllocator.scala:339)
# 	at scala.collection.mutable.ResizableArray.foreach(ResizableArray.scala:62)
# 	at scala.collection.mutable.ResizableArray.foreach$(ResizableArray.scala:55)
# 	at scala.collection.mutable.ArrayBuffer.foreach(ArrayBuffer.scala:49)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.onNewSnapshots(ExecutorPodsAllocator.scala:339)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3$adapted(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber.org$apache$spark$scheduler$cluster$k8s$ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber$$processSnapshotsInternal(ExecutorPodsSnapshotsStoreImpl.scala:138)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber.processSnapshots(ExecutorPodsSnapshotsStoreImpl.scala:126)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl.$anonfun$addSubscriber$1(ExecutorPodsSnapshotsStoreImpl.scala:81)
# 	at java.base/java.util.concurrent.Executors$RunnableAdapter.call(Unknown Source)
# 	at java.base/java.util.concurrent.FutureTask.runAndReset(Unknown Source)
# 	at java.base/java.util.concurrent.ScheduledThreadPoolExecutor$ScheduledFutureTask.run(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(Unknown Source)
# 	at java.base/java.lang.Thread.run(Unknown Source)
# 22/07/13 14:27:02 WARN ExecutorPodsSnapshotsStoreImpl: Exception when notifying snapshot subscriber.
# io.fabric8.kubernetes.client.KubernetesClientException: Failure executing: POST at: https://kubernetes.default.svc.cluster.local/api/v1/namespaces/ke-decile-lab/pods. Message: Forbidden!Configured service account doesn't have access. Service account may have been revoked. pods "test-24844a81f7f2a509-exec-7" is forbidden: exceeded quota: ke-decile-lab-quota, requested: requests.cpu=2, used: requests.cpu=32, limited: requests.cpu=32.
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.requestFailure(OperationSupport.java:639)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.assertResponseCode(OperationSupport.java:576)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleResponse(OperationSupport.java:543)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleResponse(OperationSupport.java:504)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleCreate(OperationSupport.java:292)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.handleCreate(BaseOperation.java:893)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.create(BaseOperation.java:372)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.create(BaseOperation.java:86)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$requestNewExecutors$1(ExecutorPodsAllocator.scala:400)
# 	at scala.collection.immutable.Range.foreach$mVc$sp(Range.scala:158)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.requestNewExecutors(ExecutorPodsAllocator.scala:382)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$onNewSnapshots$36(ExecutorPodsAllocator.scala:346)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$onNewSnapshots$36$adapted(ExecutorPodsAllocator.scala:339)
# 	at scala.collection.mutable.ResizableArray.foreach(ResizableArray.scala:62)
# 	at scala.collection.mutable.ResizableArray.foreach$(ResizableArray.scala:55)
# 	at scala.collection.mutable.ArrayBuffer.foreach(ArrayBuffer.scala:49)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.onNewSnapshots(ExecutorPodsAllocator.scala:339)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3$adapted(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber.org$apache$spark$scheduler$cluster$k8s$ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber$$processSnapshotsInternal(ExecutorPodsSnapshotsStoreImpl.scala:138)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber.processSnapshots(ExecutorPodsSnapshotsStoreImpl.scala:126)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$$anon$1.run(ExecutorPodsSnapshotsStoreImpl.scala:90)
# 	at java.base/java.util.concurrent.Executors$RunnableAdapter.call(Unknown Source)
# 	at java.base/java.util.concurrent.FutureTask.run(Unknown Source)
# 	at java.base/java.util.concurrent.ScheduledThreadPoolExecutor$ScheduledFutureTask.run(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(Unknown Source)
# 	at java.base/java.lang.Thread.run(Unknown Source)
# 22/07/13 14:27:03 WARN ExecutorPodsSnapshotsStoreImpl: Exception when notifying snapshot subscriber.
# io.fabric8.kubernetes.client.KubernetesClientException: Failure executing: POST at: https://kubernetes.default.svc.cluster.local/api/v1/namespaces/ke-decile-lab/pods. Message: Forbidden!Configured service account doesn't have access. Service account may have been revoked. pods "test-24844a81f7f2a509-exec-8" is forbidden: exceeded quota: ke-decile-lab-quota, requested: requests.cpu=2, used: requests.cpu=32, limited: requests.cpu=32.
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.requestFailure(OperationSupport.java:639)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.assertResponseCode(OperationSupport.java:576)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleResponse(OperationSupport.java:543)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleResponse(OperationSupport.java:504)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleCreate(OperationSupport.java:292)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.handleCreate(BaseOperation.java:893)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.create(BaseOperation.java:372)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.create(BaseOperation.java:86)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$requestNewExecutors$1(ExecutorPodsAllocator.scala:400)
# 	at scala.collection.immutable.Range.foreach$mVc$sp(Range.scala:158)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.requestNewExecutors(ExecutorPodsAllocator.scala:382)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$onNewSnapshots$36(ExecutorPodsAllocator.scala:346)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$onNewSnapshots$36$adapted(ExecutorPodsAllocator.scala:339)
# 	at scala.collection.mutable.ResizableArray.foreach(ResizableArray.scala:62)
# 	at scala.collection.mutable.ResizableArray.foreach$(ResizableArray.scala:55)
# 	at scala.collection.mutable.ArrayBuffer.foreach(ArrayBuffer.scala:49)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.onNewSnapshots(ExecutorPodsAllocator.scala:339)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3$adapted(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber.org$apache$spark$scheduler$cluster$k8s$ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber$$processSnapshotsInternal(ExecutorPodsSnapshotsStoreImpl.scala:138)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber.processSnapshots(ExecutorPodsSnapshotsStoreImpl.scala:126)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl.$anonfun$addSubscriber$1(ExecutorPodsSnapshotsStoreImpl.scala:81)
# 	at java.base/java.util.concurrent.Executors$RunnableAdapter.call(Unknown Source)
# 	at java.base/java.util.concurrent.FutureTask.runAndReset(Unknown Source)
# 	at java.base/java.util.concurrent.ScheduledThreadPoolExecutor$ScheduledFutureTask.run(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(Unknown Source)
# 	at java.base/java.lang.Thread.run(Unknown Source)
# 22/07/13 14:27:03 WARN ExecutorPodsSnapshotsStoreImpl: Exception when notifying snapshot subscriber.
# io.fabric8.kubernetes.client.KubernetesClientException: Failure executing: POST at: https://kubernetes.default.svc.cluster.local/api/v1/namespaces/ke-decile-lab/pods. Message: Forbidden!Configured service account doesn't have access. Service account may have been revoked. pods "test-24844a81f7f2a509-exec-9" is forbidden: exceeded quota: ke-decile-lab-quota, requested: requests.cpu=2, used: requests.cpu=32, limited: requests.cpu=32.
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.requestFailure(OperationSupport.java:639)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.assertResponseCode(OperationSupport.java:576)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleResponse(OperationSupport.java:543)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleResponse(OperationSupport.java:504)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleCreate(OperationSupport.java:292)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.handleCreate(BaseOperation.java:893)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.create(BaseOperation.java:372)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.create(BaseOperation.java:86)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$requestNewExecutors$1(ExecutorPodsAllocator.scala:400)
# 	at scala.collection.immutable.Range.foreach$mVc$sp(Range.scala:158)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.requestNewExecutors(ExecutorPodsAllocator.scala:382)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$onNewSnapshots$36(ExecutorPodsAllocator.scala:346)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$onNewSnapshots$36$adapted(ExecutorPodsAllocator.scala:339)
# 	at scala.collection.mutable.ResizableArray.foreach(ResizableArray.scala:62)
# 	at scala.collection.mutable.ResizableArray.foreach$(ResizableArray.scala:55)
# 	at scala.collection.mutable.ArrayBuffer.foreach(ArrayBuffer.scala:49)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.onNewSnapshots(ExecutorPodsAllocator.scala:339)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3$adapted(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber.org$apache$spark$scheduler$cluster$k8s$ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber$$processSnapshotsInternal(ExecutorPodsSnapshotsStoreImpl.scala:138)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber.processSnapshots(ExecutorPodsSnapshotsStoreImpl.scala:126)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$$anon$1.run(ExecutorPodsSnapshotsStoreImpl.scala:90)
# 	at java.base/java.util.concurrent.Executors$RunnableAdapter.call(Unknown Source)
# 	at java.base/java.util.concurrent.FutureTask.run(Unknown Source)
# 	at java.base/java.util.concurrent.ScheduledThreadPoolExecutor$ScheduledFutureTask.run(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(Unknown Source)
# 	at java.base/java.lang.Thread.run(Unknown Source)
# 22/07/13 14:27:04 WARN ExecutorPodsSnapshotsStoreImpl: Exception when notifying snapshot subscriber.
# io.fabric8.kubernetes.client.KubernetesClientException: Failure executing: POST at: https://kubernetes.default.svc.cluster.local/api/v1/namespaces/ke-decile-lab/pods. Message: Forbidden!Configured service account doesn't have access. Service account may have been revoked. pods "test-24844a81f7f2a509-exec-10" is forbidden: exceeded quota: ke-decile-lab-quota, requested: requests.cpu=2, used: requests.cpu=32, limited: requests.cpu=32.
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.requestFailure(OperationSupport.java:639)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.assertResponseCode(OperationSupport.java:576)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleResponse(OperationSupport.java:543)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleResponse(OperationSupport.java:504)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleCreate(OperationSupport.java:292)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.handleCreate(BaseOperation.java:893)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.create(BaseOperation.java:372)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.create(BaseOperation.java:86)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$requestNewExecutors$1(ExecutorPodsAllocator.scala:400)
# 	at scala.collection.immutable.Range.foreach$mVc$sp(Range.scala:158)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.requestNewExecutors(ExecutorPodsAllocator.scala:382)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$onNewSnapshots$36(ExecutorPodsAllocator.scala:346)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$onNewSnapshots$36$adapted(ExecutorPodsAllocator.scala:339)
# 	at scala.collection.mutable.ResizableArray.foreach(ResizableArray.scala:62)
# 	at scala.collection.mutable.ResizableArray.foreach$(ResizableArray.scala:55)
# 	at scala.collection.mutable.ArrayBuffer.foreach(ArrayBuffer.scala:49)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.onNewSnapshots(ExecutorPodsAllocator.scala:339)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3$adapted(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber.org$apache$spark$scheduler$cluster$k8s$ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber$$processSnapshotsInternal(ExecutorPodsSnapshotsStoreImpl.scala:138)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber.processSnapshots(ExecutorPodsSnapshotsStoreImpl.scala:126)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl.$anonfun$addSubscriber$1(ExecutorPodsSnapshotsStoreImpl.scala:81)
# 	at java.base/java.util.concurrent.Executors$RunnableAdapter.call(Unknown Source)
# 	at java.base/java.util.concurrent.FutureTask.runAndReset(Unknown Source)
# 	at java.base/java.util.concurrent.ScheduledThreadPoolExecutor$ScheduledFutureTask.run(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(Unknown Source)
# 	at java.base/java.lang.Thread.run(Unknown Source)
# 22/07/13 14:27:05 WARN ExecutorPodsSnapshotsStoreImpl: Exception when notifying snapshot subscriber.
# io.fabric8.kubernetes.client.KubernetesClientException: Failure executing: POST at: https://kubernetes.default.svc.cluster.local/api/v1/namespaces/ke-decile-lab/pods. Message: Forbidden!Configured service account doesn't have access. Service account may have been revoked. pods "test-24844a81f7f2a509-exec-11" is forbidden: exceeded quota: ke-decile-lab-quota, requested: requests.cpu=2, used: requests.cpu=32, limited: requests.cpu=32.
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.requestFailure(OperationSupport.java:639)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.assertResponseCode(OperationSupport.java:576)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleResponse(OperationSupport.java:543)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleResponse(OperationSupport.java:504)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleCreate(OperationSupport.java:292)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.handleCreate(BaseOperation.java:893)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.create(BaseOperation.java:372)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.create(BaseOperation.java:86)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$requestNewExecutors$1(ExecutorPodsAllocator.scala:400)
# 	at scala.collection.immutable.Range.foreach$mVc$sp(Range.scala:158)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.requestNewExecutors(ExecutorPodsAllocator.scala:382)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$onNewSnapshots$36(ExecutorPodsAllocator.scala:346)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$onNewSnapshots$36$adapted(ExecutorPodsAllocator.scala:339)
# 	at scala.collection.mutable.ResizableArray.foreach(ResizableArray.scala:62)
# 	at scala.collection.mutable.ResizableArray.foreach$(ResizableArray.scala:55)
# 	at scala.collection.mutable.ArrayBuffer.foreach(ArrayBuffer.scala:49)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.onNewSnapshots(ExecutorPodsAllocator.scala:339)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3$adapted(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber.org$apache$spark$scheduler$cluster$k8s$ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber$$processSnapshotsInternal(ExecutorPodsSnapshotsStoreImpl.scala:138)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber.processSnapshots(ExecutorPodsSnapshotsStoreImpl.scala:126)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl.$anonfun$addSubscriber$1(ExecutorPodsSnapshotsStoreImpl.scala:81)
# 	at java.base/java.util.concurrent.Executors$RunnableAdapter.call(Unknown Source)
# 	at java.base/java.util.concurrent.FutureTask.runAndReset(Unknown Source)
# 	at java.base/java.util.concurrent.ScheduledThreadPoolExecutor$ScheduledFutureTask.run(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(Unknown Source)
# 	at java.base/java.lang.Thread.run(Unknown Source)
# 22/07/13 14:27:06 WARN ExecutorPodsSnapshotsStoreImpl: Exception when notifying snapshot subscriber.
# io.fabric8.kubernetes.client.KubernetesClientException: Failure executing: POST at: https://kubernetes.default.svc.cluster.local/api/v1/namespaces/ke-decile-lab/pods. Message: Forbidden!Configured service account doesn't have access. Service account may have been revoked. pods "test-24844a81f7f2a509-exec-12" is forbidden: exceeded quota: ke-decile-lab-quota, requested: requests.cpu=2, used: requests.cpu=32, limited: requests.cpu=32.
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.requestFailure(OperationSupport.java:639)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.assertResponseCode(OperationSupport.java:576)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleResponse(OperationSupport.java:543)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleResponse(OperationSupport.java:504)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleCreate(OperationSupport.java:292)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.handleCreate(BaseOperation.java:893)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.create(BaseOperation.java:372)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.create(BaseOperation.java:86)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$requestNewExecutors$1(ExecutorPodsAllocator.scala:400)
# 	at scala.collection.immutable.Range.foreach$mVc$sp(Range.scala:158)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.requestNewExecutors(ExecutorPodsAllocator.scala:382)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$onNewSnapshots$36(ExecutorPodsAllocator.scala:346)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$onNewSnapshots$36$adapted(ExecutorPodsAllocator.scala:339)
# 	at scala.collection.mutable.ResizableArray.foreach(ResizableArray.scala:62)
# 	at scala.collection.mutable.ResizableArray.foreach$(ResizableArray.scala:55)
# 	at scala.collection.mutable.ArrayBuffer.foreach(ArrayBuffer.scala:49)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.onNewSnapshots(ExecutorPodsAllocator.scala:339)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3$adapted(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber.org$apache$spark$scheduler$cluster$k8s$ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber$$processSnapshotsInternal(ExecutorPodsSnapshotsStoreImpl.scala:138)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber.processSnapshots(ExecutorPodsSnapshotsStoreImpl.scala:126)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl.$anonfun$addSubscriber$1(ExecutorPodsSnapshotsStoreImpl.scala:81)
# 	at java.base/java.util.concurrent.Executors$RunnableAdapter.call(Unknown Source)
# 	at java.base/java.util.concurrent.FutureTask.runAndReset(Unknown Source)
# 	at java.base/java.util.concurrent.ScheduledThreadPoolExecutor$ScheduledFutureTask.run(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(Unknown Source)
# 	at java.base/java.lang.Thread.run(Unknown Source)
# 22/07/13 14:27:07 WARN ExecutorPodsSnapshotsStoreImpl: Exception when notifying snapshot subscriber.
# io.fabric8.kubernetes.client.KubernetesClientException: Failure executing: POST at: https://kubernetes.default.svc.cluster.local/api/v1/namespaces/ke-decile-lab/pods. Message: Forbidden!Configured service account doesn't have access. Service account may have been revoked. pods "test-24844a81f7f2a509-exec-13" is forbidden: exceeded quota: ke-decile-lab-quota, requested: requests.cpu=2, used: requests.cpu=32, limited: requests.cpu=32.
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.requestFailure(OperationSupport.java:639)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.assertResponseCode(OperationSupport.java:576)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleResponse(OperationSupport.java:543)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleResponse(OperationSupport.java:504)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleCreate(OperationSupport.java:292)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.handleCreate(BaseOperation.java:893)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.create(BaseOperation.java:372)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.create(BaseOperation.java:86)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$requestNewExecutors$1(ExecutorPodsAllocator.scala:400)
# 	at scala.collection.immutable.Range.foreach$mVc$sp(Range.scala:158)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.requestNewExecutors(ExecutorPodsAllocator.scala:382)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$onNewSnapshots$36(ExecutorPodsAllocator.scala:346)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$onNewSnapshots$36$adapted(ExecutorPodsAllocator.scala:339)
# 	at scala.collection.mutable.ResizableArray.foreach(ResizableArray.scala:62)
# 	at scala.collection.mutable.ResizableArray.foreach$(ResizableArray.scala:55)
# 	at scala.collection.mutable.ArrayBuffer.foreach(ArrayBuffer.scala:49)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.onNewSnapshots(ExecutorPodsAllocator.scala:339)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3$adapted(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber.org$apache$spark$scheduler$cluster$k8s$ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber$$processSnapshotsInternal(ExecutorPodsSnapshotsStoreImpl.scala:138)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber.processSnapshots(ExecutorPodsSnapshotsStoreImpl.scala:126)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$$anon$1.run(ExecutorPodsSnapshotsStoreImpl.scala:90)
# 	at java.base/java.util.concurrent.Executors$RunnableAdapter.call(Unknown Source)
# 	at java.base/java.util.concurrent.FutureTask.run(Unknown Source)
# 	at java.base/java.util.concurrent.ScheduledThreadPoolExecutor$ScheduledFutureTask.run(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(Unknown Source)
# 	at java.base/java.lang.Thread.run(Unknown Source)
# 22/07/13 14:27:07 WARN ExecutorPodsSnapshotsStoreImpl: Exception when notifying snapshot subscriber.
# io.fabric8.kubernetes.client.KubernetesClientException: Failure executing: POST at: https://kubernetes.default.svc.cluster.local/api/v1/namespaces/ke-decile-lab/pods. Message: Forbidden!Configured service account doesn't have access. Service account may have been revoked. pods "test-24844a81f7f2a509-exec-14" is forbidden: exceeded quota: ke-decile-lab-quota, requested: requests.cpu=2, used: requests.cpu=32, limited: requests.cpu=32.
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.requestFailure(OperationSupport.java:639)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.assertResponseCode(OperationSupport.java:576)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleResponse(OperationSupport.java:543)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleResponse(OperationSupport.java:504)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleCreate(OperationSupport.java:292)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.handleCreate(BaseOperation.java:893)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.create(BaseOperation.java:372)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.create(BaseOperation.java:86)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$requestNewExecutors$1(ExecutorPodsAllocator.scala:400)
# 	at scala.collection.immutable.Range.foreach$mVc$sp(Range.scala:158)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.requestNewExecutors(ExecutorPodsAllocator.scala:382)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$onNewSnapshots$36(ExecutorPodsAllocator.scala:346)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$onNewSnapshots$36$adapted(ExecutorPodsAllocator.scala:339)
# 	at scala.collection.mutable.ResizableArray.foreach(ResizableArray.scala:62)
# 	at scala.collection.mutable.ResizableArray.foreach$(ResizableArray.scala:55)
# 	at scala.collection.mutable.ArrayBuffer.foreach(ArrayBuffer.scala:49)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.onNewSnapshots(ExecutorPodsAllocator.scala:339)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3$adapted(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber.org$apache$spark$scheduler$cluster$k8s$ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber$$processSnapshotsInternal(ExecutorPodsSnapshotsStoreImpl.scala:138)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber.processSnapshots(ExecutorPodsSnapshotsStoreImpl.scala:126)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl.$anonfun$addSubscriber$1(ExecutorPodsSnapshotsStoreImpl.scala:81)
# 	at java.base/java.util.concurrent.Executors$RunnableAdapter.call(Unknown Source)
# 	at java.base/java.util.concurrent.FutureTask.runAndReset(Unknown Source)
# 	at java.base/java.util.concurrent.ScheduledThreadPoolExecutor$ScheduledFutureTask.run(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(Unknown Source)
# 	at java.base/java.lang.Thread.run(Unknown Source)
# 22/07/13 14:27:08 WARN ExecutorPodsSnapshotsStoreImpl: Exception when notifying snapshot subscriber.
# io.fabric8.kubernetes.client.KubernetesClientException: Failure executing: POST at: https://kubernetes.default.svc.cluster.local/api/v1/namespaces/ke-decile-lab/pods. Message: Forbidden!Configured service account doesn't have access. Service account may have been revoked. pods "test-24844a81f7f2a509-exec-15" is forbidden: exceeded quota: ke-decile-lab-quota, requested: requests.cpu=2, used: requests.cpu=32, limited: requests.cpu=32.
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.requestFailure(OperationSupport.java:639)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.assertResponseCode(OperationSupport.java:576)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleResponse(OperationSupport.java:543)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleResponse(OperationSupport.java:504)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleCreate(OperationSupport.java:292)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.handleCreate(BaseOperation.java:893)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.create(BaseOperation.java:372)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.create(BaseOperation.java:86)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$requestNewExecutors$1(ExecutorPodsAllocator.scala:400)
# 	at scala.collection.immutable.Range.foreach$mVc$sp(Range.scala:158)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.requestNewExecutors(ExecutorPodsAllocator.scala:382)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$onNewSnapshots$36(ExecutorPodsAllocator.scala:346)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$onNewSnapshots$36$adapted(ExecutorPodsAllocator.scala:339)
# 	at scala.collection.mutable.ResizableArray.foreach(ResizableArray.scala:62)
# 	at scala.collection.mutable.ResizableArray.foreach$(ResizableArray.scala:55)
# 	at scala.collection.mutable.ArrayBuffer.foreach(ArrayBuffer.scala:49)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.onNewSnapshots(ExecutorPodsAllocator.scala:339)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3$adapted(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber.org$apache$spark$scheduler$cluster$k8s$ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber$$processSnapshotsInternal(ExecutorPodsSnapshotsStoreImpl.scala:138)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber.processSnapshots(ExecutorPodsSnapshotsStoreImpl.scala:126)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl.$anonfun$addSubscriber$1(ExecutorPodsSnapshotsStoreImpl.scala:81)
# 	at java.base/java.util.concurrent.Executors$RunnableAdapter.call(Unknown Source)
# 	at java.base/java.util.concurrent.FutureTask.runAndReset(Unknown Source)
# 	at java.base/java.util.concurrent.ScheduledThreadPoolExecutor$ScheduledFutureTask.run(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(Unknown Source)
# 	at java.base/java.lang.Thread.run(Unknown Source)
# 22/07/13 14:27:10 WARN DAGScheduler: Broadcasting large task binary with size 1140.1 KiB
# +--------------------+------------+-------------------+---------+-------------------+--------------+-------------------+------------------+----------------------+-----------------+--------------------+-------------------+------------+------------------+-----------------+--------------+----------------------+-----------------------------+--------------------+----------+-----+-----+---------+--------------------+
# |         location_id|care_site_id|visit_occurrence_id|person_id|     birth_datetime|death_datetime|gender_source_value| race_source_value|ethnicity_source_value|              age|visit_start_datetime| visit_end_datetime|visit_length|payer_source_value|plan_source_value|care_site_name|care_site_source_value|place_of_service_source_value|           address_1|      city|state|  zip|   county|             country|
# +--------------------+------------+-------------------+---------+-------------------+--------------+-------------------+------------------+----------------------+-----------------+--------------------+-------------------+------------+------------------+-----------------+--------------+----------------------+-----------------------------+--------------------+----------+-----+-----+---------+--------------------+
# |0044e97d8ab2e43cd...|        null|          225291921|  5542285|1990-06-12 08:00:00|          null|             Female|White or Caucasian|          Non-Hispanic|30.55167693360712| 2020-12-29 10:00:00|2020-12-29 10:00:00|           0|              null|             null|          null|                  null|                         null|933 RUBBER AVE AP...| NAUGATUCK|   CT|06770|NEW HAVEN|United States of ...|
# |0044e97d8ab2e43cd...|        null|          225238976|  5542285|1990-06-12 08:00:00|          null|             Female|White or Caucasian|          Non-Hispanic|30.55167693360712| 2020-12-30 07:05:00|2020-12-30 08:37:00|        5520|              null|             null|          null|                  null|                         null|933 RUBBER AVE AP...| NAUGATUCK|   CT|06770|NEW HAVEN|United States of ...|
# |0044e97d8ab2e43cd...|        null|          225330634|  5542285|1990-06-12 08:00:00|          null|             Female|White or Caucasian|          Non-Hispanic|30.55167693360712| 2020-12-29 10:00:00|2020-12-29 10:00:00|           0|              null|             null|          null|                  null|                         null|933 RUBBER AVE AP...| NAUGATUCK|   CT|06770|NEW HAVEN|United States of ...|
# |01d9e421e6406540f...|        null|           71139482|  6124953|1987-02-17 10:00:00|          null|             Female|  Other/Not Listed|    Hispanic or Latino|34.83367556468173| 2017-05-30 22:11:00|2017-05-30 22:48:00|        2220|              null|             null|          null|                  null|                         null|       24 KIEFT ROAD|MIDDLETOWN|   CT|06457|MIDDLESEX|United States of ...|
# |01d9e421e6406540f...|        null|          231938051|  6124953|1987-02-17 10:00:00|          null|             Female|  Other/Not Listed|    Hispanic or Latino|34.83367556468173| 2021-02-12 02:19:00|2021-02-12 03:50:00|        5460|              null|             null|          null|                  null|                         null|       24 KIEFT ROAD|MIDDLETOWN|   CT|06457|MIDDLESEX|United States of ...|
# |01d9e421e6406540f...|        null|          146111661|  6124953|1987-02-17 10:00:00|          null|             Female|  Other/Not Listed|    Hispanic or Latino|34.83367556468173| 2019-04-29 08:00:00|2019-04-29 08:00:00|           0|              null|             null|          null|                  null|                         null|       24 KIEFT ROAD|MIDDLETOWN|   CT|06457|MIDDLESEX|United States of ...|
# |01d9e421e6406540f...|        null|          126046610|  6124953|1987-02-17 10:00:00|          null|             Female|  Other/Not Listed|    Hispanic or Latino|34.83367556468173| 2019-03-10 09:00:00|2019-03-10 09:00:00|           0|              null|             null|          null|                  null|                         null|       24 KIEFT ROAD|MIDDLETOWN|   CT|06457|MIDDLESEX|United States of ...|
# |01d9e421e6406540f...|        null|          104917982|  6124953|1987-02-17 10:00:00|          null|             Female|  Other/Not Listed|    Hispanic or Latino|34.83367556468173| 2018-06-29 21:39:00|2018-06-30 02:53:00|       18840|              null|             null|          null|                  null|                         null|       24 KIEFT ROAD|MIDDLETOWN|   CT|06457|MIDDLESEX|United States of ...|
# |01d9e421e6406540f...|        null|           69823739|  6124953|1987-02-17 10:00:00|          null|             Female|  Other/Not Listed|    Hispanic or Latino|34.83367556468173| 2017-05-05 02:38:00|2017-05-05 05:03:00|        8700|              null|             null|          null|                  null|                         null|       24 KIEFT ROAD|MIDDLETOWN|   CT|06457|MIDDLESEX|United States of ...|
# |01d9e421e6406540f...|        null|           71133143|  6124953|1987-02-17 10:00:00|          null|             Female|  Other/Not Listed|    Hispanic or Latino|34.83367556468173| 2017-05-30 19:48:00|2017-05-31 00:07:00|       15540|              null|             null|          null|                  null|                         null|       24 KIEFT ROAD|MIDDLETOWN|   CT|06457|MIDDLESEX|United States of ...|
# |01d9e421e6406540f...|        null|           61608130|  6124953|1987-02-17 10:00:00|          null|             Female|  Other/Not Listed|    Hispanic or Latino|34.83367556468173| 2016-12-02 07:45:00|2016-12-02 09:56:00|        7860|              null|             null|          null|                  null|                         null|       24 KIEFT ROAD|MIDDLETOWN|   CT|06457|MIDDLESEX|United States of ...|
# |01d9e421e6406540f...|        null|           69824771|  6124953|1987-02-17 10:00:00|          null|             Female|  Other/Not Listed|    Hispanic or Latino|34.83367556468173| 2017-05-05 04:35:00|2017-05-05 04:39:00|         240|              null|             null|          null|                  null|                         null|       24 KIEFT ROAD|MIDDLETOWN|   CT|06457|MIDDLESEX|United States of ...|
# |01d9e421e6406540f...|        null|          146086925|  6124953|1987-02-17 10:00:00|          null|             Female|  Other/Not Listed|    Hispanic or Latino|34.83367556468173| 2019-04-28 13:55:00|2019-04-28 14:05:00|         600|              null|             null|          null|                  null|                         null|       24 KIEFT ROAD|MIDDLETOWN|   CT|06457|MIDDLESEX|United States of ...|
# |01d9e421e6406540f...|        null|          232030517|  6124953|1987-02-17 10:00:00|          null|             Female|  Other/Not Listed|    Hispanic or Latino|34.83367556468173| 2021-02-11 10:00:00|2021-02-11 10:00:00|           0|              null|             null|          null|                  null|                         null|       24 KIEFT ROAD|MIDDLETOWN|   CT|06457|MIDDLESEX|United States of ...|
# |01d9e421e6406540f...|        null|           71306975|  6124953|1987-02-17 10:00:00|          null|             Female|  Other/Not Listed|    Hispanic or Latino|34.83367556468173| 2017-06-01 08:00:00|2017-06-01 08:00:00|           0|              null|             null|          null|                  null|                         null|       24 KIEFT ROAD|MIDDLETOWN|   CT|06457|MIDDLESEX|United States of ...|
# |01d9e421e6406540f...|        null|          232285652|  6124953|1987-02-17 10:00:00|          null|             Female|  Other/Not Listed|    Hispanic or Latino|34.83367556468173| 2021-02-15 10:00:00|2021-02-15 10:00:00|           0|              null|             null|          null|                  null|                         null|       24 KIEFT ROAD|MIDDLETOWN|   CT|06457|MIDDLESEX|United States of ...|
# |01d9e421e6406540f...|        null|          126046740|  6124953|1987-02-17 10:00:00|          null|             Female|  Other/Not Listed|    Hispanic or Latino|34.83367556468173| 2019-03-11 02:21:00|2019-03-11 04:59:00|        9480|              null|             null|          null|                  null|                         null|       24 KIEFT ROAD|MIDDLETOWN|   CT|06457|MIDDLESEX|United States of ...|
# |01d9e421e6406540f...|        null|          104871883|  6124953|1987-02-17 10:00:00|          null|             Female|  Other/Not Listed|    Hispanic or Latino|34.83367556468173| 2018-06-29 22:58:00|2018-06-29 23:01:00|         180|              null|             null|          null|                  null|                         null|       24 KIEFT ROAD|MIDDLETOWN|   CT|06457|MIDDLESEX|United States of ...|
# |01d9e421e6406540f...|        null|          269973812|  6124953|1987-02-17 10:00:00|          null|             Female|  Other/Not Listed|    Hispanic or Latino|34.83367556468173| 2021-12-16 10:00:00|2021-12-16 10:00:00|           0|              null|             null|          null|                  null|                         null|       24 KIEFT ROAD|MIDDLETOWN|   CT|06457|MIDDLESEX|United States of ...|
# |01d9e421e6406540f...|        null|           84136129|  6124953|1987-02-17 10:00:00|          null|             Female|  Other/Not Listed|    Hispanic or Latino|34.83367556468173| 2017-10-12 22:28:00|2017-10-12 22:37:00|         540|              null|             null|          null|                  null|                         null|       24 KIEFT ROAD|MIDDLETOWN|   CT|06457|MIDDLESEX|United States of ...|
# +--------------------+------------+-------------------+---------+-------------------+--------------+-------------------+------------------+----------------------+-----------------+--------------------+-------------------+------------+------------------+-----------------+--------------+----------------------+-----------------------------+--------------------+----------+-----+-----+---------+--------------------+
# only showing top 20 rows

# %%
def ed_vitals_pull(spark, rand_sample_size = 0, merge_with = None):
    
    codes = [3025315, 3012888, 3032652, 3027018, 3027598, 3024171, 3004249, 3026258, 3020891]
    # Body weight, Diastolic blood pressure, Glasgow coma scale, Heart rate, Mean blood pressure, Systolic blood pressure, Q-T interval corrected, Body temperature, RR  
    
    
    # First and Last vitals for the visit and keep time for each measurement
    
    vitals = merge_files("/home/jupyter/omop-ed-datapipeline/measurement", spark, show = False)
    concept = merge_files("/home/jupyter/omop-ed-datapipeline/concept", spark, show = False)
    vitals = vitals.join(concept, vitals.measurement_concept_id == concept.concept_id)
    vitals = measurement.filter(col('concept_id').isin(codes))
    main_df = vitals.groupby("visit_occurrence_id", "measurement_source_value").agg(F.max("value_as_number").alias("Max_value"),\
                                                                  F.min("value_as_number").alias("Min_value"),\
                                                                  F.mean("value_as_number").alias("Mean_value"))
    
    if rand_sample_size == 0:
        patient_number = main_df.count()
        rand_df = main_df.limit(patient_number)
    else:
        rand_df = main_df.limit(rand_sample_size)
    
    if merge_with != None:
        main_df = merge_with.join(main_df, on="visit_occurrence_id", how = "left")
    
    return main_df, rand_df

# %%
ed_vitals, rand_vitals = ed_vitals_pull(spark, rand_sample_size = 1000)
# Out:
# 22/07/13 15:14:10 WARN ExecutorPodsSnapshotsStoreImpl: Exception when notifying snapshot subscriber.
# io.fabric8.kubernetes.client.KubernetesClientException: Failure executing: POST at: https://kubernetes.default.svc.cluster.local/api/v1/namespaces/ke-decile-lab/pods. Message: Forbidden!Configured service account doesn't have access. Service account may have been revoked. pods "test-0358db81f7fdb3a2-exec-504" is forbidden: exceeded quota: ke-decile-lab-quota, requested: requests.cpu=2, used: requests.cpu=32, limited: requests.cpu=32.
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.requestFailure(OperationSupport.java:639)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.assertResponseCode(OperationSupport.java:576)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleResponse(OperationSupport.java:543)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleResponse(OperationSupport.java:504)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleCreate(OperationSupport.java:292)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.handleCreate(BaseOperation.java:893)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.create(BaseOperation.java:372)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.create(BaseOperation.java:86)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$requestNewExecutors$1(ExecutorPodsAllocator.scala:400)
# 	at scala.collection.immutable.Range.foreach$mVc$sp(Range.scala:158)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.requestNewExecutors(ExecutorPodsAllocator.scala:382)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$onNewSnapshots$36(ExecutorPodsAllocator.scala:346)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$onNewSnapshots$36$adapted(ExecutorPodsAllocator.scala:339)
# 	at scala.collection.mutable.ResizableArray.foreach(ResizableArray.scala:62)
# 	at scala.collection.mutable.ResizableArray.foreach$(ResizableArray.scala:55)
# 	at scala.collection.mutable.ArrayBuffer.foreach(ArrayBuffer.scala:49)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.onNewSnapshots(ExecutorPodsAllocator.scala:339)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3$adapted(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber.org$apache$spark$scheduler$cluster$k8s$ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber$$processSnapshotsInternal(ExecutorPodsSnapshotsStoreImpl.scala:138)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber.processSnapshots(ExecutorPodsSnapshotsStoreImpl.scala:126)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$$anon$1.run(ExecutorPodsSnapshotsStoreImpl.scala:90)
# 	at java.base/java.util.concurrent.Executors$RunnableAdapter.call(Unknown Source)
# 	at java.base/java.util.concurrent.FutureTask.run(Unknown Source)
# 	at java.base/java.util.concurrent.ScheduledThreadPoolExecutor$ScheduledFutureTask.run(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(Unknown Source)
# 	at java.base/java.lang.Thread.run(Unknown Source)
# 22/07/13 15:14:11 WARN ExecutorPodsSnapshotsStoreImpl: Exception when notifying snapshot subscriber.
# io.fabric8.kubernetes.client.KubernetesClientException: Failure executing: POST at: https://kubernetes.default.svc.cluster.local/api/v1/namespaces/ke-decile-lab/pods. Message: Forbidden!Configured service account doesn't have access. Service account may have been revoked. pods "test-0358db81f7fdb3a2-exec-505" is forbidden: exceeded quota: ke-decile-lab-quota, requested: requests.cpu=2, used: requests.cpu=32, limited: requests.cpu=32.
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.requestFailure(OperationSupport.java:639)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.assertResponseCode(OperationSupport.java:576)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleResponse(OperationSupport.java:543)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleResponse(OperationSupport.java:504)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleCreate(OperationSupport.java:292)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.handleCreate(BaseOperation.java:893)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.create(BaseOperation.java:372)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.create(BaseOperation.java:86)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$requestNewExecutors$1(ExecutorPodsAllocator.scala:400)
# 	at scala.collection.immutable.Range.foreach$mVc$sp(Range.scala:158)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.requestNewExecutors(ExecutorPodsAllocator.scala:382)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$onNewSnapshots$36(ExecutorPodsAllocator.scala:346)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$onNewSnapshots$36$adapted(ExecutorPodsAllocator.scala:339)
# 	at scala.collection.mutable.ResizableArray.foreach(ResizableArray.scala:62)
# 	at scala.collection.mutable.ResizableArray.foreach$(ResizableArray.scala:55)
# 	at scala.collection.mutable.ArrayBuffer.foreach(ArrayBuffer.scala:49)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.onNewSnapshots(ExecutorPodsAllocator.scala:339)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3$adapted(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber.org$apache$spark$scheduler$cluster$k8s$ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber$$processSnapshotsInternal(ExecutorPodsSnapshotsStoreImpl.scala:138)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber.processSnapshots(ExecutorPodsSnapshotsStoreImpl.scala:126)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl.$anonfun$addSubscriber$1(ExecutorPodsSnapshotsStoreImpl.scala:81)
# 	at java.base/java.util.concurrent.Executors$RunnableAdapter.call(Unknown Source)
# 	at java.base/java.util.concurrent.FutureTask.runAndReset(Unknown Source)
# 	at java.base/java.util.concurrent.ScheduledThreadPoolExecutor$ScheduledFutureTask.run(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(Unknown Source)
# 	at java.base/java.lang.Thread.run(Unknown Source)
# 22/07/13 15:14:11 WARN ExecutorPodsSnapshotsStoreImpl: Exception when notifying snapshot subscriber.
# io.fabric8.kubernetes.client.KubernetesClientException: Failure executing: POST at: https://kubernetes.default.svc.cluster.local/api/v1/namespaces/ke-decile-lab/pods. Message: Forbidden!Configured service account doesn't have access. Service account may have been revoked. pods "test-0358db81f7fdb3a2-exec-506" is forbidden: exceeded quota: ke-decile-lab-quota, requested: requests.cpu=2, used: requests.cpu=32, limited: requests.cpu=32.
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.requestFailure(OperationSupport.java:639)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.assertResponseCode(OperationSupport.java:576)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleResponse(OperationSupport.java:543)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleResponse(OperationSupport.java:504)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleCreate(OperationSupport.java:292)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.handleCreate(BaseOperation.java:893)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.create(BaseOperation.java:372)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.create(BaseOperation.java:86)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$requestNewExecutors$1(ExecutorPodsAllocator.scala:400)
# 	at scala.collection.immutable.Range.foreach$mVc$sp(Range.scala:158)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.requestNewExecutors(ExecutorPodsAllocator.scala:382)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$onNewSnapshots$36(ExecutorPodsAllocator.scala:346)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$onNewSnapshots$36$adapted(ExecutorPodsAllocator.scala:339)
# 	at scala.collection.mutable.ResizableArray.foreach(ResizableArray.scala:62)
# 	at scala.collection.mutable.ResizableArray.foreach$(ResizableArray.scala:55)
# 	at scala.collection.mutable.ArrayBuffer.foreach(ArrayBuffer.scala:49)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.onNewSnapshots(ExecutorPodsAllocator.scala:339)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3$adapted(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber.org$apache$spark$scheduler$cluster$k8s$ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber$$processSnapshotsInternal(ExecutorPodsSnapshotsStoreImpl.scala:138)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber.processSnapshots(ExecutorPodsSnapshotsStoreImpl.scala:126)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$$anon$1.run(ExecutorPodsSnapshotsStoreImpl.scala:90)
# 	at java.base/java.util.concurrent.Executors$RunnableAdapter.call(Unknown Source)
# 	at java.base/java.util.concurrent.FutureTask.run(Unknown Source)
# 	at java.base/java.util.concurrent.ScheduledThreadPoolExecutor$ScheduledFutureTask.run(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(Unknown Source)
# 	at java.base/java.lang.Thread.run(Unknown Source)
# 22/07/13 15:14:12 WARN ExecutorPodsSnapshotsStoreImpl: Exception when notifying snapshot subscriber.
# io.fabric8.kubernetes.client.KubernetesClientException: Failure executing: POST at: https://kubernetes.default.svc.cluster.local/api/v1/namespaces/ke-decile-lab/pods. Message: Forbidden!Configured service account doesn't have access. Service account may have been revoked. pods "test-0358db81f7fdb3a2-exec-507" is forbidden: exceeded quota: ke-decile-lab-quota, requested: requests.cpu=2, used: requests.cpu=32, limited: requests.cpu=32.
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.requestFailure(OperationSupport.java:639)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.assertResponseCode(OperationSupport.java:576)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleResponse(OperationSupport.java:543)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleResponse(OperationSupport.java:504)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleCreate(OperationSupport.java:292)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.handleCreate(BaseOperation.java:893)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.create(BaseOperation.java:372)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.create(BaseOperation.java:86)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$requestNewExecutors$1(ExecutorPodsAllocator.scala:400)
# 	at scala.collection.immutable.Range.foreach$mVc$sp(Range.scala:158)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.requestNewExecutors(ExecutorPodsAllocator.scala:382)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$onNewSnapshots$36(ExecutorPodsAllocator.scala:346)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$onNewSnapshots$36$adapted(ExecutorPodsAllocator.scala:339)
# 	at scala.collection.mutable.ResizableArray.foreach(ResizableArray.scala:62)
# 	at scala.collection.mutable.ResizableArray.foreach$(ResizableArray.scala:55)
# 	at scala.collection.mutable.ArrayBuffer.foreach(ArrayBuffer.scala:49)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.onNewSnapshots(ExecutorPodsAllocator.scala:339)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3$adapted(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber.org$apache$spark$scheduler$cluster$k8s$ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber$$processSnapshotsInternal(ExecutorPodsSnapshotsStoreImpl.scala:138)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber.processSnapshots(ExecutorPodsSnapshotsStoreImpl.scala:126)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl.$anonfun$addSubscriber$1(ExecutorPodsSnapshotsStoreImpl.scala:81)
# 	at java.base/java.util.concurrent.Executors$RunnableAdapter.call(Unknown Source)
# 	at java.base/java.util.concurrent.FutureTask.runAndReset(Unknown Source)
# 	at java.base/java.util.concurrent.ScheduledThreadPoolExecutor$ScheduledFutureTask.run(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(Unknown Source)
# 	at java.base/java.lang.Thread.run(Unknown Source)
# 22/07/13 15:14:12 WARN ExecutorPodsSnapshotsStoreImpl: Exception when notifying snapshot subscriber.
# io.fabric8.kubernetes.client.KubernetesClientException: Failure executing: POST at: https://kubernetes.default.svc.cluster.local/api/v1/namespaces/ke-decile-lab/pods. Message: Forbidden!Configured service account doesn't have access. Service account may have been revoked. pods "test-0358db81f7fdb3a2-exec-508" is forbidden: exceeded quota: ke-decile-lab-quota, requested: requests.cpu=2, used: requests.cpu=32, limited: requests.cpu=32.
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.requestFailure(OperationSupport.java:639)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.assertResponseCode(OperationSupport.java:576)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleResponse(OperationSupport.java:543)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleResponse(OperationSupport.java:504)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleCreate(OperationSupport.java:292)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.handleCreate(BaseOperation.java:893)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.create(BaseOperation.java:372)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.create(BaseOperation.java:86)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$requestNewExecutors$1(ExecutorPodsAllocator.scala:400)
# 	at scala.collection.immutable.Range.foreach$mVc$sp(Range.scala:158)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.requestNewExecutors(ExecutorPodsAllocator.scala:382)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$onNewSnapshots$36(ExecutorPodsAllocator.scala:346)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$onNewSnapshots$36$adapted(ExecutorPodsAllocator.scala:339)
# 	at scala.collection.mutable.ResizableArray.foreach(ResizableArray.scala:62)
# 	at scala.collection.mutable.ResizableArray.foreach$(ResizableArray.scala:55)
# 	at scala.collection.mutable.ArrayBuffer.foreach(ArrayBuffer.scala:49)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.onNewSnapshots(ExecutorPodsAllocator.scala:339)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3$adapted(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber.org$apache$spark$scheduler$cluster$k8s$ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber$$processSnapshotsInternal(ExecutorPodsSnapshotsStoreImpl.scala:138)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber.processSnapshots(ExecutorPodsSnapshotsStoreImpl.scala:126)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$$anon$1.run(ExecutorPodsSnapshotsStoreImpl.scala:90)
# 	at java.base/java.util.concurrent.Executors$RunnableAdapter.call(Unknown Source)
# 	at java.base/java.util.concurrent.FutureTask.run(Unknown Source)
# 	at java.base/java.util.concurrent.ScheduledThreadPoolExecutor$ScheduledFutureTask.run(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(Unknown Source)
# 	at java.base/java.lang.Thread.run(Unknown Source)
# 22/07/13 15:14:13 WARN ExecutorPodsSnapshotsStoreImpl: Exception when notifying snapshot subscriber.
# io.fabric8.kubernetes.client.KubernetesClientException: Failure executing: POST at: https://kubernetes.default.svc.cluster.local/api/v1/namespaces/ke-decile-lab/pods. Message: Forbidden!Configured service account doesn't have access. Service account may have been revoked. pods "test-0358db81f7fdb3a2-exec-509" is forbidden: exceeded quota: ke-decile-lab-quota, requested: requests.cpu=2, used: requests.cpu=32, limited: requests.cpu=32.
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.requestFailure(OperationSupport.java:639)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.assertResponseCode(OperationSupport.java:576)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleResponse(OperationSupport.java:543)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleResponse(OperationSupport.java:504)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleCreate(OperationSupport.java:292)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.handleCreate(BaseOperation.java:893)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.create(BaseOperation.java:372)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.create(BaseOperation.java:86)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$requestNewExecutors$1(ExecutorPodsAllocator.scala:400)
# 	at scala.collection.immutable.Range.foreach$mVc$sp(Range.scala:158)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.requestNewExecutors(ExecutorPodsAllocator.scala:382)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$onNewSnapshots$36(ExecutorPodsAllocator.scala:346)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$onNewSnapshots$36$adapted(ExecutorPodsAllocator.scala:339)
# 	at scala.collection.mutable.ResizableArray.foreach(ResizableArray.scala:62)
# 	at scala.collection.mutable.ResizableArray.foreach$(ResizableArray.scala:55)
# 	at scala.collection.mutable.ArrayBuffer.foreach(ArrayBuffer.scala:49)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.onNewSnapshots(ExecutorPodsAllocator.scala:339)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3$adapted(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber.org$apache$spark$scheduler$cluster$k8s$ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber$$processSnapshotsInternal(ExecutorPodsSnapshotsStoreImpl.scala:138)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber.processSnapshots(ExecutorPodsSnapshotsStoreImpl.scala:126)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl.$anonfun$addSubscriber$1(ExecutorPodsSnapshotsStoreImpl.scala:81)
# 	at java.base/java.util.concurrent.Executors$RunnableAdapter.call(Unknown Source)
# 	at java.base/java.util.concurrent.FutureTask.runAndReset(Unknown Source)
# 	at java.base/java.util.concurrent.ScheduledThreadPoolExecutor$ScheduledFutureTask.run(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(Unknown Source)
# 	at java.base/java.lang.Thread.run(Unknown Source)
# 22/07/13 15:14:14 WARN ExecutorPodsSnapshotsStoreImpl: Exception when notifying snapshot subscriber.
# io.fabric8.kubernetes.client.KubernetesClientException: Failure executing: POST at: https://kubernetes.default.svc.cluster.local/api/v1/namespaces/ke-decile-lab/pods. Message: Forbidden!Configured service account doesn't have access. Service account may have been revoked. pods "test-0358db81f7fdb3a2-exec-510" is forbidden: exceeded quota: ke-decile-lab-quota, requested: requests.cpu=2, used: requests.cpu=32, limited: requests.cpu=32.
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.requestFailure(OperationSupport.java:639)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.assertResponseCode(OperationSupport.java:576)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleResponse(OperationSupport.java:543)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleResponse(OperationSupport.java:504)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleCreate(OperationSupport.java:292)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.handleCreate(BaseOperation.java:893)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.create(BaseOperation.java:372)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.create(BaseOperation.java:86)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$requestNewExecutors$1(ExecutorPodsAllocator.scala:400)
# 	at scala.collection.immutable.Range.foreach$mVc$sp(Range.scala:158)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.requestNewExecutors(ExecutorPodsAllocator.scala:382)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$onNewSnapshots$36(ExecutorPodsAllocator.scala:346)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$onNewSnapshots$36$adapted(ExecutorPodsAllocator.scala:339)
# 	at scala.collection.mutable.ResizableArray.foreach(ResizableArray.scala:62)
# 	at scala.collection.mutable.ResizableArray.foreach$(ResizableArray.scala:55)
# 	at scala.collection.mutable.ArrayBuffer.foreach(ArrayBuffer.scala:49)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.onNewSnapshots(ExecutorPodsAllocator.scala:339)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3$adapted(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber.org$apache$spark$scheduler$cluster$k8s$ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber$$processSnapshotsInternal(ExecutorPodsSnapshotsStoreImpl.scala:138)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber.processSnapshots(ExecutorPodsSnapshotsStoreImpl.scala:126)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl.$anonfun$addSubscriber$1(ExecutorPodsSnapshotsStoreImpl.scala:81)
# 	at java.base/java.util.concurrent.Executors$RunnableAdapter.call(Unknown Source)
# 	at java.base/java.util.concurrent.FutureTask.runAndReset(Unknown Source)
# 	at java.base/java.util.concurrent.ScheduledThreadPoolExecutor$ScheduledFutureTask.run(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(Unknown Source)
# 	at java.base/java.lang.Thread.run(Unknown Source)
# (115424304, 24)
# 22/07/13 15:14:20 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 22/07/13 15:14:20 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# +---------+--------------+-----------+----------------------+----------------+--------------------+-------------------+----------------+---------------------------+-------------------+---------------+---------------+-------------------+---------------+---------+----------+-----------+-------------------+---------------+------------------------+----------------------------+-----------------------------+-----------------+------------------+
# |person_id|measurement_id|specimen_id|measurement_concept_id|measurement_date|measurement_datetime|     order_datetime|measurement_time|measurement_type_concept_id|operator_concept_id|value_as_number|value_as_string|value_as_concept_id|unit_concept_id|range_low|range_high|provider_id|visit_occurrence_id|visit_detail_id|measurement_source_value|measurement_source_value_alt|measurement_source_concept_id|unit_source_value|value_source_value|
# +---------+--------------+-----------+----------------------+----------------+--------------------+-------------------+----------------+---------------------------+-------------------+---------------+---------------+-------------------+---------------+---------+----------+-----------+-------------------+---------------+------------------------+----------------------------+-----------------------------+-----------------+------------------+
# | 13582026|     105230877|   20508922|               3032503|            null| 2014-02-14 23:42:00|2014-02-14 22:53:00|            null|                   44818702|               null|           10.6|           null|               null|           8840|      8.8|      10.2|      58139|           17542435|           null|                 Calcium|                     CALCIUM|                      1558170|            mg/dL|              10.6|
# | 13582026|fs598132345dia|       null|               4154790|            null| 2014-02-15 11:16:00|               null|            null|                       null|               null|           71.0|           null|               null|           null|     null|      null|       5263|           17542435|           null|            BP Diastolic|                        null|                   3043430603|                 |                71|
# | 13582026|fs603100402dia|       null|               4154790|            null| 2014-02-15 22:00:00|               null|            null|                       null|               null|           70.0|           null|               null|           null|     null|      null|       4426|           17542435|           null|            BP Diastolic|                        null|                   3043430603|                 |                70|
# | 13582082|     262268342|   49599976|               3004333|            null| 2016-10-10 20:24:00|2016-10-10 19:15:00|            null|                   44818702|               null|           null|           null|           46237993|           null|     null|      null|     561779|           58816795|           null|    ABORH Recheck Int...|        ABORH RECHECK INT...|                         3901|                 |             B POS|
# | 13584711|  fs2158720849|       null|               3009094|            null| 2016-11-10 19:05:00|               null|            null|                       null|               null|           null|           null|               null|           null|     null|      null|      50002|           60519378|           null|    Best Verbal Response|                        null|                         6394|                 | 5-->(V5) oriented|
# | 13589148|     333217231|   59953040|               3000963|            null| 2017-09-28 09:36:00|2017-09-28 07:29:00|            null|                   44818702|               null|           12.7|           null|               null|           8713|     12.0|      null|     937057|           82878066|           null|              Hemoglobin|                  HEMOGLOBIN|                        17187|             g/dL|              12.7|
# | 13589148|     332958533|   59953207|               3041253|            null| 2017-09-28 07:45:00|2017-09-28 07:45:00|            null|                   44818702|               null|           95.0|           null|               null|           8554|     null|      null|    2541361|           82878066|           null|    O2 Sat Calculated...|        O2 SAT CALCULATED...|                        19307|                %|                95|
# | 13590262|  fs3467604809|       null|              40766725|            null| 2018-06-26 03:36:00|               null|            null|                       null|               null|            0.0|           null|               null|           null|     null|      null|      22568|          104602027|           null|             Pain Score:|                        null|                   1601551001|                 |                 0|
# | 13591461|     640825353|  124529784|               3023103|            null| 2021-06-08 12:29:00|2021-06-08 12:07:00|            null|                   44818702|               null|            4.1|           null|               null|           8753|      3.3|      null|    1671396|          246194997|           null|               Potassium|                   POTASSIUM|                          894|           mmol/L|               4.1|
# | 13591461|  fs6687323210|       null|               3032445|            null| 2021-06-08 11:59:00|               null|            null|                       null|               null|           56.9|           null|               null|           9529|     null|      null|      10235|          246194997|           null|    IBW/kg (Calculate...|                        null|                      7074308|               kg|              56.9|
# | 13592763|   fs794407581|       null|               4313591|            null| 2014-08-24 20:00:00|               null|            null|                       null|               null|           40.0|           null|               null|           null|     null|      null|      14130|           24172041|           null|                    Resp|                        null|                            9|                 |                40|
# | 13592763|   fs796016046|       null|               4239408|            null| 2014-08-25 23:00:00|               null|            null|                       null|               null|          136.0|           null|               null|           null|     null|      null|      19071|           24172041|           null|                   Pulse|                        null|                            8|                 |               136|
# | 13606319|  fs2747456559|       null|               4108289|            null| 2017-09-07 23:35:00|               null|            null|                       null|               null|           82.0|           null|               null|           null|     null|      null|      60828|           81703391|           null|         NIBP MAP (mmHg)|                        null|                       301360|                 |                82|
# | 13606877|     346728037|       null|               3006698|            null| 2017-12-04 18:11:00|2017-12-02 07:12:00|            null|                   44818702|               null|           36.0|           null|               null|           9484|     null|      null|     939544|           87629887|           null|            ECG - P Axis|                     ECGPXIS|                         5530|              deg|                36|
# | 13606877|  fs7721452089|       null|              40771936|            null| 2022-04-07 18:14:00|               null|            null|                       null|               null|        1269.62|           null|               null|           null|     null|      null|     123992|          281983091|           null|    RMR (Mifflin-St. ...|                        null|                       681882|                 |           1269.62|
# | 13606877|  fs3017996816|       null|               4313591|            null| 2017-12-24 04:33:00|               null|            null|                       null|               null|           18.0|           null|               null|           null|     null|      null|      26995|           89111165|           null|                    Resp|                        null|                            9|                 |                18|
# | 13615721|  fs6254727067|       null|              40766725|            null| 2021-01-31 17:45:00|               null|            null|                       null|               null|            8.0|           null|               null|           null|     null|      null|      73837|          230172879|           null|             Pain Score:|                        null|                   1601551001|                 |                 8|
# | 13616539|  fs4135607717|       null|              37019008|            null| 2019-02-19 03:35:00|               null|            null|                       null|               null|            2.0|           null|               null|           null|     null|      null|       7501|          124069513|           null|          Patient Acuity|                        null|                        16054|                 |                 2|
# | 13622244|  fs2120887316|       null|               4239408|            null| 2016-10-21 01:54:00|               null|            null|                       null|               null|           73.0|           null|               null|           null|     null|      null|         80|           59453952|           null|                   Pulse|                        null|                            8|                 |                73|
# | 13622244|     194508873|   36183540|               3034426|            null| 2015-09-22 00:37:00|2015-09-21 22:36:00|            null|                   44818702|               null|            9.8|           null|               null|           8555|      9.9|      11.9|     426590|           40473452|           null|        Prothrombin Time|            PROTHROMBIN TIME|                      1810224|                s|               9.8|
# +---------+--------------+-----------+----------------------+----------------+--------------------+-------------------+----------------+---------------------------+-------------------+---------------+---------------+-------------------+---------------+---------+----------+-----------+-------------------+---------------+------------------------+----------------------------+-----------------------------+-----------------+------------------+
# only showing top 20 rows
# [Stage 266:==================================================(1202 + -2) / 1200]

# %%
measurement = merge_files("/home/jupyter/omop-ed-datapipeline/measurement", spark, show = True)
# Out:
# 22/07/13 14:37:23 WARN ExecutorPodsSnapshotsStoreImpl: Exception when notifying snapshot subscriber.
# io.fabric8.kubernetes.client.KubernetesClientException: Failure executing: POST at: https://kubernetes.default.svc.cluster.local/api/v1/namespaces/ke-decile-lab/pods. Message: Forbidden!Configured service account doesn't have access. Service account may have been revoked. pods "test-0358db81f7fdb3a2-exec-4" is forbidden: exceeded quota: ke-decile-lab-quota, requested: requests.cpu=2, used: requests.cpu=32, limited: requests.cpu=32.
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.requestFailure(OperationSupport.java:639)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.assertResponseCode(OperationSupport.java:576)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleResponse(OperationSupport.java:543)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleResponse(OperationSupport.java:504)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleCreate(OperationSupport.java:292)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.handleCreate(BaseOperation.java:893)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.create(BaseOperation.java:372)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.create(BaseOperation.java:86)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$requestNewExecutors$1(ExecutorPodsAllocator.scala:400)
# 	at scala.collection.immutable.Range.foreach$mVc$sp(Range.scala:158)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.requestNewExecutors(ExecutorPodsAllocator.scala:382)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$onNewSnapshots$36(ExecutorPodsAllocator.scala:346)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$onNewSnapshots$36$adapted(ExecutorPodsAllocator.scala:339)
# 	at scala.collection.mutable.ResizableArray.foreach(ResizableArray.scala:62)
# 	at scala.collection.mutable.ResizableArray.foreach$(ResizableArray.scala:55)
# 	at scala.collection.mutable.ArrayBuffer.foreach(ArrayBuffer.scala:49)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.onNewSnapshots(ExecutorPodsAllocator.scala:339)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3$adapted(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber.org$apache$spark$scheduler$cluster$k8s$ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber$$processSnapshotsInternal(ExecutorPodsSnapshotsStoreImpl.scala:138)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber.processSnapshots(ExecutorPodsSnapshotsStoreImpl.scala:126)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl.$anonfun$addSubscriber$1(ExecutorPodsSnapshotsStoreImpl.scala:81)
# 	at java.base/java.util.concurrent.Executors$RunnableAdapter.call(Unknown Source)
# 	at java.base/java.util.concurrent.FutureTask.runAndReset(Unknown Source)
# 	at java.base/java.util.concurrent.ScheduledThreadPoolExecutor$ScheduledFutureTask.run(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(Unknown Source)
# 	at java.base/java.lang.Thread.run(Unknown Source)
# 22/07/13 14:37:24 WARN ExecutorPodsSnapshotsStoreImpl: Exception when notifying snapshot subscriber.
# io.fabric8.kubernetes.client.KubernetesClientException: Failure executing: POST at: https://kubernetes.default.svc.cluster.local/api/v1/namespaces/ke-decile-lab/pods. Message: Forbidden!Configured service account doesn't have access. Service account may have been revoked. pods "test-0358db81f7fdb3a2-exec-5" is forbidden: exceeded quota: ke-decile-lab-quota, requested: requests.cpu=2, used: requests.cpu=32, limited: requests.cpu=32.
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.requestFailure(OperationSupport.java:639)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.assertResponseCode(OperationSupport.java:576)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleResponse(OperationSupport.java:543)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleResponse(OperationSupport.java:504)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleCreate(OperationSupport.java:292)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.handleCreate(BaseOperation.java:893)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.create(BaseOperation.java:372)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.create(BaseOperation.java:86)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$requestNewExecutors$1(ExecutorPodsAllocator.scala:400)
# 	at scala.collection.immutable.Range.foreach$mVc$sp(Range.scala:158)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.requestNewExecutors(ExecutorPodsAllocator.scala:382)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$onNewSnapshots$36(ExecutorPodsAllocator.scala:346)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$onNewSnapshots$36$adapted(ExecutorPodsAllocator.scala:339)
# 	at scala.collection.mutable.ResizableArray.foreach(ResizableArray.scala:62)
# 	at scala.collection.mutable.ResizableArray.foreach$(ResizableArray.scala:55)
# 	at scala.collection.mutable.ArrayBuffer.foreach(ArrayBuffer.scala:49)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.onNewSnapshots(ExecutorPodsAllocator.scala:339)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3$adapted(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber.org$apache$spark$scheduler$cluster$k8s$ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber$$processSnapshotsInternal(ExecutorPodsSnapshotsStoreImpl.scala:138)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber.processSnapshots(ExecutorPodsSnapshotsStoreImpl.scala:126)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl.$anonfun$addSubscriber$1(ExecutorPodsSnapshotsStoreImpl.scala:81)
# 	at java.base/java.util.concurrent.Executors$RunnableAdapter.call(Unknown Source)
# 	at java.base/java.util.concurrent.FutureTask.runAndReset(Unknown Source)
# 	at java.base/java.util.concurrent.ScheduledThreadPoolExecutor$ScheduledFutureTask.run(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(Unknown Source)
# 	at java.base/java.lang.Thread.run(Unknown Source)
# 22/07/13 14:37:25 WARN ExecutorPodsSnapshotsStoreImpl: Exception when notifying snapshot subscriber.
# io.fabric8.kubernetes.client.KubernetesClientException: Failure executing: POST at: https://kubernetes.default.svc.cluster.local/api/v1/namespaces/ke-decile-lab/pods. Message: Forbidden!Configured service account doesn't have access. Service account may have been revoked. pods "test-0358db81f7fdb3a2-exec-6" is forbidden: exceeded quota: ke-decile-lab-quota, requested: requests.cpu=2, used: requests.cpu=32, limited: requests.cpu=32.
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.requestFailure(OperationSupport.java:639)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.assertResponseCode(OperationSupport.java:576)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleResponse(OperationSupport.java:543)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleResponse(OperationSupport.java:504)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleCreate(OperationSupport.java:292)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.handleCreate(BaseOperation.java:893)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.create(BaseOperation.java:372)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.create(BaseOperation.java:86)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$requestNewExecutors$1(ExecutorPodsAllocator.scala:400)
# 	at scala.collection.immutable.Range.foreach$mVc$sp(Range.scala:158)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.requestNewExecutors(ExecutorPodsAllocator.scala:382)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$onNewSnapshots$36(ExecutorPodsAllocator.scala:346)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$onNewSnapshots$36$adapted(ExecutorPodsAllocator.scala:339)
# 	at scala.collection.mutable.ResizableArray.foreach(ResizableArray.scala:62)
# 	at scala.collection.mutable.ResizableArray.foreach$(ResizableArray.scala:55)
# 	at scala.collection.mutable.ArrayBuffer.foreach(ArrayBuffer.scala:49)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.onNewSnapshots(ExecutorPodsAllocator.scala:339)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3$adapted(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber.org$apache$spark$scheduler$cluster$k8s$ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber$$processSnapshotsInternal(ExecutorPodsSnapshotsStoreImpl.scala:138)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber.processSnapshots(ExecutorPodsSnapshotsStoreImpl.scala:126)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl.$anonfun$addSubscriber$1(ExecutorPodsSnapshotsStoreImpl.scala:81)
# 	at java.base/java.util.concurrent.Executors$RunnableAdapter.call(Unknown Source)
# 	at java.base/java.util.concurrent.FutureTask.runAndReset(Unknown Source)
# 	at java.base/java.util.concurrent.ScheduledThreadPoolExecutor$ScheduledFutureTask.run(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(Unknown Source)
# 	at java.base/java.lang.Thread.run(Unknown Source)
# 22/07/13 14:37:26 WARN ExecutorPodsSnapshotsStoreImpl: Exception when notifying snapshot subscriber.
# io.fabric8.kubernetes.client.KubernetesClientException: Failure executing: POST at: https://kubernetes.default.svc.cluster.local/api/v1/namespaces/ke-decile-lab/pods. Message: Forbidden!Configured service account doesn't have access. Service account may have been revoked. pods "test-0358db81f7fdb3a2-exec-7" is forbidden: exceeded quota: ke-decile-lab-quota, requested: requests.cpu=2, used: requests.cpu=32, limited: requests.cpu=32.
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.requestFailure(OperationSupport.java:639)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.assertResponseCode(OperationSupport.java:576)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleResponse(OperationSupport.java:543)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleResponse(OperationSupport.java:504)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleCreate(OperationSupport.java:292)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.handleCreate(BaseOperation.java:893)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.create(BaseOperation.java:372)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.create(BaseOperation.java:86)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$requestNewExecutors$1(ExecutorPodsAllocator.scala:400)
# 	at scala.collection.immutable.Range.foreach$mVc$sp(Range.scala:158)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.requestNewExecutors(ExecutorPodsAllocator.scala:382)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$onNewSnapshots$36(ExecutorPodsAllocator.scala:346)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$onNewSnapshots$36$adapted(ExecutorPodsAllocator.scala:339)
# 	at scala.collection.mutable.ResizableArray.foreach(ResizableArray.scala:62)
# 	at scala.collection.mutable.ResizableArray.foreach$(ResizableArray.scala:55)
# 	at scala.collection.mutable.ArrayBuffer.foreach(ArrayBuffer.scala:49)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.onNewSnapshots(ExecutorPodsAllocator.scala:339)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3$adapted(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber.org$apache$spark$scheduler$cluster$k8s$ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber$$processSnapshotsInternal(ExecutorPodsSnapshotsStoreImpl.scala:138)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber.processSnapshots(ExecutorPodsSnapshotsStoreImpl.scala:126)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl.$anonfun$addSubscriber$1(ExecutorPodsSnapshotsStoreImpl.scala:81)
# 	at java.base/java.util.concurrent.Executors$RunnableAdapter.call(Unknown Source)
# 	at java.base/java.util.concurrent.FutureTask.runAndReset(Unknown Source)
# 	at java.base/java.util.concurrent.ScheduledThreadPoolExecutor$ScheduledFutureTask.run(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(Unknown Source)
# 	at java.base/java.lang.Thread.run(Unknown Source)
# 22/07/13 14:37:27 WARN ExecutorPodsSnapshotsStoreImpl: Exception when notifying snapshot subscriber.
# io.fabric8.kubernetes.client.KubernetesClientException: Failure executing: POST at: https://kubernetes.default.svc.cluster.local/api/v1/namespaces/ke-decile-lab/pods. Message: Forbidden!Configured service account doesn't have access. Service account may have been revoked. pods "test-0358db81f7fdb3a2-exec-8" is forbidden: exceeded quota: ke-decile-lab-quota, requested: requests.cpu=2, used: requests.cpu=32, limited: requests.cpu=32.
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.requestFailure(OperationSupport.java:639)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.assertResponseCode(OperationSupport.java:576)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleResponse(OperationSupport.java:543)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleResponse(OperationSupport.java:504)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleCreate(OperationSupport.java:292)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.handleCreate(BaseOperation.java:893)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.create(BaseOperation.java:372)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.create(BaseOperation.java:86)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$requestNewExecutors$1(ExecutorPodsAllocator.scala:400)
# 	at scala.collection.immutable.Range.foreach$mVc$sp(Range.scala:158)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.requestNewExecutors(ExecutorPodsAllocator.scala:382)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$onNewSnapshots$36(ExecutorPodsAllocator.scala:346)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$onNewSnapshots$36$adapted(ExecutorPodsAllocator.scala:339)
# 	at scala.collection.mutable.ResizableArray.foreach(ResizableArray.scala:62)
# 	at scala.collection.mutable.ResizableArray.foreach$(ResizableArray.scala:55)
# 	at scala.collection.mutable.ArrayBuffer.foreach(ArrayBuffer.scala:49)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.onNewSnapshots(ExecutorPodsAllocator.scala:339)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3$adapted(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber.org$apache$spark$scheduler$cluster$k8s$ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber$$processSnapshotsInternal(ExecutorPodsSnapshotsStoreImpl.scala:138)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber.processSnapshots(ExecutorPodsSnapshotsStoreImpl.scala:126)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl.$anonfun$addSubscriber$1(ExecutorPodsSnapshotsStoreImpl.scala:81)
# 	at java.base/java.util.concurrent.Executors$RunnableAdapter.call(Unknown Source)
# 	at java.base/java.util.concurrent.FutureTask.runAndReset(Unknown Source)
# 	at java.base/java.util.concurrent.ScheduledThreadPoolExecutor$ScheduledFutureTask.run(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(Unknown Source)
# 	at java.base/java.lang.Thread.run(Unknown Source)
# 22/07/13 14:37:28 WARN ExecutorPodsSnapshotsStoreImpl: Exception when notifying snapshot subscriber.
# io.fabric8.kubernetes.client.KubernetesClientException: Failure executing: POST at: https://kubernetes.default.svc.cluster.local/api/v1/namespaces/ke-decile-lab/pods. Message: Forbidden!Configured service account doesn't have access. Service account may have been revoked. pods "test-0358db81f7fdb3a2-exec-9" is forbidden: exceeded quota: ke-decile-lab-quota, requested: requests.cpu=2, used: requests.cpu=32, limited: requests.cpu=32.
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.requestFailure(OperationSupport.java:639)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.assertResponseCode(OperationSupport.java:576)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleResponse(OperationSupport.java:543)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleResponse(OperationSupport.java:504)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleCreate(OperationSupport.java:292)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.handleCreate(BaseOperation.java:893)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.create(BaseOperation.java:372)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.create(BaseOperation.java:86)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$requestNewExecutors$1(ExecutorPodsAllocator.scala:400)
# 	at scala.collection.immutable.Range.foreach$mVc$sp(Range.scala:158)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.requestNewExecutors(ExecutorPodsAllocator.scala:382)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$onNewSnapshots$36(ExecutorPodsAllocator.scala:346)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$onNewSnapshots$36$adapted(ExecutorPodsAllocator.scala:339)
# 	at scala.collection.mutable.ResizableArray.foreach(ResizableArray.scala:62)
# 	at scala.collection.mutable.ResizableArray.foreach$(ResizableArray.scala:55)
# 	at scala.collection.mutable.ArrayBuffer.foreach(ArrayBuffer.scala:49)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.onNewSnapshots(ExecutorPodsAllocator.scala:339)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3$adapted(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber.org$apache$spark$scheduler$cluster$k8s$ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber$$processSnapshotsInternal(ExecutorPodsSnapshotsStoreImpl.scala:138)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber.processSnapshots(ExecutorPodsSnapshotsStoreImpl.scala:126)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl.$anonfun$addSubscriber$1(ExecutorPodsSnapshotsStoreImpl.scala:81)
# 	at java.base/java.util.concurrent.Executors$RunnableAdapter.call(Unknown Source)
# 	at java.base/java.util.concurrent.FutureTask.runAndReset(Unknown Source)
# 	at java.base/java.util.concurrent.ScheduledThreadPoolExecutor$ScheduledFutureTask.run(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(Unknown Source)
# 	at java.base/java.lang.Thread.run(Unknown Source)
# (115424304, 24)
# 22/07/13 14:37:36 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 22/07/13 14:37:37 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# +---------+--------------+-----------+----------------------+----------------+--------------------+-------------------+----------------+---------------------------+-------------------+---------------+---------------+-------------------+---------------+---------+----------+-----------+-------------------+---------------+------------------------+----------------------------+-----------------------------+-----------------+------------------+
# |person_id|measurement_id|specimen_id|measurement_concept_id|measurement_date|measurement_datetime|     order_datetime|measurement_time|measurement_type_concept_id|operator_concept_id|value_as_number|value_as_string|value_as_concept_id|unit_concept_id|range_low|range_high|provider_id|visit_occurrence_id|visit_detail_id|measurement_source_value|measurement_source_value_alt|measurement_source_concept_id|unit_source_value|value_source_value|
# +---------+--------------+-----------+----------------------+----------------+--------------------+-------------------+----------------+---------------------------+-------------------+---------------+---------------+-------------------+---------------+---------+----------+-----------+-------------------+---------------+------------------------+----------------------------+-----------------------------+-----------------+------------------+
# | 13582026|     105230877|   20508922|               3032503|            null| 2014-02-14 23:42:00|2014-02-14 22:53:00|            null|                   44818702|               null|           10.6|           null|               null|           8840|      8.8|      10.2|      58139|           17542435|           null|                 Calcium|                     CALCIUM|                      1558170|            mg/dL|              10.6|
# | 13582026|fs598132345dia|       null|               4154790|            null| 2014-02-15 11:16:00|               null|            null|                       null|               null|           71.0|           null|               null|           null|     null|      null|       5263|           17542435|           null|            BP Diastolic|                        null|                   3043430603|                 |                71|
# | 13582026|fs603100402dia|       null|               4154790|            null| 2014-02-15 22:00:00|               null|            null|                       null|               null|           70.0|           null|               null|           null|     null|      null|       4426|           17542435|           null|            BP Diastolic|                        null|                   3043430603|                 |                70|
# | 13582082|     262268342|   49599976|               3004333|            null| 2016-10-10 20:24:00|2016-10-10 19:15:00|            null|                   44818702|               null|           null|           null|           46237993|           null|     null|      null|     561779|           58816795|           null|    ABORH Recheck Int...|        ABORH RECHECK INT...|                         3901|                 |             B POS|
# | 13584711|  fs2158720849|       null|               3009094|            null| 2016-11-10 19:05:00|               null|            null|                       null|               null|           null|           null|               null|           null|     null|      null|      50002|           60519378|           null|    Best Verbal Response|                        null|                         6394|                 | 5-->(V5) oriented|
# | 13589148|     333217231|   59953040|               3000963|            null| 2017-09-28 09:36:00|2017-09-28 07:29:00|            null|                   44818702|               null|           12.7|           null|               null|           8713|     12.0|      null|     937057|           82878066|           null|              Hemoglobin|                  HEMOGLOBIN|                        17187|             g/dL|              12.7|
# | 13589148|     332958533|   59953207|               3041253|            null| 2017-09-28 07:45:00|2017-09-28 07:45:00|            null|                   44818702|               null|           95.0|           null|               null|           8554|     null|      null|    2541361|           82878066|           null|    O2 Sat Calculated...|        O2 SAT CALCULATED...|                        19307|                %|                95|
# | 13590262|  fs3467604809|       null|              40766725|            null| 2018-06-26 03:36:00|               null|            null|                       null|               null|            0.0|           null|               null|           null|     null|      null|      22568|          104602027|           null|             Pain Score:|                        null|                   1601551001|                 |                 0|
# | 13591461|     640825353|  124529784|               3023103|            null| 2021-06-08 12:29:00|2021-06-08 12:07:00|            null|                   44818702|               null|            4.1|           null|               null|           8753|      3.3|      null|    1671396|          246194997|           null|               Potassium|                   POTASSIUM|                          894|           mmol/L|               4.1|
# | 13591461|  fs6687323210|       null|               3032445|            null| 2021-06-08 11:59:00|               null|            null|                       null|               null|           56.9|           null|               null|           9529|     null|      null|      10235|          246194997|           null|    IBW/kg (Calculate...|                        null|                      7074308|               kg|              56.9|
# | 13592763|   fs794407581|       null|               4313591|            null| 2014-08-24 20:00:00|               null|            null|                       null|               null|           40.0|           null|               null|           null|     null|      null|      14130|           24172041|           null|                    Resp|                        null|                            9|                 |                40|
# | 13592763|   fs796016046|       null|               4239408|            null| 2014-08-25 23:00:00|               null|            null|                       null|               null|          136.0|           null|               null|           null|     null|      null|      19071|           24172041|           null|                   Pulse|                        null|                            8|                 |               136|
# | 13606319|  fs2747456559|       null|               4108289|            null| 2017-09-07 23:35:00|               null|            null|                       null|               null|           82.0|           null|               null|           null|     null|      null|      60828|           81703391|           null|         NIBP MAP (mmHg)|                        null|                       301360|                 |                82|
# | 13606877|     346728037|       null|               3006698|            null| 2017-12-04 18:11:00|2017-12-02 07:12:00|            null|                   44818702|               null|           36.0|           null|               null|           9484|     null|      null|     939544|           87629887|           null|            ECG - P Axis|                     ECGPXIS|                         5530|              deg|                36|
# | 13606877|  fs7721452089|       null|              40771936|            null| 2022-04-07 18:14:00|               null|            null|                       null|               null|        1269.62|           null|               null|           null|     null|      null|     123992|          281983091|           null|    RMR (Mifflin-St. ...|                        null|                       681882|                 |           1269.62|
# | 13606877|  fs3017996816|       null|               4313591|            null| 2017-12-24 04:33:00|               null|            null|                       null|               null|           18.0|           null|               null|           null|     null|      null|      26995|           89111165|           null|                    Resp|                        null|                            9|                 |                18|
# | 13615721|  fs6254727067|       null|              40766725|            null| 2021-01-31 17:45:00|               null|            null|                       null|               null|            8.0|           null|               null|           null|     null|      null|      73837|          230172879|           null|             Pain Score:|                        null|                   1601551001|                 |                 8|
# | 13616539|  fs4135607717|       null|              37019008|            null| 2019-02-19 03:35:00|               null|            null|                       null|               null|            2.0|           null|               null|           null|     null|      null|       7501|          124069513|           null|          Patient Acuity|                        null|                        16054|                 |                 2|
# | 13622244|  fs2120887316|       null|               4239408|            null| 2016-10-21 01:54:00|               null|            null|                       null|               null|           73.0|           null|               null|           null|     null|      null|         80|           59453952|           null|                   Pulse|                        null|                            8|                 |                73|
# | 13622244|     194508873|   36183540|               3034426|            null| 2015-09-22 00:37:00|2015-09-21 22:36:00|            null|                   44818702|               null|            9.8|           null|               null|           8555|      9.9|      11.9|     426590|           40473452|           null|        Prothrombin Time|            PROTHROMBIN TIME|                      1810224|                s|               9.8|
# +---------+--------------+-----------+----------------------+----------------+--------------------+-------------------+----------------+---------------------------+-------------------+---------------+---------------+-------------------+---------------+---------+----------+-----------+-------------------+---------------+------------------------+----------------------------+-----------------------------+-----------------+------------------+
# only showing top 20 rows

# %%
concept = merge_files("/home/jupyter/omop-ed-datapipeline/concept", spark, show = False)
# Out:
# (8107890, 10)

# %%
measurement2 = measurement.join(concept, measurement.measurement_concept_id == concept.concept_id)

# %%
measurement2.show()
# Out:
# 22/07/13 14:37:43 WARN package: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.
# 22/07/13 14:37:47 WARN DAGScheduler: Broadcasting large task binary with size 3.6 MiB
# 22/07/13 14:37:48 WARN ExecutorPodsSnapshotsStoreImpl: Exception when notifying snapshot subscriber.
# io.fabric8.kubernetes.client.KubernetesClientException: Failure executing: POST at: https://kubernetes.default.svc.cluster.local/api/v1/namespaces/ke-decile-lab/pods. Message: Forbidden!Configured service account doesn't have access. Service account may have been revoked. pods "test-0358db81f7fdb3a2-exec-10" is forbidden: exceeded quota: ke-decile-lab-quota, requested: requests.cpu=2, used: requests.cpu=32, limited: requests.cpu=32.
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.requestFailure(OperationSupport.java:639)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.assertResponseCode(OperationSupport.java:576)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleResponse(OperationSupport.java:543)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleResponse(OperationSupport.java:504)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleCreate(OperationSupport.java:292)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.handleCreate(BaseOperation.java:893)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.create(BaseOperation.java:372)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.create(BaseOperation.java:86)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$requestNewExecutors$1(ExecutorPodsAllocator.scala:400)
# 	at scala.collection.immutable.Range.foreach$mVc$sp(Range.scala:158)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.requestNewExecutors(ExecutorPodsAllocator.scala:382)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$onNewSnapshots$36(ExecutorPodsAllocator.scala:346)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$onNewSnapshots$36$adapted(ExecutorPodsAllocator.scala:339)
# 	at scala.collection.mutable.ResizableArray.foreach(ResizableArray.scala:62)
# 	at scala.collection.mutable.ResizableArray.foreach$(ResizableArray.scala:55)
# 	at scala.collection.mutable.ArrayBuffer.foreach(ArrayBuffer.scala:49)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.onNewSnapshots(ExecutorPodsAllocator.scala:339)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3$adapted(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber.org$apache$spark$scheduler$cluster$k8s$ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber$$processSnapshotsInternal(ExecutorPodsSnapshotsStoreImpl.scala:138)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber.processSnapshots(ExecutorPodsSnapshotsStoreImpl.scala:126)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$$anon$1.run(ExecutorPodsSnapshotsStoreImpl.scala:90)
# 	at java.base/java.util.concurrent.Executors$RunnableAdapter.call(Unknown Source)
# 	at java.base/java.util.concurrent.FutureTask.run(Unknown Source)
# 	at java.base/java.util.concurrent.ScheduledThreadPoolExecutor$ScheduledFutureTask.run(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(Unknown Source)
# 	at java.base/java.lang.Thread.run(Unknown Source)
# 22/07/13 14:37:49 WARN ExecutorPodsSnapshotsStoreImpl: Exception when notifying snapshot subscriber.
# io.fabric8.kubernetes.client.KubernetesClientException: Failure executing: POST at: https://kubernetes.default.svc.cluster.local/api/v1/namespaces/ke-decile-lab/pods. Message: Forbidden!Configured service account doesn't have access. Service account may have been revoked. pods "test-0358db81f7fdb3a2-exec-11" is forbidden: exceeded quota: ke-decile-lab-quota, requested: requests.cpu=2, used: requests.cpu=32, limited: requests.cpu=32.
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.requestFailure(OperationSupport.java:639)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.assertResponseCode(OperationSupport.java:576)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleResponse(OperationSupport.java:543)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleResponse(OperationSupport.java:504)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleCreate(OperationSupport.java:292)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.handleCreate(BaseOperation.java:893)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.create(BaseOperation.java:372)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.create(BaseOperation.java:86)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$requestNewExecutors$1(ExecutorPodsAllocator.scala:400)
# 	at scala.collection.immutable.Range.foreach$mVc$sp(Range.scala:158)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.requestNewExecutors(ExecutorPodsAllocator.scala:382)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$onNewSnapshots$36(ExecutorPodsAllocator.scala:346)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$onNewSnapshots$36$adapted(ExecutorPodsAllocator.scala:339)
# 	at scala.collection.mutable.ResizableArray.foreach(ResizableArray.scala:62)
# 	at scala.collection.mutable.ResizableArray.foreach$(ResizableArray.scala:55)
# 	at scala.collection.mutable.ArrayBuffer.foreach(ArrayBuffer.scala:49)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.onNewSnapshots(ExecutorPodsAllocator.scala:339)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3$adapted(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber.org$apache$spark$scheduler$cluster$k8s$ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber$$processSnapshotsInternal(ExecutorPodsSnapshotsStoreImpl.scala:138)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber.processSnapshots(ExecutorPodsSnapshotsStoreImpl.scala:126)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl.$anonfun$addSubscriber$1(ExecutorPodsSnapshotsStoreImpl.scala:81)
# 	at java.base/java.util.concurrent.Executors$RunnableAdapter.call(Unknown Source)
# 	at java.base/java.util.concurrent.FutureTask.runAndReset(Unknown Source)
# 	at java.base/java.util.concurrent.ScheduledThreadPoolExecutor$ScheduledFutureTask.run(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(Unknown Source)
# 	at java.base/java.lang.Thread.run(Unknown Source)
# 22/07/13 14:37:49 WARN ExecutorPodsSnapshotsStoreImpl: Exception when notifying snapshot subscriber.
# io.fabric8.kubernetes.client.KubernetesClientException: Failure executing: POST at: https://kubernetes.default.svc.cluster.local/api/v1/namespaces/ke-decile-lab/pods. Message: Forbidden!Configured service account doesn't have access. Service account may have been revoked. pods "test-0358db81f7fdb3a2-exec-12" is forbidden: exceeded quota: ke-decile-lab-quota, requested: requests.cpu=2, used: requests.cpu=32, limited: requests.cpu=32.
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.requestFailure(OperationSupport.java:639)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.assertResponseCode(OperationSupport.java:576)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleResponse(OperationSupport.java:543)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleResponse(OperationSupport.java:504)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleCreate(OperationSupport.java:292)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.handleCreate(BaseOperation.java:893)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.create(BaseOperation.java:372)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.create(BaseOperation.java:86)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$requestNewExecutors$1(ExecutorPodsAllocator.scala:400)
# 	at scala.collection.immutable.Range.foreach$mVc$sp(Range.scala:158)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.requestNewExecutors(ExecutorPodsAllocator.scala:382)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$onNewSnapshots$36(ExecutorPodsAllocator.scala:346)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$onNewSnapshots$36$adapted(ExecutorPodsAllocator.scala:339)
# 	at scala.collection.mutable.ResizableArray.foreach(ResizableArray.scala:62)
# 	at scala.collection.mutable.ResizableArray.foreach$(ResizableArray.scala:55)
# 	at scala.collection.mutable.ArrayBuffer.foreach(ArrayBuffer.scala:49)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.onNewSnapshots(ExecutorPodsAllocator.scala:339)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3$adapted(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber.org$apache$spark$scheduler$cluster$k8s$ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber$$processSnapshotsInternal(ExecutorPodsSnapshotsStoreImpl.scala:138)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber.processSnapshots(ExecutorPodsSnapshotsStoreImpl.scala:126)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$$anon$1.run(ExecutorPodsSnapshotsStoreImpl.scala:90)
# 	at java.base/java.util.concurrent.Executors$RunnableAdapter.call(Unknown Source)
# 	at java.base/java.util.concurrent.FutureTask.run(Unknown Source)
# 	at java.base/java.util.concurrent.ScheduledThreadPoolExecutor$ScheduledFutureTask.run(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(Unknown Source)
# 	at java.base/java.lang.Thread.run(Unknown Source)
# 22/07/13 14:37:50 WARN ExecutorPodsSnapshotsStoreImpl: Exception when notifying snapshot subscriber.
# io.fabric8.kubernetes.client.KubernetesClientException: Failure executing: POST at: https://kubernetes.default.svc.cluster.local/api/v1/namespaces/ke-decile-lab/pods. Message: Forbidden!Configured service account doesn't have access. Service account may have been revoked. pods "test-0358db81f7fdb3a2-exec-13" is forbidden: exceeded quota: ke-decile-lab-quota, requested: requests.cpu=2, used: requests.cpu=32, limited: requests.cpu=32.
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.requestFailure(OperationSupport.java:639)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.assertResponseCode(OperationSupport.java:576)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleResponse(OperationSupport.java:543)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleResponse(OperationSupport.java:504)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleCreate(OperationSupport.java:292)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.handleCreate(BaseOperation.java:893)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.create(BaseOperation.java:372)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.create(BaseOperation.java:86)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$requestNewExecutors$1(ExecutorPodsAllocator.scala:400)
# 	at scala.collection.immutable.Range.foreach$mVc$sp(Range.scala:158)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.requestNewExecutors(ExecutorPodsAllocator.scala:382)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$onNewSnapshots$36(ExecutorPodsAllocator.scala:346)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$onNewSnapshots$36$adapted(ExecutorPodsAllocator.scala:339)
# 	at scala.collection.mutable.ResizableArray.foreach(ResizableArray.scala:62)
# 	at scala.collection.mutable.ResizableArray.foreach$(ResizableArray.scala:55)
# 	at scala.collection.mutable.ArrayBuffer.foreach(ArrayBuffer.scala:49)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.onNewSnapshots(ExecutorPodsAllocator.scala:339)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3$adapted(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber.org$apache$spark$scheduler$cluster$k8s$ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber$$processSnapshotsInternal(ExecutorPodsSnapshotsStoreImpl.scala:138)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber.processSnapshots(ExecutorPodsSnapshotsStoreImpl.scala:126)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl.$anonfun$addSubscriber$1(ExecutorPodsSnapshotsStoreImpl.scala:81)
# 	at java.base/java.util.concurrent.Executors$RunnableAdapter.call(Unknown Source)
# 	at java.base/java.util.concurrent.FutureTask.runAndReset(Unknown Source)
# 	at java.base/java.util.concurrent.ScheduledThreadPoolExecutor$ScheduledFutureTask.run(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(Unknown Source)
# 	at java.base/java.lang.Thread.run(Unknown Source)
# 22/07/13 14:37:50 WARN ExecutorPodsSnapshotsStoreImpl: Exception when notifying snapshot subscriber.
# io.fabric8.kubernetes.client.KubernetesClientException: Failure executing: POST at: https://kubernetes.default.svc.cluster.local/api/v1/namespaces/ke-decile-lab/pods. Message: Forbidden!Configured service account doesn't have access. Service account may have been revoked. pods "test-0358db81f7fdb3a2-exec-14" is forbidden: exceeded quota: ke-decile-lab-quota, requested: requests.cpu=2, used: requests.cpu=32, limited: requests.cpu=32.
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.requestFailure(OperationSupport.java:639)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.assertResponseCode(OperationSupport.java:576)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleResponse(OperationSupport.java:543)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleResponse(OperationSupport.java:504)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleCreate(OperationSupport.java:292)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.handleCreate(BaseOperation.java:893)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.create(BaseOperation.java:372)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.create(BaseOperation.java:86)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$requestNewExecutors$1(ExecutorPodsAllocator.scala:400)
# 	at scala.collection.immutable.Range.foreach$mVc$sp(Range.scala:158)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.requestNewExecutors(ExecutorPodsAllocator.scala:382)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$onNewSnapshots$36(ExecutorPodsAllocator.scala:346)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$onNewSnapshots$36$adapted(ExecutorPodsAllocator.scala:339)
# 	at scala.collection.mutable.ResizableArray.foreach(ResizableArray.scala:62)
# 	at scala.collection.mutable.ResizableArray.foreach$(ResizableArray.scala:55)
# 	at scala.collection.mutable.ArrayBuffer.foreach(ArrayBuffer.scala:49)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.onNewSnapshots(ExecutorPodsAllocator.scala:339)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3$adapted(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber.org$apache$spark$scheduler$cluster$k8s$ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber$$processSnapshotsInternal(ExecutorPodsSnapshotsStoreImpl.scala:138)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber.processSnapshots(ExecutorPodsSnapshotsStoreImpl.scala:126)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$$anon$1.run(ExecutorPodsSnapshotsStoreImpl.scala:90)
# 	at java.base/java.util.concurrent.Executors$RunnableAdapter.call(Unknown Source)
# 	at java.base/java.util.concurrent.FutureTask.run(Unknown Source)
# 	at java.base/java.util.concurrent.ScheduledThreadPoolExecutor$ScheduledFutureTask.run(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(Unknown Source)
# 	at java.base/java.lang.Thread.run(Unknown Source)
# 22/07/13 14:37:51 WARN ExecutorPodsSnapshotsStoreImpl: Exception when notifying snapshot subscriber.
# io.fabric8.kubernetes.client.KubernetesClientException: Failure executing: POST at: https://kubernetes.default.svc.cluster.local/api/v1/namespaces/ke-decile-lab/pods. Message: Forbidden!Configured service account doesn't have access. Service account may have been revoked. pods "test-0358db81f7fdb3a2-exec-15" is forbidden: exceeded quota: ke-decile-lab-quota, requested: requests.cpu=2, used: requests.cpu=32, limited: requests.cpu=32.
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.requestFailure(OperationSupport.java:639)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.assertResponseCode(OperationSupport.java:576)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleResponse(OperationSupport.java:543)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleResponse(OperationSupport.java:504)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleCreate(OperationSupport.java:292)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.handleCreate(BaseOperation.java:893)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.create(BaseOperation.java:372)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.create(BaseOperation.java:86)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$requestNewExecutors$1(ExecutorPodsAllocator.scala:400)
# 	at scala.collection.immutable.Range.foreach$mVc$sp(Range.scala:158)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.requestNewExecutors(ExecutorPodsAllocator.scala:382)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$onNewSnapshots$36(ExecutorPodsAllocator.scala:346)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$onNewSnapshots$36$adapted(ExecutorPodsAllocator.scala:339)
# 	at scala.collection.mutable.ResizableArray.foreach(ResizableArray.scala:62)
# 	at scala.collection.mutable.ResizableArray.foreach$(ResizableArray.scala:55)
# 	at scala.collection.mutable.ArrayBuffer.foreach(ArrayBuffer.scala:49)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.onNewSnapshots(ExecutorPodsAllocator.scala:339)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3$adapted(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber.org$apache$spark$scheduler$cluster$k8s$ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber$$processSnapshotsInternal(ExecutorPodsSnapshotsStoreImpl.scala:138)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber.processSnapshots(ExecutorPodsSnapshotsStoreImpl.scala:126)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl.$anonfun$addSubscriber$1(ExecutorPodsSnapshotsStoreImpl.scala:81)
# 	at java.base/java.util.concurrent.Executors$RunnableAdapter.call(Unknown Source)
# 	at java.base/java.util.concurrent.FutureTask.runAndReset(Unknown Source)
# 	at java.base/java.util.concurrent.ScheduledThreadPoolExecutor$ScheduledFutureTask.run(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(Unknown Source)
# 	at java.base/java.lang.Thread.run(Unknown Source)
# 22/07/13 14:37:52 WARN ExecutorPodsSnapshotsStoreImpl: Exception when notifying snapshot subscriber.
# io.fabric8.kubernetes.client.KubernetesClientException: Failure executing: POST at: https://kubernetes.default.svc.cluster.local/api/v1/namespaces/ke-decile-lab/pods. Message: Forbidden!Configured service account doesn't have access. Service account may have been revoked. pods "test-0358db81f7fdb3a2-exec-16" is forbidden: exceeded quota: ke-decile-lab-quota, requested: requests.cpu=2, used: requests.cpu=32, limited: requests.cpu=32.
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.requestFailure(OperationSupport.java:639)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.assertResponseCode(OperationSupport.java:576)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleResponse(OperationSupport.java:543)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleResponse(OperationSupport.java:504)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleCreate(OperationSupport.java:292)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.handleCreate(BaseOperation.java:893)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.create(BaseOperation.java:372)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.create(BaseOperation.java:86)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$requestNewExecutors$1(ExecutorPodsAllocator.scala:400)
# 	at scala.collection.immutable.Range.foreach$mVc$sp(Range.scala:158)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.requestNewExecutors(ExecutorPodsAllocator.scala:382)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$onNewSnapshots$36(ExecutorPodsAllocator.scala:346)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$onNewSnapshots$36$adapted(ExecutorPodsAllocator.scala:339)
# 	at scala.collection.mutable.ResizableArray.foreach(ResizableArray.scala:62)
# 	at scala.collection.mutable.ResizableArray.foreach$(ResizableArray.scala:55)
# 	at scala.collection.mutable.ArrayBuffer.foreach(ArrayBuffer.scala:49)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.onNewSnapshots(ExecutorPodsAllocator.scala:339)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3$adapted(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber.org$apache$spark$scheduler$cluster$k8s$ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber$$processSnapshotsInternal(ExecutorPodsSnapshotsStoreImpl.scala:138)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber.processSnapshots(ExecutorPodsSnapshotsStoreImpl.scala:126)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl.$anonfun$addSubscriber$1(ExecutorPodsSnapshotsStoreImpl.scala:81)
# 	at java.base/java.util.concurrent.Executors$RunnableAdapter.call(Unknown Source)
# 	at java.base/java.util.concurrent.FutureTask.runAndReset(Unknown Source)
# 	at java.base/java.util.concurrent.ScheduledThreadPoolExecutor$ScheduledFutureTask.run(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(Unknown Source)
# 	at java.base/java.lang.Thread.run(Unknown Source)
# 22/07/13 14:37:53 WARN ExecutorPodsSnapshotsStoreImpl: Exception when notifying snapshot subscriber.
# io.fabric8.kubernetes.client.KubernetesClientException: Failure executing: POST at: https://kubernetes.default.svc.cluster.local/api/v1/namespaces/ke-decile-lab/pods. Message: Forbidden!Configured service account doesn't have access. Service account may have been revoked. pods "test-0358db81f7fdb3a2-exec-17" is forbidden: exceeded quota: ke-decile-lab-quota, requested: requests.cpu=2, used: requests.cpu=32, limited: requests.cpu=32.
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.requestFailure(OperationSupport.java:639)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.assertResponseCode(OperationSupport.java:576)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleResponse(OperationSupport.java:543)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleResponse(OperationSupport.java:504)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleCreate(OperationSupport.java:292)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.handleCreate(BaseOperation.java:893)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.create(BaseOperation.java:372)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.create(BaseOperation.java:86)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$requestNewExecutors$1(ExecutorPodsAllocator.scala:400)
# 	at scala.collection.immutable.Range.foreach$mVc$sp(Range.scala:158)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.requestNewExecutors(ExecutorPodsAllocator.scala:382)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$onNewSnapshots$36(ExecutorPodsAllocator.scala:346)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$onNewSnapshots$36$adapted(ExecutorPodsAllocator.scala:339)
# 	at scala.collection.mutable.ResizableArray.foreach(ResizableArray.scala:62)
# 	at scala.collection.mutable.ResizableArray.foreach$(ResizableArray.scala:55)
# 	at scala.collection.mutable.ArrayBuffer.foreach(ArrayBuffer.scala:49)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.onNewSnapshots(ExecutorPodsAllocator.scala:339)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3$adapted(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber.org$apache$spark$scheduler$cluster$k8s$ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber$$processSnapshotsInternal(ExecutorPodsSnapshotsStoreImpl.scala:138)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber.processSnapshots(ExecutorPodsSnapshotsStoreImpl.scala:126)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl.$anonfun$addSubscriber$1(ExecutorPodsSnapshotsStoreImpl.scala:81)
# 	at java.base/java.util.concurrent.Executors$RunnableAdapter.call(Unknown Source)
# 	at java.base/java.util.concurrent.FutureTask.runAndReset(Unknown Source)
# 	at java.base/java.util.concurrent.ScheduledThreadPoolExecutor$ScheduledFutureTask.run(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(Unknown Source)
# 	at java.base/java.lang.Thread.run(Unknown Source)
# 22/07/13 14:37:54 WARN ExecutorPodsSnapshotsStoreImpl: Exception when notifying snapshot subscriber.
# io.fabric8.kubernetes.client.KubernetesClientException: Failure executing: POST at: https://kubernetes.default.svc.cluster.local/api/v1/namespaces/ke-decile-lab/pods. Message: Forbidden!Configured service account doesn't have access. Service account may have been revoked. pods "test-0358db81f7fdb3a2-exec-18" is forbidden: exceeded quota: ke-decile-lab-quota, requested: requests.cpu=2, used: requests.cpu=32, limited: requests.cpu=32.
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.requestFailure(OperationSupport.java:639)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.assertResponseCode(OperationSupport.java:576)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleResponse(OperationSupport.java:543)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleResponse(OperationSupport.java:504)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleCreate(OperationSupport.java:292)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.handleCreate(BaseOperation.java:893)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.create(BaseOperation.java:372)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.create(BaseOperation.java:86)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$requestNewExecutors$1(ExecutorPodsAllocator.scala:400)
# 	at scala.collection.immutable.Range.foreach$mVc$sp(Range.scala:158)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.requestNewExecutors(ExecutorPodsAllocator.scala:382)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$onNewSnapshots$36(ExecutorPodsAllocator.scala:346)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$onNewSnapshots$36$adapted(ExecutorPodsAllocator.scala:339)
# 	at scala.collection.mutable.ResizableArray.foreach(ResizableArray.scala:62)
# 	at scala.collection.mutable.ResizableArray.foreach$(ResizableArray.scala:55)
# 	at scala.collection.mutable.ArrayBuffer.foreach(ArrayBuffer.scala:49)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.onNewSnapshots(ExecutorPodsAllocator.scala:339)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3$adapted(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber.org$apache$spark$scheduler$cluster$k8s$ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber$$processSnapshotsInternal(ExecutorPodsSnapshotsStoreImpl.scala:138)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber.processSnapshots(ExecutorPodsSnapshotsStoreImpl.scala:126)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl.$anonfun$addSubscriber$1(ExecutorPodsSnapshotsStoreImpl.scala:81)
# 	at java.base/java.util.concurrent.Executors$RunnableAdapter.call(Unknown Source)
# 	at java.base/java.util.concurrent.FutureTask.runAndReset(Unknown Source)
# 	at java.base/java.util.concurrent.ScheduledThreadPoolExecutor$ScheduledFutureTask.run(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(Unknown Source)
# 	at java.base/java.lang.Thread.run(Unknown Source)
# 22/07/13 14:37:55 WARN ExecutorPodsSnapshotsStoreImpl: Exception when notifying snapshot subscriber.
# io.fabric8.kubernetes.client.KubernetesClientException: Failure executing: POST at: https://kubernetes.default.svc.cluster.local/api/v1/namespaces/ke-decile-lab/pods. Message: Forbidden!Configured service account doesn't have access. Service account may have been revoked. pods "test-0358db81f7fdb3a2-exec-19" is forbidden: exceeded quota: ke-decile-lab-quota, requested: requests.cpu=2, used: requests.cpu=32, limited: requests.cpu=32.
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.requestFailure(OperationSupport.java:639)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.assertResponseCode(OperationSupport.java:576)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleResponse(OperationSupport.java:543)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleResponse(OperationSupport.java:504)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleCreate(OperationSupport.java:292)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.handleCreate(BaseOperation.java:893)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.create(BaseOperation.java:372)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.create(BaseOperation.java:86)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$requestNewExecutors$1(ExecutorPodsAllocator.scala:400)
# 	at scala.collection.immutable.Range.foreach$mVc$sp(Range.scala:158)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.requestNewExecutors(ExecutorPodsAllocator.scala:382)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$onNewSnapshots$36(ExecutorPodsAllocator.scala:346)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$onNewSnapshots$36$adapted(ExecutorPodsAllocator.scala:339)
# 	at scala.collection.mutable.ResizableArray.foreach(ResizableArray.scala:62)
# 	at scala.collection.mutable.ResizableArray.foreach$(ResizableArray.scala:55)
# 	at scala.collection.mutable.ArrayBuffer.foreach(ArrayBuffer.scala:49)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.onNewSnapshots(ExecutorPodsAllocator.scala:339)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3$adapted(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber.org$apache$spark$scheduler$cluster$k8s$ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber$$processSnapshotsInternal(ExecutorPodsSnapshotsStoreImpl.scala:138)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber.processSnapshots(ExecutorPodsSnapshotsStoreImpl.scala:126)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl.$anonfun$addSubscriber$1(ExecutorPodsSnapshotsStoreImpl.scala:81)
# 	at java.base/java.util.concurrent.Executors$RunnableAdapter.call(Unknown Source)
# 	at java.base/java.util.concurrent.FutureTask.runAndReset(Unknown Source)
# 	at java.base/java.util.concurrent.ScheduledThreadPoolExecutor$ScheduledFutureTask.run(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(Unknown Source)
# 	at java.base/java.lang.Thread.run(Unknown Source)
# 22/07/13 14:37:56 WARN ExecutorPodsSnapshotsStoreImpl: Exception when notifying snapshot subscriber.
# io.fabric8.kubernetes.client.KubernetesClientException: Failure executing: POST at: https://kubernetes.default.svc.cluster.local/api/v1/namespaces/ke-decile-lab/pods. Message: Forbidden!Configured service account doesn't have access. Service account may have been revoked. pods "test-0358db81f7fdb3a2-exec-20" is forbidden: exceeded quota: ke-decile-lab-quota, requested: requests.cpu=2, used: requests.cpu=32, limited: requests.cpu=32.
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.requestFailure(OperationSupport.java:639)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.assertResponseCode(OperationSupport.java:576)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleResponse(OperationSupport.java:543)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleResponse(OperationSupport.java:504)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleCreate(OperationSupport.java:292)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.handleCreate(BaseOperation.java:893)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.create(BaseOperation.java:372)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.create(BaseOperation.java:86)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$requestNewExecutors$1(ExecutorPodsAllocator.scala:400)
# 	at scala.collection.immutable.Range.foreach$mVc$sp(Range.scala:158)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.requestNewExecutors(ExecutorPodsAllocator.scala:382)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$onNewSnapshots$36(ExecutorPodsAllocator.scala:346)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$onNewSnapshots$36$adapted(ExecutorPodsAllocator.scala:339)
# 	at scala.collection.mutable.ResizableArray.foreach(ResizableArray.scala:62)
# 	at scala.collection.mutable.ResizableArray.foreach$(ResizableArray.scala:55)
# 	at scala.collection.mutable.ArrayBuffer.foreach(ArrayBuffer.scala:49)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.onNewSnapshots(ExecutorPodsAllocator.scala:339)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3$adapted(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber.org$apache$spark$scheduler$cluster$k8s$ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber$$processSnapshotsInternal(ExecutorPodsSnapshotsStoreImpl.scala:138)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber.processSnapshots(ExecutorPodsSnapshotsStoreImpl.scala:126)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl.$anonfun$addSubscriber$1(ExecutorPodsSnapshotsStoreImpl.scala:81)
# 	at java.base/java.util.concurrent.Executors$RunnableAdapter.call(Unknown Source)
# 	at java.base/java.util.concurrent.FutureTask.runAndReset(Unknown Source)
# 	at java.base/java.util.concurrent.ScheduledThreadPoolExecutor$ScheduledFutureTask.run(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(Unknown Source)
# 	at java.base/java.lang.Thread.run(Unknown Source)
# 22/07/13 14:37:57 WARN ExecutorPodsSnapshotsStoreImpl: Exception when notifying snapshot subscriber.
# io.fabric8.kubernetes.client.KubernetesClientException: Failure executing: POST at: https://kubernetes.default.svc.cluster.local/api/v1/namespaces/ke-decile-lab/pods. Message: Forbidden!Configured service account doesn't have access. Service account may have been revoked. pods "test-0358db81f7fdb3a2-exec-21" is forbidden: exceeded quota: ke-decile-lab-quota, requested: requests.cpu=2, used: requests.cpu=32, limited: requests.cpu=32.
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.requestFailure(OperationSupport.java:639)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.assertResponseCode(OperationSupport.java:576)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleResponse(OperationSupport.java:543)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleResponse(OperationSupport.java:504)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleCreate(OperationSupport.java:292)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.handleCreate(BaseOperation.java:893)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.create(BaseOperation.java:372)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.create(BaseOperation.java:86)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$requestNewExecutors$1(ExecutorPodsAllocator.scala:400)
# 	at scala.collection.immutable.Range.foreach$mVc$sp(Range.scala:158)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.requestNewExecutors(ExecutorPodsAllocator.scala:382)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$onNewSnapshots$36(ExecutorPodsAllocator.scala:346)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$onNewSnapshots$36$adapted(ExecutorPodsAllocator.scala:339)
# 	at scala.collection.mutable.ResizableArray.foreach(ResizableArray.scala:62)
# 	at scala.collection.mutable.ResizableArray.foreach$(ResizableArray.scala:55)
# 	at scala.collection.mutable.ArrayBuffer.foreach(ArrayBuffer.scala:49)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.onNewSnapshots(ExecutorPodsAllocator.scala:339)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3$adapted(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber.org$apache$spark$scheduler$cluster$k8s$ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber$$processSnapshotsInternal(ExecutorPodsSnapshotsStoreImpl.scala:138)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber.processSnapshots(ExecutorPodsSnapshotsStoreImpl.scala:126)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl.$anonfun$addSubscriber$1(ExecutorPodsSnapshotsStoreImpl.scala:81)
# 	at java.base/java.util.concurrent.Executors$RunnableAdapter.call(Unknown Source)
# 	at java.base/java.util.concurrent.FutureTask.runAndReset(Unknown Source)
# 	at java.base/java.util.concurrent.ScheduledThreadPoolExecutor$ScheduledFutureTask.run(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(Unknown Source)
# 	at java.base/java.lang.Thread.run(Unknown Source)
# 22/07/13 14:37:58 WARN ExecutorPodsSnapshotsStoreImpl: Exception when notifying snapshot subscriber.
# io.fabric8.kubernetes.client.KubernetesClientException: Failure executing: POST at: https://kubernetes.default.svc.cluster.local/api/v1/namespaces/ke-decile-lab/pods. Message: Forbidden!Configured service account doesn't have access. Service account may have been revoked. pods "test-0358db81f7fdb3a2-exec-22" is forbidden: exceeded quota: ke-decile-lab-quota, requested: requests.cpu=2, used: requests.cpu=32, limited: requests.cpu=32.
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.requestFailure(OperationSupport.java:639)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.assertResponseCode(OperationSupport.java:576)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleResponse(OperationSupport.java:543)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleResponse(OperationSupport.java:504)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleCreate(OperationSupport.java:292)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.handleCreate(BaseOperation.java:893)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.create(BaseOperation.java:372)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.create(BaseOperation.java:86)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$requestNewExecutors$1(ExecutorPodsAllocator.scala:400)
# 	at scala.collection.immutable.Range.foreach$mVc$sp(Range.scala:158)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.requestNewExecutors(ExecutorPodsAllocator.scala:382)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$onNewSnapshots$36(ExecutorPodsAllocator.scala:346)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$onNewSnapshots$36$adapted(ExecutorPodsAllocator.scala:339)
# 	at scala.collection.mutable.ResizableArray.foreach(ResizableArray.scala:62)
# 	at scala.collection.mutable.ResizableArray.foreach$(ResizableArray.scala:55)
# 	at scala.collection.mutable.ArrayBuffer.foreach(ArrayBuffer.scala:49)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.onNewSnapshots(ExecutorPodsAllocator.scala:339)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3$adapted(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber.org$apache$spark$scheduler$cluster$k8s$ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber$$processSnapshotsInternal(ExecutorPodsSnapshotsStoreImpl.scala:138)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber.processSnapshots(ExecutorPodsSnapshotsStoreImpl.scala:126)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl.$anonfun$addSubscriber$1(ExecutorPodsSnapshotsStoreImpl.scala:81)
# 	at java.base/java.util.concurrent.Executors$RunnableAdapter.call(Unknown Source)
# 	at java.base/java.util.concurrent.FutureTask.runAndReset(Unknown Source)
# 	at java.base/java.util.concurrent.ScheduledThreadPoolExecutor$ScheduledFutureTask.run(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(Unknown Source)
# 	at java.base/java.lang.Thread.run(Unknown Source)
# 22/07/13 14:37:59 WARN ExecutorPodsSnapshotsStoreImpl: Exception when notifying snapshot subscriber.
# io.fabric8.kubernetes.client.KubernetesClientException: Failure executing: POST at: https://kubernetes.default.svc.cluster.local/api/v1/namespaces/ke-decile-lab/pods. Message: Forbidden!Configured service account doesn't have access. Service account may have been revoked. pods "test-0358db81f7fdb3a2-exec-23" is forbidden: exceeded quota: ke-decile-lab-quota, requested: requests.cpu=2, used: requests.cpu=32, limited: requests.cpu=32.
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.requestFailure(OperationSupport.java:639)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.assertResponseCode(OperationSupport.java:576)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleResponse(OperationSupport.java:543)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleResponse(OperationSupport.java:504)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleCreate(OperationSupport.java:292)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.handleCreate(BaseOperation.java:893)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.create(BaseOperation.java:372)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.create(BaseOperation.java:86)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$requestNewExecutors$1(ExecutorPodsAllocator.scala:400)
# 	at scala.collection.immutable.Range.foreach$mVc$sp(Range.scala:158)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.requestNewExecutors(ExecutorPodsAllocator.scala:382)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$onNewSnapshots$36(ExecutorPodsAllocator.scala:346)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$onNewSnapshots$36$adapted(ExecutorPodsAllocator.scala:339)
# 	at scala.collection.mutable.ResizableArray.foreach(ResizableArray.scala:62)
# 	at scala.collection.mutable.ResizableArray.foreach$(ResizableArray.scala:55)
# 	at scala.collection.mutable.ArrayBuffer.foreach(ArrayBuffer.scala:49)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.onNewSnapshots(ExecutorPodsAllocator.scala:339)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3$adapted(ExecutorPodsAllocator.scala:117)
# ...
# 	at scala.collection.mutable.ResizableArray.foreach$(ResizableArray.scala:55)
# 	at scala.collection.mutable.ArrayBuffer.foreach(ArrayBuffer.scala:49)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.onNewSnapshots(ExecutorPodsAllocator.scala:339)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3$adapted(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber.org$apache$spark$scheduler$cluster$k8s$ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber$$processSnapshotsInternal(ExecutorPodsSnapshotsStoreImpl.scala:138)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber.processSnapshots(ExecutorPodsSnapshotsStoreImpl.scala:126)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$$anon$1.run(ExecutorPodsSnapshotsStoreImpl.scala:90)
# 	at java.base/java.util.concurrent.Executors$RunnableAdapter.call(Unknown Source)
# 	at java.base/java.util.concurrent.FutureTask.run(Unknown Source)
# 	at java.base/java.util.concurrent.ScheduledThreadPoolExecutor$ScheduledFutureTask.run(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(Unknown Source)
# 	at java.base/java.lang.Thread.run(Unknown Source)
# 22/07/13 14:38:54 WARN DAGScheduler: Broadcasting large task binary with size 1400.5 KiB
# [Stage 260:>                                                        (0 + 1) / 1]
# +---------+--------------+-----------+----------------------+----------------+--------------------+-------------------+----------------+---------------------------+-------------------+---------------+---------------+-------------------+---------------+---------+----------+-----------+-------------------+---------------+------------------------+----------------------------+-----------------------------+-----------------+------------------+----------+--------------------+-----------+-------------+----------------+----------------+------------+----------------+--------------+--------------+
# |person_id|measurement_id|specimen_id|measurement_concept_id|measurement_date|measurement_datetime|     order_datetime|measurement_time|measurement_type_concept_id|operator_concept_id|value_as_number|value_as_string|value_as_concept_id|unit_concept_id|range_low|range_high|provider_id|visit_occurrence_id|visit_detail_id|measurement_source_value|measurement_source_value_alt|measurement_source_concept_id|unit_source_value|value_source_value|concept_id|        concept_name|  domain_id|vocabulary_id|concept_class_id|standard_concept|concept_code|valid_start_date|valid_end_date|invalid_reason|
# +---------+--------------+-----------+----------------------+----------------+--------------------+-------------------+----------------+---------------------------+-------------------+---------------+---------------+-------------------+---------------+---------+----------+-----------+-------------------+---------------+------------------------+----------------------------+-----------------------------+-----------------+------------------+----------+--------------------+-----------+-------------+----------------+----------------+------------+----------------+--------------+--------------+
# | 13399651|     115375877|   21617014|               3000899|            null| 2014-04-02 16:05:00|2014-03-29 08:13:00|            null|                   44818702|               null|           1.02|           null|               null|           8859|     null|      null|      40515|           19006917|           null|    Pneumococcal Sero...|           PNEUMO AB TYPE 7F|                      1740014|            ug/mL|              1.02|   3000899|Streptococcus pne...|Measurement|        LOINC|        Lab Test|               S|     25296-5|      1970-01-01|    2099-12-31|          null|
# | 13578741|     270396697|   50584086|               3000899|            null| 2016-11-21 07:18:00|2016-11-17 19:35:00|            null|                   44818702|               null|           3.84|           null|               null|           8859|     null|      null|    1876725|           60896369|           null|    Pneumococcal Sero...|           PNEUMO AB TYPE 7F|                      1740014|            ug/mL|              3.84|   3000899|Streptococcus pne...|Measurement|        LOINC|        Lab Test|               S|     25296-5|      1970-01-01|    2099-12-31|          null|
# | 10646683|     631171062|  121849087|               3000899|            null| 2021-05-02 03:19:00|2021-04-27 20:38:00|            null|                   44818702|               null|           null|           null|               null|           8859|     null|      null|    2286097|          239747398|           null|        Serotype 51 (7F)|            SEROTYPE 51 (7F)|                         6692|            ug/mL|              <0.3|   3000899|Streptococcus pne...|Measurement|        LOINC|        Lab Test|               S|     25296-5|      1970-01-01|    2099-12-31|          null|
# | 43959772|     658273727|  128256471|               3000899|            null| 2021-07-22 02:54:00|2021-07-15 18:06:00|            null|                   44818702|               null|            0.8|           null|               null|           8859|     null|      null|    2342851|          250932779|           null|        Serotype 51 (7F)|            SEROTYPE 51 (7F)|                         6692|            ug/mL|               0.8|   3000899|Streptococcus pne...|Measurement|        LOINC|        Lab Test|               S|     25296-5|      1970-01-01|    2099-12-31|          null|
# | 48409809|     248170371|   44570646|               3000899|            null| 2016-07-29 02:24:00|2016-07-25 21:11:00|            null|                   44818702|               null|           0.48|           null|               null|           8859|     null|      null|     447583|           54910582|           null|    Pneumococcal Sero...|           PNEUMO AB TYPE 7F|                      1740014|            ug/mL|              0.48|   3000899|Streptococcus pne...|Measurement|        LOINC|        Lab Test|               S|     25296-5|      1970-01-01|    2099-12-31|          null|
# | 13389783|     135628741|   25863568|               3000899|            null| 2014-09-13 22:13:00|2014-09-11 01:37:00|            null|                   44818702|               null|           0.34|           null|               null|           8859|     null|      null|     171666|           24708821|           null|    Pneumococcal Sero...|           PNEUMO AB TYPE 7F|                      1740014|            ug/mL|              0.34|   3000899|Streptococcus pne...|Measurement|        LOINC|        Lab Test|               S|     25296-5|      1970-01-01|    2099-12-31|          null|
# | 21090499|     629259377|  121384339|               3000899|            null| 2021-04-25 05:42:00|2021-04-21 18:23:00|            null|                   44818702|               null|            3.1|           null|               null|           8859|     null|      null|    2021311|          240394346|           null|        Serotype 51 (7F)|            SEROTYPE 51 (7F)|                         6692|            ug/mL|               3.1|   3000899|Streptococcus pne...|Measurement|        LOINC|        Lab Test|               S|     25296-5|      1970-01-01|    2099-12-31|          null|
# |  5443976|     556443953|   99048339|               3000899|            null| 2020-07-09 13:12:00|2020-07-02 20:34:00|            null|                   44818702|               null|            1.1|           null|               null|           null|     null|      null|    1846464|          205699185|           null|        Serotype 51 (7F)|            SEROTYPE 51 (7F)|                         6692|                 |               1.1|   3000899|Streptococcus pne...|Measurement|        LOINC|        Lab Test|               S|     25296-5|      1970-01-01|    2099-12-31|          null|
# | 12614036|     423852261|   73142619|               3000899|            null| 2018-11-30 15:21:00|2018-11-20 22:56:00|            null|                   44818702|               null|            4.9|           null|               null|           null|     null|      null|    1495979|          117584019|           null|        Serotype 51 (7F)|            SEROTYPE 51 (7F)|                         6692|                 |               4.9|   3000899|Streptococcus pne...|Measurement|        LOINC|        Lab Test|               S|     25296-5|      1970-01-01|    2099-12-31|          null|
# | 13981613|     219973666|   40076011|               3000899|            null| 2016-02-27 00:20:00|2016-02-17 20:19:00|            null|                   44818702|               null|           6.04|           null|               null|           8859|     null|      null|     466897|           43377687|           null|    Pneumococcal Sero...|           PNEUMO AB TYPE 7F|                      1740014|            ug/mL|              6.04|   3000899|Streptococcus pne...|Measurement|        LOINC|        Lab Test|               S|     25296-5|      1970-01-01|    2099-12-31|          null|
# | 45095485|     214129197|   34326637|               3000899|            null| 2016-01-20 17:50:00|2016-01-15 00:14:00|            null|                   44818702|               null|           1.57|           null|               null|           8859|     null|      null|     453272|           45517351|           null|    Pneumococcal Sero...|           PNEUMO AB TYPE 7F|                      1740014|            ug/mL|              1.57|   3000899|Streptococcus pne...|Measurement|        LOINC|        Lab Test|               S|     25296-5|      1970-01-01|    2099-12-31|          null|
# | 10757207|      94169413|   15151075|               3000899|            null| 2013-07-18 23:43:00|2013-07-16 00:34:00|            null|                   44818702|               null|           3.33|           null|               null|           8859|     null|      null|      52426|           11328298|           null|    Pneumococcal Sero...|           PNEUMO AB TYPE 7F|                      1740014|            ug/mL|              3.33|   3000899|Streptococcus pne...|Measurement|        LOINC|        Lab Test|               S|     25296-5|      1970-01-01|    2099-12-31|          null|
# | 47092929|     225067104|   41125555|               3000899|            null| 2016-03-27 16:34:00|2016-03-24 20:09:00|            null|                   44818702|               null|           1.34|           null|               null|           8859|     null|      null|     460838|           48743722|           null|    Pneumococcal Sero...|           PNEUMO AB TYPE 7F|                      1740014|            ug/mL|              1.34|   3000899|Streptococcus pne...|Measurement|        LOINC|        Lab Test|               S|     25296-5|      1970-01-01|    2099-12-31|          null|
# | 36675402|     659110858|  128590665|               3000899|            null| 2021-07-25 02:52:00|2021-07-21 00:21:00|            null|                   44818702|               null|            1.1|           null|               null|           8859|     null|      null|    2018984|          251708398|           null|        Serotype 51 (7F)|            SEROTYPE 51 (7F)|                         6692|            ug/mL|               1.1|   3000899|Streptococcus pne...|Measurement|        LOINC|        Lab Test|               S|     25296-5|      1970-01-01|    2099-12-31|          null|
# | 47061164|     231170179|   41975135|               3000899|            null| 2016-05-02 16:04:00|2016-04-28 21:40:00|            null|                   44818702|               null|           0.46|           null|               null|           8859|     null|      null|     460838|           50401126|           null|    Pneumococcal Sero...|           PNEUMO AB TYPE 7F|                      1740014|            ug/mL|              0.46|   3000899|Streptococcus pne...|Measurement|        LOINC|        Lab Test|               S|     25296-5|      1970-01-01|    2099-12-31|          null|
# | 20896866|     376347451|   65004324|               3000899|            null| 2018-04-22 08:14:00|2018-04-19 18:06:00|            null|                   44818702|               null|           8.29|           null|               null|           8859|     null|      null|     918123|           96376562|           null|    Pneumococcal Sero...|           PNEUMO AB TYPE 7F|                      1740014|            ug/mL|              8.29|   3000899|Streptococcus pne...|Measurement|        LOINC|        Lab Test|               S|     25296-5|      1970-01-01|    2099-12-31|          null|
# | 10632932|     222860127|   40633572|               3000899|            null| 2016-03-14 17:27:00|2016-03-09 20:15:00|            null|                   44818702|               null|           0.11|           null|               null|           8859|     null|      null|     484564|           47970271|           null|    Pneumococcal Sero...|           PNEUMO AB TYPE 7F|                      1740014|            ug/mL|              0.11|   3000899|Streptococcus pne...|Measurement|        LOINC|        Lab Test|               S|     25296-5|      1970-01-01|    2099-12-31|          null|
# | 33942168|     178311059|   33299220|               3000899|            null| 2015-06-11 08:06:00|2015-06-07 23:43:00|            null|                   44818702|               null|           1.44|           null|               null|           8859|     null|      null|     193710|           35996476|           null|    Pneumococcal Sero...|           PNEUMO AB TYPE 7F|                      1740014|            ug/mL|              1.44|   3000899|Streptococcus pne...|Measurement|        LOINC|        Lab Test|               S|     25296-5|      1970-01-01|    2099-12-31|          null|
# | 43509082|     365586152|   50565560|               3000899|            null| 2018-03-02 03:41:00|2018-02-26 02:24:00|            null|                   44818702|               null|            0.3|           null|               null|           8859|     null|      null|     917379|           93087943|           null|        Serotype 51 (7F)|            SEROTYPE 51 (7F)|                         6692|            ug/mL|               0.3|   3000899|Streptococcus pne...|Measurement|        LOINC|        Lab Test|               S|     25296-5|      1970-01-01|    2099-12-31|          null|
# | 19535337|     454092497|   78639726|               3000899|            null| 2019-04-08 02:43:00|2019-04-02 02:37:00|            null|                   44818702|               null|            2.5|           null|               null|           null|     null|      null|    1507600|          127705224|           null|        Serotype 51 (7F)|            SEROTYPE 51 (7F)|                         6692|                 |               2.5|   3000899|Streptococcus pne...|Measurement|        LOINC|        Lab Test|               S|     25296-5|      1970-01-01|    2099-12-31|          null|
# +---------+--------------+-----------+----------------------+----------------+--------------------+-------------------+----------------+---------------------------+-------------------+---------------+---------------+-------------------+---------------+---------+----------+-----------+-------------------+---------------+------------------------+----------------------------+-----------------------------+-----------------+------------------+----------+--------------------+-----------+-------------+----------------+----------------+------------+----------------+--------------+--------------+
# only showing top 20 rows

# %%
measurement2.select('concept_class_id').distinct().collect()
# Out:
# 22/07/13 14:47:23 WARN ExecutorPodsSnapshotsStoreImpl: Exception when notifying snapshot subscriber.
# io.fabric8.kubernetes.client.KubernetesClientException: Failure executing: POST at: https://kubernetes.default.svc.cluster.local/api/v1/namespaces/ke-decile-lab/pods. Message: Forbidden!Configured service account doesn't have access. Service account may have been revoked. pods "test-0358db81f7fdb3a2-exec-356" is forbidden: exceeded quota: ke-decile-lab-quota, requested: requests.cpu=2, used: requests.cpu=32, limited: requests.cpu=32.
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.requestFailure(OperationSupport.java:639)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.assertResponseCode(OperationSupport.java:576)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleResponse(OperationSupport.java:543)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleResponse(OperationSupport.java:504)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleCreate(OperationSupport.java:292)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.handleCreate(BaseOperation.java:893)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.create(BaseOperation.java:372)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.create(BaseOperation.java:86)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$requestNewExecutors$1(ExecutorPodsAllocator.scala:400)
# 	at scala.collection.immutable.Range.foreach$mVc$sp(Range.scala:158)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.requestNewExecutors(ExecutorPodsAllocator.scala:382)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$onNewSnapshots$36(ExecutorPodsAllocator.scala:346)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$onNewSnapshots$36$adapted(ExecutorPodsAllocator.scala:339)
# 	at scala.collection.mutable.ResizableArray.foreach(ResizableArray.scala:62)
# 	at scala.collection.mutable.ResizableArray.foreach$(ResizableArray.scala:55)
# 	at scala.collection.mutable.ArrayBuffer.foreach(ArrayBuffer.scala:49)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.onNewSnapshots(ExecutorPodsAllocator.scala:339)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3$adapted(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber.org$apache$spark$scheduler$cluster$k8s$ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber$$processSnapshotsInternal(ExecutorPodsSnapshotsStoreImpl.scala:138)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber.processSnapshots(ExecutorPodsSnapshotsStoreImpl.scala:126)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$$anon$1.run(ExecutorPodsSnapshotsStoreImpl.scala:90)
# 	at java.base/java.util.concurrent.Executors$RunnableAdapter.call(Unknown Source)
# 	at java.base/java.util.concurrent.FutureTask.run(Unknown Source)
# 	at java.base/java.util.concurrent.ScheduledThreadPoolExecutor$ScheduledFutureTask.run(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(Unknown Source)
# 	at java.base/java.lang.Thread.run(Unknown Source)
# 22/07/13 14:47:23 WARN ExecutorPodsSnapshotsStoreImpl: Exception when notifying snapshot subscriber.
# io.fabric8.kubernetes.client.KubernetesClientException: Failure executing: POST at: https://kubernetes.default.svc.cluster.local/api/v1/namespaces/ke-decile-lab/pods. Message: Forbidden!Configured service account doesn't have access. Service account may have been revoked. pods "test-0358db81f7fdb3a2-exec-357" is forbidden: exceeded quota: ke-decile-lab-quota, requested: requests.cpu=2, used: requests.cpu=32, limited: requests.cpu=32.
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.requestFailure(OperationSupport.java:639)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.assertResponseCode(OperationSupport.java:576)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleResponse(OperationSupport.java:543)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleResponse(OperationSupport.java:504)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleCreate(OperationSupport.java:292)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.handleCreate(BaseOperation.java:893)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.create(BaseOperation.java:372)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.create(BaseOperation.java:86)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$requestNewExecutors$1(ExecutorPodsAllocator.scala:400)
# 	at scala.collection.immutable.Range.foreach$mVc$sp(Range.scala:158)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.requestNewExecutors(ExecutorPodsAllocator.scala:382)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$onNewSnapshots$36(ExecutorPodsAllocator.scala:346)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$onNewSnapshots$36$adapted(ExecutorPodsAllocator.scala:339)
# 	at scala.collection.mutable.ResizableArray.foreach(ResizableArray.scala:62)
# 	at scala.collection.mutable.ResizableArray.foreach$(ResizableArray.scala:55)
# 	at scala.collection.mutable.ArrayBuffer.foreach(ArrayBuffer.scala:49)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.onNewSnapshots(ExecutorPodsAllocator.scala:339)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3$adapted(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber.org$apache$spark$scheduler$cluster$k8s$ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber$$processSnapshotsInternal(ExecutorPodsSnapshotsStoreImpl.scala:138)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber.processSnapshots(ExecutorPodsSnapshotsStoreImpl.scala:126)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl.$anonfun$addSubscriber$1(ExecutorPodsSnapshotsStoreImpl.scala:81)
# 	at java.base/java.util.concurrent.Executors$RunnableAdapter.call(Unknown Source)
# 	at java.base/java.util.concurrent.FutureTask.runAndReset(Unknown Source)
# 	at java.base/java.util.concurrent.ScheduledThreadPoolExecutor$ScheduledFutureTask.run(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(Unknown Source)
# 	at java.base/java.lang.Thread.run(Unknown Source)
# 22/07/13 14:47:24 WARN ExecutorPodsSnapshotsStoreImpl: Exception when notifying snapshot subscriber.
# io.fabric8.kubernetes.client.KubernetesClientException: Failure executing: POST at: https://kubernetes.default.svc.cluster.local/api/v1/namespaces/ke-decile-lab/pods. Message: Forbidden!Configured service account doesn't have access. Service account may have been revoked. pods "test-0358db81f7fdb3a2-exec-358" is forbidden: exceeded quota: ke-decile-lab-quota, requested: requests.cpu=2, used: requests.cpu=32, limited: requests.cpu=32.
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.requestFailure(OperationSupport.java:639)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.assertResponseCode(OperationSupport.java:576)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleResponse(OperationSupport.java:543)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleResponse(OperationSupport.java:504)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleCreate(OperationSupport.java:292)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.handleCreate(BaseOperation.java:893)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.create(BaseOperation.java:372)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.create(BaseOperation.java:86)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$requestNewExecutors$1(ExecutorPodsAllocator.scala:400)
# 	at scala.collection.immutable.Range.foreach$mVc$sp(Range.scala:158)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.requestNewExecutors(ExecutorPodsAllocator.scala:382)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$onNewSnapshots$36(ExecutorPodsAllocator.scala:346)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$onNewSnapshots$36$adapted(ExecutorPodsAllocator.scala:339)
# 	at scala.collection.mutable.ResizableArray.foreach(ResizableArray.scala:62)
# 	at scala.collection.mutable.ResizableArray.foreach$(ResizableArray.scala:55)
# 	at scala.collection.mutable.ArrayBuffer.foreach(ArrayBuffer.scala:49)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.onNewSnapshots(ExecutorPodsAllocator.scala:339)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3$adapted(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber.org$apache$spark$scheduler$cluster$k8s$ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber$$processSnapshotsInternal(ExecutorPodsSnapshotsStoreImpl.scala:138)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber.processSnapshots(ExecutorPodsSnapshotsStoreImpl.scala:126)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$$anon$1.run(ExecutorPodsSnapshotsStoreImpl.scala:90)
# 	at java.base/java.util.concurrent.Executors$RunnableAdapter.call(Unknown Source)
# 	at java.base/java.util.concurrent.FutureTask.run(Unknown Source)
# 	at java.base/java.util.concurrent.ScheduledThreadPoolExecutor$ScheduledFutureTask.run(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(Unknown Source)
# 	at java.base/java.lang.Thread.run(Unknown Source)
# 22/07/13 14:47:24 WARN ExecutorPodsSnapshotsStoreImpl: Exception when notifying snapshot subscriber.
# io.fabric8.kubernetes.client.KubernetesClientException: Failure executing: POST at: https://kubernetes.default.svc.cluster.local/api/v1/namespaces/ke-decile-lab/pods. Message: Forbidden!Configured service account doesn't have access. Service account may have been revoked. pods "test-0358db81f7fdb3a2-exec-359" is forbidden: exceeded quota: ke-decile-lab-quota, requested: requests.cpu=2, used: requests.cpu=32, limited: requests.cpu=32.
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.requestFailure(OperationSupport.java:639)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.assertResponseCode(OperationSupport.java:576)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleResponse(OperationSupport.java:543)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleResponse(OperationSupport.java:504)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleCreate(OperationSupport.java:292)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.handleCreate(BaseOperation.java:893)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.create(BaseOperation.java:372)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.create(BaseOperation.java:86)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$requestNewExecutors$1(ExecutorPodsAllocator.scala:400)
# 	at scala.collection.immutable.Range.foreach$mVc$sp(Range.scala:158)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.requestNewExecutors(ExecutorPodsAllocator.scala:382)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$onNewSnapshots$36(ExecutorPodsAllocator.scala:346)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$onNewSnapshots$36$adapted(ExecutorPodsAllocator.scala:339)
# 	at scala.collection.mutable.ResizableArray.foreach(ResizableArray.scala:62)
# 	at scala.collection.mutable.ResizableArray.foreach$(ResizableArray.scala:55)
# 	at scala.collection.mutable.ArrayBuffer.foreach(ArrayBuffer.scala:49)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.onNewSnapshots(ExecutorPodsAllocator.scala:339)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3$adapted(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber.org$apache$spark$scheduler$cluster$k8s$ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber$$processSnapshotsInternal(ExecutorPodsSnapshotsStoreImpl.scala:138)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber.processSnapshots(ExecutorPodsSnapshotsStoreImpl.scala:126)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl.$anonfun$addSubscriber$1(ExecutorPodsSnapshotsStoreImpl.scala:81)
# 	at java.base/java.util.concurrent.Executors$RunnableAdapter.call(Unknown Source)
# 	at java.base/java.util.concurrent.FutureTask.runAndReset(Unknown Source)
# 	at java.base/java.util.concurrent.ScheduledThreadPoolExecutor$ScheduledFutureTask.run(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(Unknown Source)
# 	at java.base/java.lang.Thread.run(Unknown Source)
# 22/07/13 14:47:25 WARN ExecutorPodsSnapshotsStoreImpl: Exception when notifying snapshot subscriber.
# io.fabric8.kubernetes.client.KubernetesClientException: Failure executing: POST at: https://kubernetes.default.svc.cluster.local/api/v1/namespaces/ke-decile-lab/pods. Message: Forbidden!Configured service account doesn't have access. Service account may have been revoked. pods "test-0358db81f7fdb3a2-exec-360" is forbidden: exceeded quota: ke-decile-lab-quota, requested: requests.cpu=2, used: requests.cpu=32, limited: requests.cpu=32.
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.requestFailure(OperationSupport.java:639)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.assertResponseCode(OperationSupport.java:576)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleResponse(OperationSupport.java:543)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleResponse(OperationSupport.java:504)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleCreate(OperationSupport.java:292)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.handleCreate(BaseOperation.java:893)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.create(BaseOperation.java:372)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.create(BaseOperation.java:86)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$requestNewExecutors$1(ExecutorPodsAllocator.scala:400)
# 	at scala.collection.immutable.Range.foreach$mVc$sp(Range.scala:158)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.requestNewExecutors(ExecutorPodsAllocator.scala:382)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$onNewSnapshots$36(ExecutorPodsAllocator.scala:346)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$onNewSnapshots$36$adapted(ExecutorPodsAllocator.scala:339)
# 	at scala.collection.mutable.ResizableArray.foreach(ResizableArray.scala:62)
# 	at scala.collection.mutable.ResizableArray.foreach$(ResizableArray.scala:55)
# 	at scala.collection.mutable.ArrayBuffer.foreach(ArrayBuffer.scala:49)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.onNewSnapshots(ExecutorPodsAllocator.scala:339)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3$adapted(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber.org$apache$spark$scheduler$cluster$k8s$ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber$$processSnapshotsInternal(ExecutorPodsSnapshotsStoreImpl.scala:138)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber.processSnapshots(ExecutorPodsSnapshotsStoreImpl.scala:126)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$$anon$1.run(ExecutorPodsSnapshotsStoreImpl.scala:90)
# 	at java.base/java.util.concurrent.Executors$RunnableAdapter.call(Unknown Source)
# 	at java.base/java.util.concurrent.FutureTask.run(Unknown Source)
# 	at java.base/java.util.concurrent.ScheduledThreadPoolExecutor$ScheduledFutureTask.run(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(Unknown Source)
# 	at java.base/java.lang.Thread.run(Unknown Source)
# 22/07/13 14:47:25 WARN ExecutorPodsSnapshotsStoreImpl: Exception when notifying snapshot subscriber.
# io.fabric8.kubernetes.client.KubernetesClientException: Failure executing: POST at: https://kubernetes.default.svc.cluster.local/api/v1/namespaces/ke-decile-lab/pods. Message: Forbidden!Configured service account doesn't have access. Service account may have been revoked. pods "test-0358db81f7fdb3a2-exec-361" is forbidden: exceeded quota: ke-decile-lab-quota, requested: requests.cpu=2, used: requests.cpu=32, limited: requests.cpu=32.
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.requestFailure(OperationSupport.java:639)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.assertResponseCode(OperationSupport.java:576)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleResponse(OperationSupport.java:543)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleResponse(OperationSupport.java:504)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleCreate(OperationSupport.java:292)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.handleCreate(BaseOperation.java:893)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.create(BaseOperation.java:372)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.create(BaseOperation.java:86)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$requestNewExecutors$1(ExecutorPodsAllocator.scala:400)
# 	at scala.collection.immutable.Range.foreach$mVc$sp(Range.scala:158)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.requestNewExecutors(ExecutorPodsAllocator.scala:382)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$onNewSnapshots$36(ExecutorPodsAllocator.scala:346)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$onNewSnapshots$36$adapted(ExecutorPodsAllocator.scala:339)
# 	at scala.collection.mutable.ResizableArray.foreach(ResizableArray.scala:62)
# 	at scala.collection.mutable.ResizableArray.foreach$(ResizableArray.scala:55)
# 	at scala.collection.mutable.ArrayBuffer.foreach(ArrayBuffer.scala:49)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.onNewSnapshots(ExecutorPodsAllocator.scala:339)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3$adapted(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber.org$apache$spark$scheduler$cluster$k8s$ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber$$processSnapshotsInternal(ExecutorPodsSnapshotsStoreImpl.scala:138)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber.processSnapshots(ExecutorPodsSnapshotsStoreImpl.scala:126)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl.$anonfun$addSubscriber$1(ExecutorPodsSnapshotsStoreImpl.scala:81)
# 	at java.base/java.util.concurrent.Executors$RunnableAdapter.call(Unknown Source)
# 	at java.base/java.util.concurrent.FutureTask.runAndReset(Unknown Source)
# 	at java.base/java.util.concurrent.ScheduledThreadPoolExecutor$ScheduledFutureTask.run(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(Unknown Source)
# 	at java.base/java.lang.Thread.run(Unknown Source)
# 22/07/13 14:47:26 WARN ExecutorPodsSnapshotsStoreImpl: Exception when notifying snapshot subscriber.
# io.fabric8.kubernetes.client.KubernetesClientException: Failure executing: POST at: https://kubernetes.default.svc.cluster.local/api/v1/namespaces/ke-decile-lab/pods. Message: Forbidden!Configured service account doesn't have access. Service account may have been revoked. pods "test-0358db81f7fdb3a2-exec-362" is forbidden: exceeded quota: ke-decile-lab-quota, requested: requests.cpu=2, used: requests.cpu=32, limited: requests.cpu=32.
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.requestFailure(OperationSupport.java:639)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.assertResponseCode(OperationSupport.java:576)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleResponse(OperationSupport.java:543)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleResponse(OperationSupport.java:504)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleCreate(OperationSupport.java:292)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.handleCreate(BaseOperation.java:893)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.create(BaseOperation.java:372)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.create(BaseOperation.java:86)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$requestNewExecutors$1(ExecutorPodsAllocator.scala:400)
# 	at scala.collection.immutable.Range.foreach$mVc$sp(Range.scala:158)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.requestNewExecutors(ExecutorPodsAllocator.scala:382)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$onNewSnapshots$36(ExecutorPodsAllocator.scala:346)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$onNewSnapshots$36$adapted(ExecutorPodsAllocator.scala:339)
# 	at scala.collection.mutable.ResizableArray.foreach(ResizableArray.scala:62)
# 	at scala.collection.mutable.ResizableArray.foreach$(ResizableArray.scala:55)
# 	at scala.collection.mutable.ArrayBuffer.foreach(ArrayBuffer.scala:49)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.onNewSnapshots(ExecutorPodsAllocator.scala:339)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3$adapted(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber.org$apache$spark$scheduler$cluster$k8s$ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber$$processSnapshotsInternal(ExecutorPodsSnapshotsStoreImpl.scala:138)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber.processSnapshots(ExecutorPodsSnapshotsStoreImpl.scala:126)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl.$anonfun$addSubscriber$1(ExecutorPodsSnapshotsStoreImpl.scala:81)
# 	at java.base/java.util.concurrent.Executors$RunnableAdapter.call(Unknown Source)
# 	at java.base/java.util.concurrent.FutureTask.runAndReset(Unknown Source)
# 	at java.base/java.util.concurrent.ScheduledThreadPoolExecutor$ScheduledFutureTask.run(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(Unknown Source)
# 	at java.base/java.lang.Thread.run(Unknown Source)
# 22/07/13 14:47:27 WARN ExecutorPodsSnapshotsStoreImpl: Exception when notifying snapshot subscriber.
# io.fabric8.kubernetes.client.KubernetesClientException: Failure executing: POST at: https://kubernetes.default.svc.cluster.local/api/v1/namespaces/ke-decile-lab/pods. Message: Forbidden!Configured service account doesn't have access. Service account may have been revoked. pods "test-0358db81f7fdb3a2-exec-363" is forbidden: exceeded quota: ke-decile-lab-quota, requested: requests.cpu=2, used: requests.cpu=32, limited: requests.cpu=32.
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.requestFailure(OperationSupport.java:639)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.assertResponseCode(OperationSupport.java:576)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleResponse(OperationSupport.java:543)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleResponse(OperationSupport.java:504)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleCreate(OperationSupport.java:292)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.handleCreate(BaseOperation.java:893)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.create(BaseOperation.java:372)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.create(BaseOperation.java:86)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$requestNewExecutors$1(ExecutorPodsAllocator.scala:400)
# 	at scala.collection.immutable.Range.foreach$mVc$sp(Range.scala:158)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.requestNewExecutors(ExecutorPodsAllocator.scala:382)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$onNewSnapshots$36(ExecutorPodsAllocator.scala:346)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$onNewSnapshots$36$adapted(ExecutorPodsAllocator.scala:339)
# 	at scala.collection.mutable.ResizableArray.foreach(ResizableArray.scala:62)
# 	at scala.collection.mutable.ResizableArray.foreach$(ResizableArray.scala:55)
# 	at scala.collection.mutable.ArrayBuffer.foreach(ArrayBuffer.scala:49)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.onNewSnapshots(ExecutorPodsAllocator.scala:339)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3$adapted(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber.org$apache$spark$scheduler$cluster$k8s$ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber$$processSnapshotsInternal(ExecutorPodsSnapshotsStoreImpl.scala:138)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber.processSnapshots(ExecutorPodsSnapshotsStoreImpl.scala:126)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl.$anonfun$addSubscriber$1(ExecutorPodsSnapshotsStoreImpl.scala:81)
# 	at java.base/java.util.concurrent.Executors$RunnableAdapter.call(Unknown Source)
# 	at java.base/java.util.concurrent.FutureTask.runAndReset(Unknown Source)
# 	at java.base/java.util.concurrent.ScheduledThreadPoolExecutor$ScheduledFutureTask.run(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(Unknown Source)
# 	at java.base/java.lang.Thread.run(Unknown Source)
# 22/07/13 14:47:28 WARN ExecutorPodsSnapshotsStoreImpl: Exception when notifying snapshot subscriber.
# io.fabric8.kubernetes.client.KubernetesClientException: Failure executing: POST at: https://kubernetes.default.svc.cluster.local/api/v1/namespaces/ke-decile-lab/pods. Message: Forbidden!Configured service account doesn't have access. Service account may have been revoked. pods "test-0358db81f7fdb3a2-exec-364" is forbidden: exceeded quota: ke-decile-lab-quota, requested: requests.cpu=2, used: requests.cpu=32, limited: requests.cpu=32.
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.requestFailure(OperationSupport.java:639)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.assertResponseCode(OperationSupport.java:576)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleResponse(OperationSupport.java:543)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleResponse(OperationSupport.java:504)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleCreate(OperationSupport.java:292)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.handleCreate(BaseOperation.java:893)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.create(BaseOperation.java:372)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.create(BaseOperation.java:86)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$requestNewExecutors$1(ExecutorPodsAllocator.scala:400)
# 	at scala.collection.immutable.Range.foreach$mVc$sp(Range.scala:158)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.requestNewExecutors(ExecutorPodsAllocator.scala:382)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$onNewSnapshots$36(ExecutorPodsAllocator.scala:346)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$onNewSnapshots$36$adapted(ExecutorPodsAllocator.scala:339)
# 	at scala.collection.mutable.ResizableArray.foreach(ResizableArray.scala:62)
# 	at scala.collection.mutable.ResizableArray.foreach$(ResizableArray.scala:55)
# 	at scala.collection.mutable.ArrayBuffer.foreach(ArrayBuffer.scala:49)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.onNewSnapshots(ExecutorPodsAllocator.scala:339)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3$adapted(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber.org$apache$spark$scheduler$cluster$k8s$ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber$$processSnapshotsInternal(ExecutorPodsSnapshotsStoreImpl.scala:138)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber.processSnapshots(ExecutorPodsSnapshotsStoreImpl.scala:126)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl.$anonfun$addSubscriber$1(ExecutorPodsSnapshotsStoreImpl.scala:81)
# 	at java.base/java.util.concurrent.Executors$RunnableAdapter.call(Unknown Source)
# 	at java.base/java.util.concurrent.FutureTask.runAndReset(Unknown Source)
# 	at java.base/java.util.concurrent.ScheduledThreadPoolExecutor$ScheduledFutureTask.run(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(Unknown Source)
# 	at java.base/java.lang.Thread.run(Unknown Source)
# 22/07/13 14:47:29 WARN ExecutorPodsSnapshotsStoreImpl: Exception when notifying snapshot subscriber.
# io.fabric8.kubernetes.client.KubernetesClientException: Failure executing: POST at: https://kubernetes.default.svc.cluster.local/api/v1/namespaces/ke-decile-lab/pods. Message: Forbidden!Configured service account doesn't have access. Service account may have been revoked. pods "test-0358db81f7fdb3a2-exec-365" is forbidden: exceeded quota: ke-decile-lab-quota, requested: requests.cpu=2, used: requests.cpu=32, limited: requests.cpu=32.
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.requestFailure(OperationSupport.java:639)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.assertResponseCode(OperationSupport.java:576)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleResponse(OperationSupport.java:543)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleResponse(OperationSupport.java:504)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleCreate(OperationSupport.java:292)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.handleCreate(BaseOperation.java:893)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.create(BaseOperation.java:372)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.create(BaseOperation.java:86)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$requestNewExecutors$1(ExecutorPodsAllocator.scala:400)
# 	at scala.collection.immutable.Range.foreach$mVc$sp(Range.scala:158)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.requestNewExecutors(ExecutorPodsAllocator.scala:382)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$onNewSnapshots$36(ExecutorPodsAllocator.scala:346)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$onNewSnapshots$36$adapted(ExecutorPodsAllocator.scala:339)
# 	at scala.collection.mutable.ResizableArray.foreach(ResizableArray.scala:62)
# 	at scala.collection.mutable.ResizableArray.foreach$(ResizableArray.scala:55)
# 	at scala.collection.mutable.ArrayBuffer.foreach(ArrayBuffer.scala:49)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.onNewSnapshots(ExecutorPodsAllocator.scala:339)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3$adapted(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber.org$apache$spark$scheduler$cluster$k8s$ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber$$processSnapshotsInternal(ExecutorPodsSnapshotsStoreImpl.scala:138)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber.processSnapshots(ExecutorPodsSnapshotsStoreImpl.scala:126)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl.$anonfun$addSubscriber$1(ExecutorPodsSnapshotsStoreImpl.scala:81)
# 	at java.base/java.util.concurrent.Executors$RunnableAdapter.call(Unknown Source)
# 	at java.base/java.util.concurrent.FutureTask.runAndReset(Unknown Source)
# 	at java.base/java.util.concurrent.ScheduledThreadPoolExecutor$ScheduledFutureTask.run(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(Unknown Source)
# 	at java.base/java.lang.Thread.run(Unknown Source)
# 22/07/13 14:47:30 WARN ExecutorPodsSnapshotsStoreImpl: Exception when notifying snapshot subscriber.
# io.fabric8.kubernetes.client.KubernetesClientException: Failure executing: POST at: https://kubernetes.default.svc.cluster.local/api/v1/namespaces/ke-decile-lab/pods. Message: Forbidden!Configured service account doesn't have access. Service account may have been revoked. pods "test-0358db81f7fdb3a2-exec-366" is forbidden: exceeded quota: ke-decile-lab-quota, requested: requests.cpu=2, used: requests.cpu=32, limited: requests.cpu=32.
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.requestFailure(OperationSupport.java:639)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.assertResponseCode(OperationSupport.java:576)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleResponse(OperationSupport.java:543)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleResponse(OperationSupport.java:504)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleCreate(OperationSupport.java:292)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.handleCreate(BaseOperation.java:893)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.create(BaseOperation.java:372)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.create(BaseOperation.java:86)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$requestNewExecutors$1(ExecutorPodsAllocator.scala:400)
# 	at scala.collection.immutable.Range.foreach$mVc$sp(Range.scala:158)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.requestNewExecutors(ExecutorPodsAllocator.scala:382)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$onNewSnapshots$36(ExecutorPodsAllocator.scala:346)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$onNewSnapshots$36$adapted(ExecutorPodsAllocator.scala:339)
# 	at scala.collection.mutable.ResizableArray.foreach(ResizableArray.scala:62)
# 	at scala.collection.mutable.ResizableArray.foreach$(ResizableArray.scala:55)
# 	at scala.collection.mutable.ArrayBuffer.foreach(ArrayBuffer.scala:49)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.onNewSnapshots(ExecutorPodsAllocator.scala:339)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3$adapted(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber.org$apache$spark$scheduler$cluster$k8s$ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber$$processSnapshotsInternal(ExecutorPodsSnapshotsStoreImpl.scala:138)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber.processSnapshots(ExecutorPodsSnapshotsStoreImpl.scala:126)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl.$anonfun$addSubscriber$1(ExecutorPodsSnapshotsStoreImpl.scala:81)
# 	at java.base/java.util.concurrent.Executors$RunnableAdapter.call(Unknown Source)
# 	at java.base/java.util.concurrent.FutureTask.runAndReset(Unknown Source)
# 	at java.base/java.util.concurrent.ScheduledThreadPoolExecutor$ScheduledFutureTask.run(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(Unknown Source)
# 	at java.base/java.lang.Thread.run(Unknown Source)
# 22/07/13 14:47:31 WARN ExecutorPodsSnapshotsStoreImpl: Exception when notifying snapshot subscriber.
# io.fabric8.kubernetes.client.KubernetesClientException: Failure executing: POST at: https://kubernetes.default.svc.cluster.local/api/v1/namespaces/ke-decile-lab/pods. Message: Forbidden!Configured service account doesn't have access. Service account may have been revoked. pods "test-0358db81f7fdb3a2-exec-367" is forbidden: exceeded quota: ke-decile-lab-quota, requested: requests.cpu=2, used: requests.cpu=32, limited: requests.cpu=32.
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.requestFailure(OperationSupport.java:639)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.assertResponseCode(OperationSupport.java:576)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleResponse(OperationSupport.java:543)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleResponse(OperationSupport.java:504)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleCreate(OperationSupport.java:292)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.handleCreate(BaseOperation.java:893)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.create(BaseOperation.java:372)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.create(BaseOperation.java:86)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$requestNewExecutors$1(ExecutorPodsAllocator.scala:400)
# 	at scala.collection.immutable.Range.foreach$mVc$sp(Range.scala:158)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.requestNewExecutors(ExecutorPodsAllocator.scala:382)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$onNewSnapshots$36(ExecutorPodsAllocator.scala:346)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$onNewSnapshots$36$adapted(ExecutorPodsAllocator.scala:339)
# 	at scala.collection.mutable.ResizableArray.foreach(ResizableArray.scala:62)
# 	at scala.collection.mutable.ResizableArray.foreach$(ResizableArray.scala:55)
# 	at scala.collection.mutable.ArrayBuffer.foreach(ArrayBuffer.scala:49)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.onNewSnapshots(ExecutorPodsAllocator.scala:339)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3$adapted(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber.org$apache$spark$scheduler$cluster$k8s$ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber$$processSnapshotsInternal(ExecutorPodsSnapshotsStoreImpl.scala:138)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber.processSnapshots(ExecutorPodsSnapshotsStoreImpl.scala:126)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl.$anonfun$addSubscriber$1(ExecutorPodsSnapshotsStoreImpl.scala:81)
# 	at java.base/java.util.concurrent.Executors$RunnableAdapter.call(Unknown Source)
# 	at java.base/java.util.concurrent.FutureTask.runAndReset(Unknown Source)
# 	at java.base/java.util.concurrent.ScheduledThreadPoolExecutor$ScheduledFutureTask.run(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(Unknown Source)
# 	at java.base/java.lang.Thread.run(Unknown Source)
# 22/07/13 14:47:32 WARN ExecutorPodsSnapshotsStoreImpl: Exception when notifying snapshot subscriber.
# io.fabric8.kubernetes.client.KubernetesClientException: Failure executing: POST at: https://kubernetes.default.svc.cluster.local/api/v1/namespaces/ke-decile-lab/pods. Message: Forbidden!Configured service account doesn't have access. Service account may have been revoked. pods "test-0358db81f7fdb3a2-exec-368" is forbidden: exceeded quota: ke-decile-lab-quota, requested: requests.cpu=2, used: requests.cpu=32, limited: requests.cpu=32.
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.requestFailure(OperationSupport.java:639)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.assertResponseCode(OperationSupport.java:576)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleResponse(OperationSupport.java:543)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleResponse(OperationSupport.java:504)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleCreate(OperationSupport.java:292)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.handleCreate(BaseOperation.java:893)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.create(BaseOperation.java:372)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.create(BaseOperation.java:86)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$requestNewExecutors$1(ExecutorPodsAllocator.scala:400)
# 	at scala.collection.immutable.Range.foreach$mVc$sp(Range.scala:158)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.requestNewExecutors(ExecutorPodsAllocator.scala:382)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$onNewSnapshots$36(ExecutorPodsAllocator.scala:346)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$onNewSnapshots$36$adapted(ExecutorPodsAllocator.scala:339)
# 	at scala.collection.mutable.ResizableArray.foreach(ResizableArray.scala:62)
# 	at scala.collection.mutable.ResizableArray.foreach$(ResizableArray.scala:55)
# 	at scala.collection.mutable.ArrayBuffer.foreach(ArrayBuffer.scala:49)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.onNewSnapshots(ExecutorPodsAllocator.scala:339)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3$adapted(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber.org$apache$spark$scheduler$cluster$k8s$ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber$$processSnapshotsInternal(ExecutorPodsSnapshotsStoreImpl.scala:138)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber.processSnapshots(ExecutorPodsSnapshotsStoreImpl.scala:126)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl.$anonfun$addSubscriber$1(ExecutorPodsSnapshotsStoreImpl.scala:81)
# 	at java.base/java.util.concurrent.Executors$RunnableAdapter.call(Unknown Source)
# 	at java.base/java.util.concurrent.FutureTask.runAndReset(Unknown Source)
# 	at java.base/java.util.concurrent.ScheduledThreadPoolExecutor$ScheduledFutureTask.run(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(Unknown Source)
# 	at java.base/java.lang.Thread.run(Unknown Source)
# 22/07/13 14:47:33 WARN ExecutorPodsSnapshotsStoreImpl: Exception when notifying snapshot subscriber.
# io.fabric8.kubernetes.client.KubernetesClientException: Failure executing: POST at: https://kubernetes.default.svc.cluster.local/api/v1/namespaces/ke-decile-lab/pods. Message: Forbidden!Configured service account doesn't have access. Service account may have been revoked. pods "test-0358db81f7fdb3a2-exec-369" is forbidden: exceeded quota: ke-decile-lab-quota, requested: requests.cpu=2, used: requests.cpu=32, limited: requests.cpu=32.
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.requestFailure(OperationSupport.java:639)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.assertResponseCode(OperationSupport.java:576)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleResponse(OperationSupport.java:543)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleResponse(OperationSupport.java:504)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleCreate(OperationSupport.java:292)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.handleCreate(BaseOperation.java:893)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.create(BaseOperation.java:372)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.create(BaseOperation.java:86)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$requestNewExecutors$1(ExecutorPodsAllocator.scala:400)
# 	at scala.collection.immutable.Range.foreach$mVc$sp(Range.scala:158)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.requestNewExecutors(ExecutorPodsAllocator.scala:382)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$onNewSnapshots$36(ExecutorPodsAllocator.scala:346)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$onNewSnapshots$36$adapted(ExecutorPodsAllocator.scala:339)
# 	at scala.collection.mutable.ResizableArray.foreach(ResizableArray.scala:62)
# 	at scala.collection.mutable.ResizableArray.foreach$(ResizableArray.scala:55)
# 	at scala.collection.mutable.ArrayBuffer.foreach(ArrayBuffer.scala:49)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.onNewSnapshots(ExecutorPodsAllocator.scala:339)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3$adapted(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber.org$apache$spark$scheduler$cluster$k8s$ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber$$processSnapshotsInternal(ExecutorPodsSnapshotsStoreImpl.scala:138)
# ...
# 	 container started at: 2022-07-13T14:48:38Z
# 	 container finished at: 2022-07-13T14:50:49Z
# 	 exit code: 137
# 	 termination reason: OOMKilled
#
# 22/07/13 14:50:51 WARN TaskSetManager: Lost task 1.1 in stage 275.3 (TID 16391) (192.168.34.121 executor 415): FetchFailed(null, shuffleId=10, mapIndex=-1, mapId=-1, reduceId=44, message=
# org.apache.spark.shuffle.MetadataFetchFailedException: Missing an output location for shuffle 10 partition 44
# 	at org.apache.spark.MapOutputTracker$.validateStatus(MapOutputTracker.scala:1619)
# 	at org.apache.spark.MapOutputTracker$.$anonfun$convertMapStatuses$10(MapOutputTracker.scala:1566)
# 	at org.apache.spark.MapOutputTracker$.$anonfun$convertMapStatuses$10$adapted(MapOutputTracker.scala:1565)
# 	at scala.collection.Iterator.foreach(Iterator.scala:943)
# 	at scala.collection.Iterator.foreach$(Iterator.scala:943)
# 	at scala.collection.AbstractIterator.foreach(Iterator.scala:1431)
# 	at org.apache.spark.MapOutputTracker$.convertMapStatuses(MapOutputTracker.scala:1565)
# 	at org.apache.spark.MapOutputTrackerWorker.getMapSizesByExecutorIdImpl(MapOutputTracker.scala:1230)
# 	at org.apache.spark.MapOutputTrackerWorker.getMapSizesByExecutorId(MapOutputTracker.scala:1192)
# 	at org.apache.spark.shuffle.sort.SortShuffleManager.getReader(SortShuffleManager.scala:140)
# 	at org.apache.spark.shuffle.ShuffleManager.getReader(ShuffleManager.scala:63)
# 	at org.apache.spark.shuffle.ShuffleManager.getReader$(ShuffleManager.scala:57)
# 	at org.apache.spark.shuffle.sort.SortShuffleManager.getReader(SortShuffleManager.scala:73)
# 	at org.apache.spark.sql.execution.ShuffledRowRDD.compute(ShuffledRowRDD.scala:208)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:373)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:337)
# 	at org.apache.spark.rdd.MapPartitionsRDD.compute(MapPartitionsRDD.scala:52)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:373)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:337)
# 	at org.apache.spark.rdd.ZippedPartitionsRDD2.compute(ZippedPartitionsRDD.scala:89)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:373)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:337)
# 	at org.apache.spark.rdd.MapPartitionsRDD.compute(MapPartitionsRDD.scala:52)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:373)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:337)
# 	at org.apache.spark.rdd.MapPartitionsRDD.compute(MapPartitionsRDD.scala:52)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:373)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:337)
# 	at org.apache.spark.shuffle.ShuffleWriteProcessor.write(ShuffleWriteProcessor.scala:59)
# 	at org.apache.spark.scheduler.ShuffleMapTask.runTask(ShuffleMapTask.scala:99)
# 	at org.apache.spark.scheduler.ShuffleMapTask.runTask(ShuffleMapTask.scala:52)
# 	at org.apache.spark.scheduler.Task.run(Task.scala:131)
# 	at org.apache.spark.executor.Executor$TaskRunner.$anonfun$run$3(Executor.scala:506)
# 	at org.apache.spark.util.Utils$.tryWithSafeFinally(Utils.scala:1462)
# 	at org.apache.spark.executor.Executor$TaskRunner.run(Executor.scala:509)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(Unknown Source)
# 	at java.base/java.lang.Thread.run(Unknown Source)
#
# )
# 22/07/13 14:50:51 WARN TaskSetManager: Lost task 5.1 in stage 275.3 (TID 16392) (192.168.34.121 executor 415): FetchFailed(null, shuffleId=10, mapIndex=-1, mapId=-1, reduceId=167, message=
# org.apache.spark.shuffle.MetadataFetchFailedException: Missing an output location for shuffle 10 partition 167
# 	at org.apache.spark.MapOutputTracker$.validateStatus(MapOutputTracker.scala:1619)
# 	at org.apache.spark.MapOutputTracker$.$anonfun$convertMapStatuses$10(MapOutputTracker.scala:1566)
# 	at org.apache.spark.MapOutputTracker$.$anonfun$convertMapStatuses$10$adapted(MapOutputTracker.scala:1565)
# 	at scala.collection.Iterator.foreach(Iterator.scala:943)
# 	at scala.collection.Iterator.foreach$(Iterator.scala:943)
# 	at scala.collection.AbstractIterator.foreach(Iterator.scala:1431)
# 	at org.apache.spark.MapOutputTracker$.convertMapStatuses(MapOutputTracker.scala:1565)
# 	at org.apache.spark.MapOutputTrackerWorker.getMapSizesByExecutorIdImpl(MapOutputTracker.scala:1230)
# 	at org.apache.spark.MapOutputTrackerWorker.getMapSizesByExecutorId(MapOutputTracker.scala:1192)
# 	at org.apache.spark.shuffle.sort.SortShuffleManager.getReader(SortShuffleManager.scala:140)
# 	at org.apache.spark.shuffle.ShuffleManager.getReader(ShuffleManager.scala:63)
# 	at org.apache.spark.shuffle.ShuffleManager.getReader$(ShuffleManager.scala:57)
# 	at org.apache.spark.shuffle.sort.SortShuffleManager.getReader(SortShuffleManager.scala:73)
# 	at org.apache.spark.sql.execution.ShuffledRowRDD.compute(ShuffledRowRDD.scala:208)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:373)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:337)
# 	at org.apache.spark.rdd.MapPartitionsRDD.compute(MapPartitionsRDD.scala:52)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:373)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:337)
# 	at org.apache.spark.rdd.ZippedPartitionsRDD2.compute(ZippedPartitionsRDD.scala:89)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:373)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:337)
# 	at org.apache.spark.rdd.MapPartitionsRDD.compute(MapPartitionsRDD.scala:52)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:373)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:337)
# 	at org.apache.spark.rdd.MapPartitionsRDD.compute(MapPartitionsRDD.scala:52)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:373)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:337)
# 	at org.apache.spark.shuffle.ShuffleWriteProcessor.write(ShuffleWriteProcessor.scala:59)
# 	at org.apache.spark.scheduler.ShuffleMapTask.runTask(ShuffleMapTask.scala:99)
# 	at org.apache.spark.scheduler.ShuffleMapTask.runTask(ShuffleMapTask.scala:52)
# 	at org.apache.spark.scheduler.Task.run(Task.scala:131)
# 	at org.apache.spark.executor.Executor$TaskRunner.$anonfun$run$3(Executor.scala:506)
# 	at org.apache.spark.util.Utils$.tryWithSafeFinally(Utils.scala:1462)
# 	at org.apache.spark.executor.Executor$TaskRunner.run(Executor.scala:509)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(Unknown Source)
# 	at java.base/java.lang.Thread.run(Unknown Source)
#
# )
# 22/07/13 14:50:51 WARN TaskSetManager: Lost task 6.0 in stage 275.3 (TID 16393) (192.168.34.121 executor 415): FetchFailed(null, shuffleId=10, mapIndex=-1, mapId=-1, reduceId=199, message=
# org.apache.spark.shuffle.MetadataFetchFailedException: Missing an output location for shuffle 10 partition 199
# 	at org.apache.spark.MapOutputTracker$.validateStatus(MapOutputTracker.scala:1619)
# 	at org.apache.spark.MapOutputTracker$.$anonfun$convertMapStatuses$10(MapOutputTracker.scala:1566)
# 	at org.apache.spark.MapOutputTracker$.$anonfun$convertMapStatuses$10$adapted(MapOutputTracker.scala:1565)
# 	at scala.collection.Iterator.foreach(Iterator.scala:943)
# 	at scala.collection.Iterator.foreach$(Iterator.scala:943)
# 	at scala.collection.AbstractIterator.foreach(Iterator.scala:1431)
# 	at org.apache.spark.MapOutputTracker$.convertMapStatuses(MapOutputTracker.scala:1565)
# 	at org.apache.spark.MapOutputTrackerWorker.getMapSizesByExecutorIdImpl(MapOutputTracker.scala:1230)
# 	at org.apache.spark.MapOutputTrackerWorker.getMapSizesByExecutorId(MapOutputTracker.scala:1192)
# 	at org.apache.spark.shuffle.sort.SortShuffleManager.getReader(SortShuffleManager.scala:140)
# 	at org.apache.spark.shuffle.ShuffleManager.getReader(ShuffleManager.scala:63)
# 	at org.apache.spark.shuffle.ShuffleManager.getReader$(ShuffleManager.scala:57)
# 	at org.apache.spark.shuffle.sort.SortShuffleManager.getReader(SortShuffleManager.scala:73)
# 	at org.apache.spark.sql.execution.ShuffledRowRDD.compute(ShuffledRowRDD.scala:208)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:373)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:337)
# 	at org.apache.spark.rdd.MapPartitionsRDD.compute(MapPartitionsRDD.scala:52)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:373)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:337)
# 	at org.apache.spark.rdd.ZippedPartitionsRDD2.compute(ZippedPartitionsRDD.scala:89)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:373)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:337)
# 	at org.apache.spark.rdd.MapPartitionsRDD.compute(MapPartitionsRDD.scala:52)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:373)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:337)
# 	at org.apache.spark.rdd.MapPartitionsRDD.compute(MapPartitionsRDD.scala:52)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:373)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:337)
# 	at org.apache.spark.shuffle.ShuffleWriteProcessor.write(ShuffleWriteProcessor.scala:59)
# 	at org.apache.spark.scheduler.ShuffleMapTask.runTask(ShuffleMapTask.scala:99)
# 	at org.apache.spark.scheduler.ShuffleMapTask.runTask(ShuffleMapTask.scala:52)
# 	at org.apache.spark.scheduler.Task.run(Task.scala:131)
# 	at org.apache.spark.executor.Executor$TaskRunner.$anonfun$run$3(Executor.scala:506)
# 	at org.apache.spark.util.Utils$.tryWithSafeFinally(Utils.scala:1462)
# 	at org.apache.spark.executor.Executor$TaskRunner.run(Executor.scala:509)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(Unknown Source)
# 	at java.base/java.lang.Thread.run(Unknown Source)
#
# )
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# Input In [11], in <cell line: 1>()
# ----> 1 measurement2.select('concept_class_id').distinct().collect()
#
# File /usr/local/lib/python3.9/dist-packages/pyspark/sql/dataframe.py:693, in DataFrame.collect(self)
#     683 """Returns all the records as a list of :class:`Row`.
#     684
#     685 .. versionadded:: 1.3.0
#    (...)
#     690 [Row(age=2, name='Alice'), Row(age=5, name='Bob')]
#     691 """
#     692 with SCCallSiteSync(self._sc) as css:
# --> 693     sock_info = self._jdf.collectToPython()
#     694 return list(_load_from_socket(sock_info, BatchedSerializer(PickleSerializer())))
#
# File /usr/local/lib/python3.9/dist-packages/py4j/java_gateway.py:1321, in JavaMember.__call__(self, *args)
#    1315 command = proto.CALL_COMMAND_NAME +\
#    1316     self.command_header +\
#    1317     args_command +\
#    1318     proto.END_COMMAND_PART
#    1320 answer = self.gateway_client.send_command(command)
# -> 1321 return_value = get_return_value(
#    1322     answer, self.gateway_client, self.target_id, self.name)
#    1324 for temp_arg in temp_args:
#    1325     temp_arg._detach()
#
# File /usr/local/lib/python3.9/dist-packages/pyspark/sql/utils.py:111, in capture_sql_exception.<locals>.deco(*a, **kw)
#     109 def deco(*a, **kw):
#     110     try:
# --> 111         return f(*a, **kw)
#     112     except py4j.protocol.Py4JJavaError as e:
#     113         converted = convert_exception(e.java_exception)
#
# File /usr/local/lib/python3.9/dist-packages/py4j/protocol.py:326, in get_return_value(answer, gateway_client, target_id, name)
#     324 value = OUTPUT_CONVERTER[type](answer[2:], gateway_client)
#     325 if answer[1] == REFERENCE_TYPE:
# --> 326     raise Py4JJavaError(
#     327         "An error occurred while calling {0}{1}{2}.\n".
#     328         format(target_id, ".", name), value)
#     329 else:
#     330     raise Py4JError(
#     331         "An error occurred while calling {0}{1}{2}. Trace:\n{3}\n".
#     332         format(target_id, ".", name, value))
#
# Py4JJavaError: An error occurred while calling o1421.collectToPython.
# : org.apache.spark.SparkException: Job aborted due to stage failure: ShuffleMapStage 275 (collect at /tmp/ipykernel_7010/3383850185.py:1) has failed the maximum allowable number of times: 4. Most recent failure reason:
# org.apache.spark.shuffle.MetadataFetchFailedException: Missing an output location for shuffle 10 partition 44
# 	at org.apache.spark.MapOutputTracker$.validateStatus(MapOutputTracker.scala:1619)
# 	at org.apache.spark.MapOutputTracker$.$anonfun$convertMapStatuses$10(MapOutputTracker.scala:1566)
# 	at org.apache.spark.MapOutputTracker$.$anonfun$convertMapStatuses$10$adapted(MapOutputTracker.scala:1565)
# 	at scala.collection.Iterator.foreach(Iterator.scala:943)
# 	at scala.collection.Iterator.foreach$(Iterator.scala:943)
# 	at scala.collection.AbstractIterator.foreach(Iterator.scala:1431)
# 	at org.apache.spark.MapOutputTracker$.convertMapStatuses(MapOutputTracker.scala:1565)
# 	at org.apache.spark.MapOutputTrackerWorker.getMapSizesByExecutorIdImpl(MapOutputTracker.scala:1230)
# 	at org.apache.spark.MapOutputTrackerWorker.getMapSizesByExecutorId(MapOutputTracker.scala:1192)
# 	at org.apache.spark.shuffle.sort.SortShuffleManager.getReader(SortShuffleManager.scala:140)
# 	at org.apache.spark.shuffle.ShuffleManager.getReader(ShuffleManager.scala:63)
# 	at org.apache.spark.shuffle.ShuffleManager.getReader$(ShuffleManager.scala:57)
# 	at org.apache.spark.shuffle.sort.SortShuffleManager.getReader(SortShuffleManager.scala:73)
# 	at org.apache.spark.sql.execution.ShuffledRowRDD.compute(ShuffledRowRDD.scala:208)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:373)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:337)
# 	at org.apache.spark.rdd.MapPartitionsRDD.compute(MapPartitionsRDD.scala:52)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:373)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:337)
# 	at org.apache.spark.rdd.ZippedPartitionsRDD2.compute(ZippedPartitionsRDD.scala:89)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:373)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:337)
# 	at org.apache.spark.rdd.MapPartitionsRDD.compute(MapPartitionsRDD.scala:52)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:373)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:337)
# 	at org.apache.spark.rdd.MapPartitionsRDD.compute(MapPartitionsRDD.scala:52)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:373)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:337)
# 	at org.apache.spark.shuffle.ShuffleWriteProcessor.write(ShuffleWriteProcessor.scala:59)
# 	at org.apache.spark.scheduler.ShuffleMapTask.runTask(ShuffleMapTask.scala:99)
# 	at org.apache.spark.scheduler.ShuffleMapTask.runTask(ShuffleMapTask.scala:52)
# 	at org.apache.spark.scheduler.Task.run(Task.scala:131)
# 	at org.apache.spark.executor.Executor$TaskRunner.$anonfun$run$3(Executor.scala:506)
# 	at org.apache.spark.util.Utils$.tryWithSafeFinally(Utils.scala:1462)
# 	at org.apache.spark.executor.Executor$TaskRunner.run(Executor.scala:509)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(Unknown Source)
# 	at java.base/java.lang.Thread.run(Unknown Source)
#
# 	at org.apache.spark.scheduler.DAGScheduler.failJobAndIndependentStages(DAGScheduler.scala:2454)
# 	at org.apache.spark.scheduler.DAGScheduler.$anonfun$abortStage$2(DAGScheduler.scala:2403)
# 	at org.apache.spark.scheduler.DAGScheduler.$anonfun$abortStage$2$adapted(DAGScheduler.scala:2402)
# 	at scala.collection.mutable.ResizableArray.foreach(ResizableArray.scala:62)
# 	at scala.collection.mutable.ResizableArray.foreach$(ResizableArray.scala:55)
# 	at scala.collection.mutable.ArrayBuffer.foreach(ArrayBuffer.scala:49)
# 	at org.apache.spark.scheduler.DAGScheduler.abortStage(DAGScheduler.scala:2402)
# 	at org.apache.spark.scheduler.DAGScheduler.handleTaskCompletion(DAGScheduler.scala:1843)
# 	at org.apache.spark.scheduler.DAGSchedulerEventProcessLoop.doOnReceive(DAGScheduler.scala:2639)
# 	at org.apache.spark.scheduler.DAGSchedulerEventProcessLoop.onReceive(DAGScheduler.scala:2584)
# 	at org.apache.spark.scheduler.DAGSchedulerEventProcessLoop.onReceive(DAGScheduler.scala:2573)
# 	at org.apache.spark.util.EventLoop$$anon$1.run(EventLoop.scala:49)

# %%
df = measurement2.filter(col('concept_id').isin(codes))
df.show()
# Out:
# 22/07/13 15:02:13 WARN DAGScheduler: Broadcasting large task binary with size 4.0 MiB
# 22/07/13 15:02:15 WARN ExecutorPodsSnapshotsStoreImpl: Exception when notifying snapshot subscriber.
# io.fabric8.kubernetes.client.KubernetesClientException: Failure executing: POST at: https://kubernetes.default.svc.cluster.local/api/v1/namespaces/ke-decile-lab/pods. Message: Forbidden!Configured service account doesn't have access. Service account may have been revoked. pods "test-0358db81f7fdb3a2-exec-459" is forbidden: exceeded quota: ke-decile-lab-quota, requested: requests.cpu=2, used: requests.cpu=32, limited: requests.cpu=32.
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.requestFailure(OperationSupport.java:639)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.assertResponseCode(OperationSupport.java:576)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleResponse(OperationSupport.java:543)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleResponse(OperationSupport.java:504)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleCreate(OperationSupport.java:292)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.handleCreate(BaseOperation.java:893)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.create(BaseOperation.java:372)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.create(BaseOperation.java:86)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$requestNewExecutors$1(ExecutorPodsAllocator.scala:400)
# 	at scala.collection.immutable.Range.foreach$mVc$sp(Range.scala:158)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.requestNewExecutors(ExecutorPodsAllocator.scala:382)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$onNewSnapshots$36(ExecutorPodsAllocator.scala:346)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$onNewSnapshots$36$adapted(ExecutorPodsAllocator.scala:339)
# 	at scala.collection.mutable.ResizableArray.foreach(ResizableArray.scala:62)
# 	at scala.collection.mutable.ResizableArray.foreach$(ResizableArray.scala:55)
# 	at scala.collection.mutable.ArrayBuffer.foreach(ArrayBuffer.scala:49)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.onNewSnapshots(ExecutorPodsAllocator.scala:339)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3$adapted(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber.org$apache$spark$scheduler$cluster$k8s$ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber$$processSnapshotsInternal(ExecutorPodsSnapshotsStoreImpl.scala:138)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber.processSnapshots(ExecutorPodsSnapshotsStoreImpl.scala:126)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl.$anonfun$addSubscriber$1(ExecutorPodsSnapshotsStoreImpl.scala:81)
# 	at java.base/java.util.concurrent.Executors$RunnableAdapter.call(Unknown Source)
# 	at java.base/java.util.concurrent.FutureTask.runAndReset(Unknown Source)
# 	at java.base/java.util.concurrent.ScheduledThreadPoolExecutor$ScheduledFutureTask.run(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(Unknown Source)
# 	at java.base/java.lang.Thread.run(Unknown Source)
# 22/07/13 15:02:16 WARN ExecutorPodsSnapshotsStoreImpl: Exception when notifying snapshot subscriber.
# io.fabric8.kubernetes.client.KubernetesClientException: Failure executing: POST at: https://kubernetes.default.svc.cluster.local/api/v1/namespaces/ke-decile-lab/pods. Message: Forbidden!Configured service account doesn't have access. Service account may have been revoked. pods "test-0358db81f7fdb3a2-exec-460" is forbidden: exceeded quota: ke-decile-lab-quota, requested: requests.cpu=2, used: requests.cpu=32, limited: requests.cpu=32.
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.requestFailure(OperationSupport.java:639)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.assertResponseCode(OperationSupport.java:576)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleResponse(OperationSupport.java:543)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleResponse(OperationSupport.java:504)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleCreate(OperationSupport.java:292)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.handleCreate(BaseOperation.java:893)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.create(BaseOperation.java:372)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.create(BaseOperation.java:86)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$requestNewExecutors$1(ExecutorPodsAllocator.scala:400)
# 	at scala.collection.immutable.Range.foreach$mVc$sp(Range.scala:158)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.requestNewExecutors(ExecutorPodsAllocator.scala:382)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$onNewSnapshots$36(ExecutorPodsAllocator.scala:346)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$onNewSnapshots$36$adapted(ExecutorPodsAllocator.scala:339)
# 	at scala.collection.mutable.ResizableArray.foreach(ResizableArray.scala:62)
# 	at scala.collection.mutable.ResizableArray.foreach$(ResizableArray.scala:55)
# 	at scala.collection.mutable.ArrayBuffer.foreach(ArrayBuffer.scala:49)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.onNewSnapshots(ExecutorPodsAllocator.scala:339)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3$adapted(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber.org$apache$spark$scheduler$cluster$k8s$ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber$$processSnapshotsInternal(ExecutorPodsSnapshotsStoreImpl.scala:138)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber.processSnapshots(ExecutorPodsSnapshotsStoreImpl.scala:126)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl.$anonfun$addSubscriber$1(ExecutorPodsSnapshotsStoreImpl.scala:81)
# 	at java.base/java.util.concurrent.Executors$RunnableAdapter.call(Unknown Source)
# 	at java.base/java.util.concurrent.FutureTask.runAndReset(Unknown Source)
# 	at java.base/java.util.concurrent.ScheduledThreadPoolExecutor$ScheduledFutureTask.run(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(Unknown Source)
# 	at java.base/java.lang.Thread.run(Unknown Source)
# 22/07/13 15:02:17 WARN ExecutorPodsSnapshotsStoreImpl: Exception when notifying snapshot subscriber.
# io.fabric8.kubernetes.client.KubernetesClientException: Failure executing: POST at: https://kubernetes.default.svc.cluster.local/api/v1/namespaces/ke-decile-lab/pods. Message: Forbidden!Configured service account doesn't have access. Service account may have been revoked. pods "test-0358db81f7fdb3a2-exec-461" is forbidden: exceeded quota: ke-decile-lab-quota, requested: requests.cpu=2, used: requests.cpu=32, limited: requests.cpu=32.
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.requestFailure(OperationSupport.java:639)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.assertResponseCode(OperationSupport.java:576)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleResponse(OperationSupport.java:543)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleResponse(OperationSupport.java:504)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleCreate(OperationSupport.java:292)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.handleCreate(BaseOperation.java:893)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.create(BaseOperation.java:372)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.create(BaseOperation.java:86)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$requestNewExecutors$1(ExecutorPodsAllocator.scala:400)
# 	at scala.collection.immutable.Range.foreach$mVc$sp(Range.scala:158)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.requestNewExecutors(ExecutorPodsAllocator.scala:382)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$onNewSnapshots$36(ExecutorPodsAllocator.scala:346)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$onNewSnapshots$36$adapted(ExecutorPodsAllocator.scala:339)
# 	at scala.collection.mutable.ResizableArray.foreach(ResizableArray.scala:62)
# 	at scala.collection.mutable.ResizableArray.foreach$(ResizableArray.scala:55)
# 	at scala.collection.mutable.ArrayBuffer.foreach(ArrayBuffer.scala:49)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.onNewSnapshots(ExecutorPodsAllocator.scala:339)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3$adapted(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber.org$apache$spark$scheduler$cluster$k8s$ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber$$processSnapshotsInternal(ExecutorPodsSnapshotsStoreImpl.scala:138)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber.processSnapshots(ExecutorPodsSnapshotsStoreImpl.scala:126)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl.$anonfun$addSubscriber$1(ExecutorPodsSnapshotsStoreImpl.scala:81)
# 	at java.base/java.util.concurrent.Executors$RunnableAdapter.call(Unknown Source)
# 	at java.base/java.util.concurrent.FutureTask.runAndReset(Unknown Source)
# 	at java.base/java.util.concurrent.ScheduledThreadPoolExecutor$ScheduledFutureTask.run(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(Unknown Source)
# 	at java.base/java.lang.Thread.run(Unknown Source)
# 22/07/13 15:02:18 WARN ExecutorPodsSnapshotsStoreImpl: Exception when notifying snapshot subscriber.
# io.fabric8.kubernetes.client.KubernetesClientException: Failure executing: POST at: https://kubernetes.default.svc.cluster.local/api/v1/namespaces/ke-decile-lab/pods. Message: Forbidden!Configured service account doesn't have access. Service account may have been revoked. pods "test-0358db81f7fdb3a2-exec-462" is forbidden: exceeded quota: ke-decile-lab-quota, requested: requests.cpu=2, used: requests.cpu=32, limited: requests.cpu=32.
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.requestFailure(OperationSupport.java:639)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.assertResponseCode(OperationSupport.java:576)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleResponse(OperationSupport.java:543)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleResponse(OperationSupport.java:504)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleCreate(OperationSupport.java:292)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.handleCreate(BaseOperation.java:893)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.create(BaseOperation.java:372)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.create(BaseOperation.java:86)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$requestNewExecutors$1(ExecutorPodsAllocator.scala:400)
# 	at scala.collection.immutable.Range.foreach$mVc$sp(Range.scala:158)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.requestNewExecutors(ExecutorPodsAllocator.scala:382)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$onNewSnapshots$36(ExecutorPodsAllocator.scala:346)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$onNewSnapshots$36$adapted(ExecutorPodsAllocator.scala:339)
# 	at scala.collection.mutable.ResizableArray.foreach(ResizableArray.scala:62)
# 	at scala.collection.mutable.ResizableArray.foreach$(ResizableArray.scala:55)
# 	at scala.collection.mutable.ArrayBuffer.foreach(ArrayBuffer.scala:49)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.onNewSnapshots(ExecutorPodsAllocator.scala:339)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3$adapted(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber.org$apache$spark$scheduler$cluster$k8s$ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber$$processSnapshotsInternal(ExecutorPodsSnapshotsStoreImpl.scala:138)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber.processSnapshots(ExecutorPodsSnapshotsStoreImpl.scala:126)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl.$anonfun$addSubscriber$1(ExecutorPodsSnapshotsStoreImpl.scala:81)
# 	at java.base/java.util.concurrent.Executors$RunnableAdapter.call(Unknown Source)
# 	at java.base/java.util.concurrent.FutureTask.runAndReset(Unknown Source)
# 	at java.base/java.util.concurrent.ScheduledThreadPoolExecutor$ScheduledFutureTask.run(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(Unknown Source)
# 	at java.base/java.lang.Thread.run(Unknown Source)
# 22/07/13 15:02:19 WARN ExecutorPodsSnapshotsStoreImpl: Exception when notifying snapshot subscriber.
# io.fabric8.kubernetes.client.KubernetesClientException: Failure executing: POST at: https://kubernetes.default.svc.cluster.local/api/v1/namespaces/ke-decile-lab/pods. Message: Forbidden!Configured service account doesn't have access. Service account may have been revoked. pods "test-0358db81f7fdb3a2-exec-463" is forbidden: exceeded quota: ke-decile-lab-quota, requested: requests.cpu=2, used: requests.cpu=32, limited: requests.cpu=32.
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.requestFailure(OperationSupport.java:639)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.assertResponseCode(OperationSupport.java:576)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleResponse(OperationSupport.java:543)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleResponse(OperationSupport.java:504)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleCreate(OperationSupport.java:292)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.handleCreate(BaseOperation.java:893)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.create(BaseOperation.java:372)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.create(BaseOperation.java:86)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$requestNewExecutors$1(ExecutorPodsAllocator.scala:400)
# 	at scala.collection.immutable.Range.foreach$mVc$sp(Range.scala:158)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.requestNewExecutors(ExecutorPodsAllocator.scala:382)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$onNewSnapshots$36(ExecutorPodsAllocator.scala:346)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$onNewSnapshots$36$adapted(ExecutorPodsAllocator.scala:339)
# 	at scala.collection.mutable.ResizableArray.foreach(ResizableArray.scala:62)
# 	at scala.collection.mutable.ResizableArray.foreach$(ResizableArray.scala:55)
# 	at scala.collection.mutable.ArrayBuffer.foreach(ArrayBuffer.scala:49)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.onNewSnapshots(ExecutorPodsAllocator.scala:339)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3$adapted(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber.org$apache$spark$scheduler$cluster$k8s$ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber$$processSnapshotsInternal(ExecutorPodsSnapshotsStoreImpl.scala:138)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber.processSnapshots(ExecutorPodsSnapshotsStoreImpl.scala:126)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl.$anonfun$addSubscriber$1(ExecutorPodsSnapshotsStoreImpl.scala:81)
# 	at java.base/java.util.concurrent.Executors$RunnableAdapter.call(Unknown Source)
# 	at java.base/java.util.concurrent.FutureTask.runAndReset(Unknown Source)
# 	at java.base/java.util.concurrent.ScheduledThreadPoolExecutor$ScheduledFutureTask.run(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(Unknown Source)
# 	at java.base/java.lang.Thread.run(Unknown Source)
# 22/07/13 15:02:20 WARN ExecutorPodsSnapshotsStoreImpl: Exception when notifying snapshot subscriber.
# io.fabric8.kubernetes.client.KubernetesClientException: Failure executing: POST at: https://kubernetes.default.svc.cluster.local/api/v1/namespaces/ke-decile-lab/pods. Message: Forbidden!Configured service account doesn't have access. Service account may have been revoked. pods "test-0358db81f7fdb3a2-exec-464" is forbidden: exceeded quota: ke-decile-lab-quota, requested: requests.cpu=2, used: requests.cpu=32, limited: requests.cpu=32.
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.requestFailure(OperationSupport.java:639)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.assertResponseCode(OperationSupport.java:576)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleResponse(OperationSupport.java:543)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleResponse(OperationSupport.java:504)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleCreate(OperationSupport.java:292)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.handleCreate(BaseOperation.java:893)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.create(BaseOperation.java:372)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.create(BaseOperation.java:86)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$requestNewExecutors$1(ExecutorPodsAllocator.scala:400)
# 	at scala.collection.immutable.Range.foreach$mVc$sp(Range.scala:158)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.requestNewExecutors(ExecutorPodsAllocator.scala:382)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$onNewSnapshots$36(ExecutorPodsAllocator.scala:346)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$onNewSnapshots$36$adapted(ExecutorPodsAllocator.scala:339)
# 	at scala.collection.mutable.ResizableArray.foreach(ResizableArray.scala:62)
# 	at scala.collection.mutable.ResizableArray.foreach$(ResizableArray.scala:55)
# 	at scala.collection.mutable.ArrayBuffer.foreach(ArrayBuffer.scala:49)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.onNewSnapshots(ExecutorPodsAllocator.scala:339)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3$adapted(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber.org$apache$spark$scheduler$cluster$k8s$ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber$$processSnapshotsInternal(ExecutorPodsSnapshotsStoreImpl.scala:138)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber.processSnapshots(ExecutorPodsSnapshotsStoreImpl.scala:126)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl.$anonfun$addSubscriber$1(ExecutorPodsSnapshotsStoreImpl.scala:81)
# 	at java.base/java.util.concurrent.Executors$RunnableAdapter.call(Unknown Source)
# 	at java.base/java.util.concurrent.FutureTask.runAndReset(Unknown Source)
# 	at java.base/java.util.concurrent.ScheduledThreadPoolExecutor$ScheduledFutureTask.run(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(Unknown Source)
# 	at java.base/java.lang.Thread.run(Unknown Source)
# 22/07/13 15:02:21 WARN ExecutorPodsSnapshotsStoreImpl: Exception when notifying snapshot subscriber.
# io.fabric8.kubernetes.client.KubernetesClientException: Failure executing: POST at: https://kubernetes.default.svc.cluster.local/api/v1/namespaces/ke-decile-lab/pods. Message: Forbidden!Configured service account doesn't have access. Service account may have been revoked. pods "test-0358db81f7fdb3a2-exec-465" is forbidden: exceeded quota: ke-decile-lab-quota, requested: requests.cpu=2, used: requests.cpu=32, limited: requests.cpu=32.
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.requestFailure(OperationSupport.java:639)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.assertResponseCode(OperationSupport.java:576)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleResponse(OperationSupport.java:543)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleResponse(OperationSupport.java:504)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleCreate(OperationSupport.java:292)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.handleCreate(BaseOperation.java:893)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.create(BaseOperation.java:372)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.create(BaseOperation.java:86)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$requestNewExecutors$1(ExecutorPodsAllocator.scala:400)
# 	at scala.collection.immutable.Range.foreach$mVc$sp(Range.scala:158)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.requestNewExecutors(ExecutorPodsAllocator.scala:382)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$onNewSnapshots$36(ExecutorPodsAllocator.scala:346)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$onNewSnapshots$36$adapted(ExecutorPodsAllocator.scala:339)
# 	at scala.collection.mutable.ResizableArray.foreach(ResizableArray.scala:62)
# 	at scala.collection.mutable.ResizableArray.foreach$(ResizableArray.scala:55)
# 	at scala.collection.mutable.ArrayBuffer.foreach(ArrayBuffer.scala:49)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.onNewSnapshots(ExecutorPodsAllocator.scala:339)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3$adapted(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber.org$apache$spark$scheduler$cluster$k8s$ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber$$processSnapshotsInternal(ExecutorPodsSnapshotsStoreImpl.scala:138)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber.processSnapshots(ExecutorPodsSnapshotsStoreImpl.scala:126)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl.$anonfun$addSubscriber$1(ExecutorPodsSnapshotsStoreImpl.scala:81)
# 	at java.base/java.util.concurrent.Executors$RunnableAdapter.call(Unknown Source)
# 	at java.base/java.util.concurrent.FutureTask.runAndReset(Unknown Source)
# 	at java.base/java.util.concurrent.ScheduledThreadPoolExecutor$ScheduledFutureTask.run(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(Unknown Source)
# 	at java.base/java.lang.Thread.run(Unknown Source)
# 22/07/13 15:02:22 WARN ExecutorPodsSnapshotsStoreImpl: Exception when notifying snapshot subscriber.
# io.fabric8.kubernetes.client.KubernetesClientException: Failure executing: POST at: https://kubernetes.default.svc.cluster.local/api/v1/namespaces/ke-decile-lab/pods. Message: Forbidden!Configured service account doesn't have access. Service account may have been revoked. pods "test-0358db81f7fdb3a2-exec-466" is forbidden: exceeded quota: ke-decile-lab-quota, requested: requests.cpu=2, used: requests.cpu=32, limited: requests.cpu=32.
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.requestFailure(OperationSupport.java:639)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.assertResponseCode(OperationSupport.java:576)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleResponse(OperationSupport.java:543)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleResponse(OperationSupport.java:504)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleCreate(OperationSupport.java:292)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.handleCreate(BaseOperation.java:893)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.create(BaseOperation.java:372)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.create(BaseOperation.java:86)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$requestNewExecutors$1(ExecutorPodsAllocator.scala:400)
# 	at scala.collection.immutable.Range.foreach$mVc$sp(Range.scala:158)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.requestNewExecutors(ExecutorPodsAllocator.scala:382)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$onNewSnapshots$36(ExecutorPodsAllocator.scala:346)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$onNewSnapshots$36$adapted(ExecutorPodsAllocator.scala:339)
# 	at scala.collection.mutable.ResizableArray.foreach(ResizableArray.scala:62)
# 	at scala.collection.mutable.ResizableArray.foreach$(ResizableArray.scala:55)
# 	at scala.collection.mutable.ArrayBuffer.foreach(ArrayBuffer.scala:49)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.onNewSnapshots(ExecutorPodsAllocator.scala:339)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3$adapted(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber.org$apache$spark$scheduler$cluster$k8s$ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber$$processSnapshotsInternal(ExecutorPodsSnapshotsStoreImpl.scala:138)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber.processSnapshots(ExecutorPodsSnapshotsStoreImpl.scala:126)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl.$anonfun$addSubscriber$1(ExecutorPodsSnapshotsStoreImpl.scala:81)
# 	at java.base/java.util.concurrent.Executors$RunnableAdapter.call(Unknown Source)
# 	at java.base/java.util.concurrent.FutureTask.runAndReset(Unknown Source)
# 	at java.base/java.util.concurrent.ScheduledThreadPoolExecutor$ScheduledFutureTask.run(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(Unknown Source)
# 	at java.base/java.lang.Thread.run(Unknown Source)
# 22/07/13 15:02:23 WARN ExecutorPodsSnapshotsStoreImpl: Exception when notifying snapshot subscriber.
# io.fabric8.kubernetes.client.KubernetesClientException: Failure executing: POST at: https://kubernetes.default.svc.cluster.local/api/v1/namespaces/ke-decile-lab/pods. Message: Forbidden!Configured service account doesn't have access. Service account may have been revoked. pods "test-0358db81f7fdb3a2-exec-467" is forbidden: exceeded quota: ke-decile-lab-quota, requested: requests.cpu=2, used: requests.cpu=32, limited: requests.cpu=32.
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.requestFailure(OperationSupport.java:639)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.assertResponseCode(OperationSupport.java:576)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleResponse(OperationSupport.java:543)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleResponse(OperationSupport.java:504)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleCreate(OperationSupport.java:292)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.handleCreate(BaseOperation.java:893)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.create(BaseOperation.java:372)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.create(BaseOperation.java:86)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$requestNewExecutors$1(ExecutorPodsAllocator.scala:400)
# 	at scala.collection.immutable.Range.foreach$mVc$sp(Range.scala:158)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.requestNewExecutors(ExecutorPodsAllocator.scala:382)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$onNewSnapshots$36(ExecutorPodsAllocator.scala:346)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$onNewSnapshots$36$adapted(ExecutorPodsAllocator.scala:339)
# 	at scala.collection.mutable.ResizableArray.foreach(ResizableArray.scala:62)
# 	at scala.collection.mutable.ResizableArray.foreach$(ResizableArray.scala:55)
# 	at scala.collection.mutable.ArrayBuffer.foreach(ArrayBuffer.scala:49)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.onNewSnapshots(ExecutorPodsAllocator.scala:339)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3$adapted(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber.org$apache$spark$scheduler$cluster$k8s$ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber$$processSnapshotsInternal(ExecutorPodsSnapshotsStoreImpl.scala:138)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber.processSnapshots(ExecutorPodsSnapshotsStoreImpl.scala:126)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl.$anonfun$addSubscriber$1(ExecutorPodsSnapshotsStoreImpl.scala:81)
# 	at java.base/java.util.concurrent.Executors$RunnableAdapter.call(Unknown Source)
# 	at java.base/java.util.concurrent.FutureTask.runAndReset(Unknown Source)
# 	at java.base/java.util.concurrent.ScheduledThreadPoolExecutor$ScheduledFutureTask.run(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(Unknown Source)
# 	at java.base/java.lang.Thread.run(Unknown Source)
# 22/07/13 15:02:24 WARN ExecutorPodsSnapshotsStoreImpl: Exception when notifying snapshot subscriber.
# io.fabric8.kubernetes.client.KubernetesClientException: Failure executing: POST at: https://kubernetes.default.svc.cluster.local/api/v1/namespaces/ke-decile-lab/pods. Message: Forbidden!Configured service account doesn't have access. Service account may have been revoked. pods "test-0358db81f7fdb3a2-exec-468" is forbidden: exceeded quota: ke-decile-lab-quota, requested: requests.cpu=2, used: requests.cpu=32, limited: requests.cpu=32.
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.requestFailure(OperationSupport.java:639)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.assertResponseCode(OperationSupport.java:576)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleResponse(OperationSupport.java:543)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleResponse(OperationSupport.java:504)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleCreate(OperationSupport.java:292)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.handleCreate(BaseOperation.java:893)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.create(BaseOperation.java:372)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.create(BaseOperation.java:86)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$requestNewExecutors$1(ExecutorPodsAllocator.scala:400)
# 	at scala.collection.immutable.Range.foreach$mVc$sp(Range.scala:158)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.requestNewExecutors(ExecutorPodsAllocator.scala:382)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$onNewSnapshots$36(ExecutorPodsAllocator.scala:346)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$onNewSnapshots$36$adapted(ExecutorPodsAllocator.scala:339)
# 	at scala.collection.mutable.ResizableArray.foreach(ResizableArray.scala:62)
# 	at scala.collection.mutable.ResizableArray.foreach$(ResizableArray.scala:55)
# 	at scala.collection.mutable.ArrayBuffer.foreach(ArrayBuffer.scala:49)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.onNewSnapshots(ExecutorPodsAllocator.scala:339)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3$adapted(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber.org$apache$spark$scheduler$cluster$k8s$ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber$$processSnapshotsInternal(ExecutorPodsSnapshotsStoreImpl.scala:138)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber.processSnapshots(ExecutorPodsSnapshotsStoreImpl.scala:126)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl.$anonfun$addSubscriber$1(ExecutorPodsSnapshotsStoreImpl.scala:81)
# 	at java.base/java.util.concurrent.Executors$RunnableAdapter.call(Unknown Source)
# 	at java.base/java.util.concurrent.FutureTask.runAndReset(Unknown Source)
# 	at java.base/java.util.concurrent.ScheduledThreadPoolExecutor$ScheduledFutureTask.run(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(Unknown Source)
# 	at java.base/java.lang.Thread.run(Unknown Source)
# 22/07/13 15:02:25 WARN ExecutorPodsSnapshotsStoreImpl: Exception when notifying snapshot subscriber.
# io.fabric8.kubernetes.client.KubernetesClientException: Failure executing: POST at: https://kubernetes.default.svc.cluster.local/api/v1/namespaces/ke-decile-lab/pods. Message: Forbidden!Configured service account doesn't have access. Service account may have been revoked. pods "test-0358db81f7fdb3a2-exec-469" is forbidden: exceeded quota: ke-decile-lab-quota, requested: requests.cpu=2, used: requests.cpu=32, limited: requests.cpu=32.
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.requestFailure(OperationSupport.java:639)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.assertResponseCode(OperationSupport.java:576)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleResponse(OperationSupport.java:543)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleResponse(OperationSupport.java:504)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleCreate(OperationSupport.java:292)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.handleCreate(BaseOperation.java:893)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.create(BaseOperation.java:372)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.create(BaseOperation.java:86)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$requestNewExecutors$1(ExecutorPodsAllocator.scala:400)
# 	at scala.collection.immutable.Range.foreach$mVc$sp(Range.scala:158)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.requestNewExecutors(ExecutorPodsAllocator.scala:382)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$onNewSnapshots$36(ExecutorPodsAllocator.scala:346)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$onNewSnapshots$36$adapted(ExecutorPodsAllocator.scala:339)
# 	at scala.collection.mutable.ResizableArray.foreach(ResizableArray.scala:62)
# 	at scala.collection.mutable.ResizableArray.foreach$(ResizableArray.scala:55)
# 	at scala.collection.mutable.ArrayBuffer.foreach(ArrayBuffer.scala:49)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.onNewSnapshots(ExecutorPodsAllocator.scala:339)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3$adapted(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber.org$apache$spark$scheduler$cluster$k8s$ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber$$processSnapshotsInternal(ExecutorPodsSnapshotsStoreImpl.scala:138)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber.processSnapshots(ExecutorPodsSnapshotsStoreImpl.scala:126)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl.$anonfun$addSubscriber$1(ExecutorPodsSnapshotsStoreImpl.scala:81)
# 	at java.base/java.util.concurrent.Executors$RunnableAdapter.call(Unknown Source)
# 	at java.base/java.util.concurrent.FutureTask.runAndReset(Unknown Source)
# 	at java.base/java.util.concurrent.ScheduledThreadPoolExecutor$ScheduledFutureTask.run(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(Unknown Source)
# 	at java.base/java.lang.Thread.run(Unknown Source)
# 22/07/13 15:02:26 WARN ExecutorPodsSnapshotsStoreImpl: Exception when notifying snapshot subscriber.
# io.fabric8.kubernetes.client.KubernetesClientException: Failure executing: POST at: https://kubernetes.default.svc.cluster.local/api/v1/namespaces/ke-decile-lab/pods. Message: Forbidden!Configured service account doesn't have access. Service account may have been revoked. pods "test-0358db81f7fdb3a2-exec-470" is forbidden: exceeded quota: ke-decile-lab-quota, requested: requests.cpu=2, used: requests.cpu=32, limited: requests.cpu=32.
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.requestFailure(OperationSupport.java:639)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.assertResponseCode(OperationSupport.java:576)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleResponse(OperationSupport.java:543)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleResponse(OperationSupport.java:504)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleCreate(OperationSupport.java:292)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.handleCreate(BaseOperation.java:893)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.create(BaseOperation.java:372)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.create(BaseOperation.java:86)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$requestNewExecutors$1(ExecutorPodsAllocator.scala:400)
# 	at scala.collection.immutable.Range.foreach$mVc$sp(Range.scala:158)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.requestNewExecutors(ExecutorPodsAllocator.scala:382)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$onNewSnapshots$36(ExecutorPodsAllocator.scala:346)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$onNewSnapshots$36$adapted(ExecutorPodsAllocator.scala:339)
# 	at scala.collection.mutable.ResizableArray.foreach(ResizableArray.scala:62)
# 	at scala.collection.mutable.ResizableArray.foreach$(ResizableArray.scala:55)
# 	at scala.collection.mutable.ArrayBuffer.foreach(ArrayBuffer.scala:49)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.onNewSnapshots(ExecutorPodsAllocator.scala:339)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3$adapted(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber.org$apache$spark$scheduler$cluster$k8s$ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber$$processSnapshotsInternal(ExecutorPodsSnapshotsStoreImpl.scala:138)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber.processSnapshots(ExecutorPodsSnapshotsStoreImpl.scala:126)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl.$anonfun$addSubscriber$1(ExecutorPodsSnapshotsStoreImpl.scala:81)
# 	at java.base/java.util.concurrent.Executors$RunnableAdapter.call(Unknown Source)
# 	at java.base/java.util.concurrent.FutureTask.runAndReset(Unknown Source)
# 	at java.base/java.util.concurrent.ScheduledThreadPoolExecutor$ScheduledFutureTask.run(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(Unknown Source)
# 	at java.base/java.lang.Thread.run(Unknown Source)
# 22/07/13 15:02:27 WARN ExecutorPodsSnapshotsStoreImpl: Exception when notifying snapshot subscriber.
# io.fabric8.kubernetes.client.KubernetesClientException: Failure executing: POST at: https://kubernetes.default.svc.cluster.local/api/v1/namespaces/ke-decile-lab/pods. Message: Forbidden!Configured service account doesn't have access. Service account may have been revoked. pods "test-0358db81f7fdb3a2-exec-471" is forbidden: exceeded quota: ke-decile-lab-quota, requested: requests.cpu=2, used: requests.cpu=32, limited: requests.cpu=32.
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.requestFailure(OperationSupport.java:639)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.assertResponseCode(OperationSupport.java:576)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleResponse(OperationSupport.java:543)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleResponse(OperationSupport.java:504)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleCreate(OperationSupport.java:292)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.handleCreate(BaseOperation.java:893)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.create(BaseOperation.java:372)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.create(BaseOperation.java:86)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$requestNewExecutors$1(ExecutorPodsAllocator.scala:400)
# 	at scala.collection.immutable.Range.foreach$mVc$sp(Range.scala:158)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.requestNewExecutors(ExecutorPodsAllocator.scala:382)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$onNewSnapshots$36(ExecutorPodsAllocator.scala:346)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$onNewSnapshots$36$adapted(ExecutorPodsAllocator.scala:339)
# 	at scala.collection.mutable.ResizableArray.foreach(ResizableArray.scala:62)
# 	at scala.collection.mutable.ResizableArray.foreach$(ResizableArray.scala:55)
# 	at scala.collection.mutable.ArrayBuffer.foreach(ArrayBuffer.scala:49)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.onNewSnapshots(ExecutorPodsAllocator.scala:339)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3$adapted(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber.org$apache$spark$scheduler$cluster$k8s$ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber$$processSnapshotsInternal(ExecutorPodsSnapshotsStoreImpl.scala:138)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber.processSnapshots(ExecutorPodsSnapshotsStoreImpl.scala:126)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl.$anonfun$addSubscriber$1(ExecutorPodsSnapshotsStoreImpl.scala:81)
# 	at java.base/java.util.concurrent.Executors$RunnableAdapter.call(Unknown Source)
# 	at java.base/java.util.concurrent.FutureTask.runAndReset(Unknown Source)
# 	at java.base/java.util.concurrent.ScheduledThreadPoolExecutor$ScheduledFutureTask.run(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(Unknown Source)
# 	at java.base/java.lang.Thread.run(Unknown Source)
# 22/07/13 15:02:28 WARN ExecutorPodsSnapshotsStoreImpl: Exception when notifying snapshot subscriber.
# io.fabric8.kubernetes.client.KubernetesClientException: Failure executing: POST at: https://kubernetes.default.svc.cluster.local/api/v1/namespaces/ke-decile-lab/pods. Message: Forbidden!Configured service account doesn't have access. Service account may have been revoked. pods "test-0358db81f7fdb3a2-exec-472" is forbidden: exceeded quota: ke-decile-lab-quota, requested: requests.cpu=2, used: requests.cpu=32, limited: requests.cpu=32.
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.requestFailure(OperationSupport.java:639)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.assertResponseCode(OperationSupport.java:576)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleResponse(OperationSupport.java:543)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleResponse(OperationSupport.java:504)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleCreate(OperationSupport.java:292)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.handleCreate(BaseOperation.java:893)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.create(BaseOperation.java:372)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.create(BaseOperation.java:86)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$requestNewExecutors$1(ExecutorPodsAllocator.scala:400)
# 	at scala.collection.immutable.Range.foreach$mVc$sp(Range.scala:158)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.requestNewExecutors(ExecutorPodsAllocator.scala:382)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$onNewSnapshots$36(ExecutorPodsAllocator.scala:346)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$onNewSnapshots$36$adapted(ExecutorPodsAllocator.scala:339)
# 	at scala.collection.mutable.ResizableArray.foreach(ResizableArray.scala:62)
# 	at scala.collection.mutable.ResizableArray.foreach$(ResizableArray.scala:55)
# 	at scala.collection.mutable.ArrayBuffer.foreach(ArrayBuffer.scala:49)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.onNewSnapshots(ExecutorPodsAllocator.scala:339)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3$adapted(ExecutorPodsAllocator.scala:117)
# ...
# 	at scala.collection.mutable.ArrayBuffer.foreach(ArrayBuffer.scala:49)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.onNewSnapshots(ExecutorPodsAllocator.scala:339)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3$adapted(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber.org$apache$spark$scheduler$cluster$k8s$ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber$$processSnapshotsInternal(ExecutorPodsSnapshotsStoreImpl.scala:138)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber.processSnapshots(ExecutorPodsSnapshotsStoreImpl.scala:126)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl.$anonfun$addSubscriber$1(ExecutorPodsSnapshotsStoreImpl.scala:81)
# 	at java.base/java.util.concurrent.Executors$RunnableAdapter.call(Unknown Source)
# 	at java.base/java.util.concurrent.FutureTask.runAndReset(Unknown Source)
# 	at java.base/java.util.concurrent.ScheduledThreadPoolExecutor$ScheduledFutureTask.run(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(Unknown Source)
# 	at java.base/java.lang.Thread.run(Unknown Source)
# 22/07/13 15:02:39 WARN DAGScheduler: Broadcasting large task binary with size 1588.1 KiB
# [Stage 266:==========(1202 + -2) / 1200][Stage 280:>                (0 + 1) / 1]
# +---------+--------------+-----------+----------------------+----------------+--------------------+-------------------+----------------+---------------------------+-------------------+---------------+---------------+-------------------+---------------+---------+----------+-----------+-------------------+---------------+------------------------+----------------------------+-----------------------------+-----------------+------------------+----------+----------------+-----------+-------------+--------------------+----------------+------------+----------------+--------------+--------------+
# |person_id|measurement_id|specimen_id|measurement_concept_id|measurement_date|measurement_datetime|     order_datetime|measurement_time|measurement_type_concept_id|operator_concept_id|value_as_number|value_as_string|value_as_concept_id|unit_concept_id|range_low|range_high|provider_id|visit_occurrence_id|visit_detail_id|measurement_source_value|measurement_source_value_alt|measurement_source_concept_id|unit_source_value|value_source_value|concept_id|    concept_name|  domain_id|vocabulary_id|    concept_class_id|standard_concept|concept_code|valid_start_date|valid_end_date|invalid_reason|
# +---------+--------------+-----------+----------------------+----------------+--------------------+-------------------+----------------+---------------------------+-------------------+---------------+---------------+-------------------+---------------+---------+----------+-----------+-------------------+---------------+------------------------+----------------------------+-----------------------------+-----------------+------------------+----------+----------------+-----------+-------------+--------------------+----------------+------------+----------------+--------------+--------------+
# | 34376443|     216876183|   39813451|               3024171|            null| 2016-02-05 15:15:00|2016-02-05 14:05:00|            null|                   44818702|               null|           30.0|           null|               null|           null|     null|      null|     421394|           46043349|           null|               Resp Rate|                   RESP RATE|                         6098|      {beats}/min|                30|   3024171|Respiratory rate|Measurement|        LOINC|Clinical Observation|               S|      9279-1|      1996-09-06|    2099-12-31|          null|
# | 11039044|     554779408|   98993582|               3024171|            null| 2020-07-02 04:46:00|2020-07-01 23:00:00|            null|                   44818702|               null|           20.0|           null|               null|           null|     null|      null|    1719271|          206319389|           null|               Resp Rate|                   RESP RATE|                        16024|                 |                20|   3024171|Respiratory rate|Measurement|        LOINC|Clinical Observation|               S|      9279-1|      1996-09-06|    2099-12-31|          null|
# | 34376443|     217484629|   39956021|               3024171|            null| 2016-02-11 11:09:00|2016-02-11 10:40:00|            null|                   44818702|               null|           32.0|           null|               null|           null|     null|      null|     471233|           46043349|           null|               Resp Rate|                   RESP RATE|                         6098|      {beats}/min|                32|   3024171|Respiratory rate|Measurement|        LOINC|Clinical Observation|               S|      9279-1|      1996-09-06|    2099-12-31|          null|
# | 34109648|     156747921|   29657346|               3024171|            null| 2015-01-29 15:01:00|2015-01-29 11:00:00|            null|                   44818702|               null|           12.0|           null|               null|           null|     null|      null|     231383|           29117034|           null|               Resp Rate|                   RESP RATE|                         6098|      {beats}/min|                12|   3024171|Respiratory rate|Measurement|        LOINC|Clinical Observation|               S|      9279-1|      1996-09-06|    2099-12-31|          null|
# | 14001514|     168388202|   31711196|               3024171|            null| 2015-04-12 01:12:00|2015-04-12 00:24:00|            null|                   44818702|               null|           28.0|           null|               null|           null|     null|      null|     244781|           33030879|           null|               Resp Rate|                   RESP RATE|                         6098|      {beats}/min|                28|   3024171|Respiratory rate|Measurement|        LOINC|Clinical Observation|               S|      9279-1|      1996-09-06|    2099-12-31|          null|
# | 14001514|     167229020|   31496101|               3024171|            null| 2015-04-04 13:05:00|2015-04-04 09:24:00|            null|                   44818702|               null|           28.0|           null|               null|           null|     null|      null|     244781|           33030879|           null|               Resp Rate|                   RESP RATE|                         6098|      {beats}/min|                28|   3024171|Respiratory rate|Measurement|        LOINC|Clinical Observation|               S|      9279-1|      1996-09-06|    2099-12-31|          null|
# | 43633707|     171656590|   32257495|               3024171|            null| 2015-05-01 12:30:00|2015-05-01 09:00:00|            null|                   44818702|               null|           20.0|           null|               null|           null|     null|      null|     227143|           34187564|           null|               Resp Rate|                   RESP RATE|                         6098|      {beats}/min|                20|   3024171|Respiratory rate|Measurement|        LOINC|Clinical Observation|               S|      9279-1|      1996-09-06|    2099-12-31|          null|
# | 34376443|     219018916|   40195676|               3024171|            null| 2016-02-21 04:30:00|2016-02-21 01:00:00|            null|                   44818702|               null|           32.0|           null|               null|           null|     null|      null|     421394|           46043349|           null|               Resp Rate|                   RESP RATE|                         6098|      {beats}/min|                32|   3024171|Respiratory rate|Measurement|        LOINC|Clinical Observation|               S|      9279-1|      1996-09-06|    2099-12-31|          null|
# | 34376443|     215749063|   39580117|               3024171|            null| 2016-01-28 12:51:00|2016-01-28 04:32:00|            null|                   44818702|               null|           22.0|           null|               null|           null|     null|      null|     455615|           46043349|           null|               Resp Rate|                   RESP RATE|                         6098|      {beats}/min|                22|   3024171|Respiratory rate|Measurement|        LOINC|Clinical Observation|               S|      9279-1|      1996-09-06|    2099-12-31|          null|
# | 42639534|     600212280|  112593218|               3024171|            null| 2021-01-06 06:28:00|2021-01-06 04:46:00|            null|                   44818702|               null|           18.0|           null|               null|           null|     null|      null|    2044661|          225693258|           null|               Resp Rate|                   RESP RATE|                        16024|                 |                18|   3024171|Respiratory rate|Measurement|        LOINC|Clinical Observation|               S|      9279-1|      1996-09-06|    2099-12-31|          null|
# | 12969863|     175290948|   32900383|               3024171|            null| 2015-05-23 13:58:00|2015-05-23 12:12:00|            null|                   44818702|               null|           30.0|           null|               null|           null|     null|      null|     244781|           34801944|           null|               Resp Rate|                   RESP RATE|                         6098|      {beats}/min|                30|   3024171|Respiratory rate|Measurement|        LOINC|Clinical Observation|               S|      9279-1|      1996-09-06|    2099-12-31|          null|
# | 41143052|     729082096|  148492182|               3024171|            null| 2022-04-17 19:14:00|2022-04-16 23:00:00|            null|                   44818702|               null|           30.0|           null|               null|           null|     null|      null|    2364327|          282641514|           null|               Resp Rate|                   RESP RATE|                        16024|                 |                30|   3024171|Respiratory rate|Measurement|        LOINC|Clinical Observation|               S|      9279-1|      1996-09-06|    2099-12-31|          null|
# | 13930065|     611777386|  116929147|               3024171|            null| 2021-02-19 04:02:00|2021-02-19 03:06:00|            null|                   44818702|               null|           18.0|           null|               null|           null|     null|      null|    2044661|          232390864|           null|               Resp Rate|                   RESP RATE|                        16024|                 |                18|   3024171|Respiratory rate|Measurement|        LOINC|Clinical Observation|               S|      9279-1|      1996-09-06|    2099-12-31|          null|
# | 12969863|     173381775|   32583556|               3024171|            null| 2015-05-13 02:56:00|2015-05-13 01:42:00|            null|                   44818702|               null|           17.0|           null|               null|           null|     null|      null|     244781|           34801944|           null|               Resp Rate|                   RESP RATE|                         6098|      {beats}/min|                17|   3024171|Respiratory rate|Measurement|        LOINC|Clinical Observation|               S|      9279-1|      1996-09-06|    2099-12-31|          null|
# | 22004915|     322945925|   58380360|               3024171|            null| 2017-08-10 03:47:00|2017-08-10 02:40:00|            null|                   44818702|               null|           16.0|           null|               null|           null|     null|      null|     937639|           78841468|           null|               Resp Rate|                   RESP RATE|                        16024|                 |                16|   3024171|Respiratory rate|Measurement|        LOINC|Clinical Observation|               S|      9279-1|      1996-09-06|    2099-12-31|          null|
# | 22004915|     323522506|   58466161|               3024171|            null| 2017-08-13 02:32:00|2017-08-13 02:06:00|            null|                   44818702|               null|           14.0|           null|               null|           null|     null|      null|     931807|           78841468|           null|               Resp Rate|                   RESP RATE|                        16024|                 |                14|   3024171|Respiratory rate|Measurement|        LOINC|Clinical Observation|               S|      9279-1|      1996-09-06|    2099-12-31|          null|
# | 14001514|     173572059|   32593381|               3024171|            null| 2015-05-13 14:30:00|2015-05-13 09:00:00|            null|                   44818702|               null|           16.0|           null|               null|           null|     null|      null|     244781|           33030879|           null|               Resp Rate|                   RESP RATE|                         6098|      {beats}/min|                16|   3024171|Respiratory rate|Measurement|        LOINC|Clinical Observation|               S|      9279-1|      1996-09-06|    2099-12-31|          null|
# | 14001514|     168598396|   31753576|               3024171|            null| 2015-04-14 03:50:00|2015-04-14 01:42:00|            null|                   44818702|               null|           26.0|           null|               null|           null|     null|      null|     231383|           33030879|           null|               Resp Rate|                   RESP RATE|                         6098|      {beats}/min|                26|   3024171|Respiratory rate|Measurement|        LOINC|Clinical Observation|               S|      9279-1|      1996-09-06|    2099-12-31|          null|
# | 41143052|     728522543|  148298343|               3024171|            null| 2022-04-14 22:22:00|2022-04-14 21:44:00|            null|                   44818702|               null|           25.0|           null|               null|           null|     null|      null|    2365350|          282641514|           null|               Resp Rate|                   RESP RATE|                        16024|                 |                25|   3024171|Respiratory rate|Measurement|        LOINC|Clinical Observation|               S|      9279-1|      1996-09-06|    2099-12-31|          null|
# | 48573139|     217731287|   39986300|               3024171|            null| 2016-02-12 11:19:00|2016-02-12 10:55:00|            null|                   44818702|               null|           16.0|           null|               null|           null|     null|      null|     421394|           46831746|           null|               Resp Rate|                   RESP RATE|                         6098|      {beats}/min|                16|   3024171|Respiratory rate|Measurement|        LOINC|Clinical Observation|               S|      9279-1|      1996-09-06|    2099-12-31|          null|
# +---------+--------------+-----------+----------------------+----------------+--------------------+-------------------+----------------+---------------------------+-------------------+---------------+---------------+-------------------+---------------+---------+----------+-----------+-------------------+---------------+------------------------+----------------------------+-----------------------------+-----------------+------------------+----------+----------------+-----------+-------------+--------------------+----------------+------------+----------------+--------------+--------------+
# only showing top 20 rows
# [Stage 266:==================================================(1202 + -2) / 1200]

# %%
df = df.groupby("visit_occurrence_id", "measurement_source_value").agg(F.max("value_as_number").alias("Max_value"),\
                                                                  F.min("value_as_number").alias("Min_value"),\
                                                                  F.mean("value_as_number").alias("Mean_value"))

df.show()
# Out:
# 22/07/13 15:07:39 WARN DAGScheduler: Broadcasting large task binary with size 1736.2 KiB
# 22/07/13 15:07:42 WARN ExecutorPodsSnapshotsStoreImpl: Exception when notifying snapshot subscriber.
# io.fabric8.kubernetes.client.KubernetesClientException: Failure executing: POST at: https://kubernetes.default.svc.cluster.local/api/v1/namespaces/ke-decile-lab/pods. Message: Forbidden!Configured service account doesn't have access. Service account may have been revoked. pods "test-0358db81f7fdb3a2-exec-485" is forbidden: exceeded quota: ke-decile-lab-quota, requested: requests.cpu=2, used: requests.cpu=32, limited: requests.cpu=32.
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.requestFailure(OperationSupport.java:639)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.assertResponseCode(OperationSupport.java:576)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleResponse(OperationSupport.java:543)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleResponse(OperationSupport.java:504)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleCreate(OperationSupport.java:292)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.handleCreate(BaseOperation.java:893)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.create(BaseOperation.java:372)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.create(BaseOperation.java:86)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$requestNewExecutors$1(ExecutorPodsAllocator.scala:400)
# 	at scala.collection.immutable.Range.foreach$mVc$sp(Range.scala:158)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.requestNewExecutors(ExecutorPodsAllocator.scala:382)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$onNewSnapshots$36(ExecutorPodsAllocator.scala:346)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$onNewSnapshots$36$adapted(ExecutorPodsAllocator.scala:339)
# 	at scala.collection.mutable.ResizableArray.foreach(ResizableArray.scala:62)
# 	at scala.collection.mutable.ResizableArray.foreach$(ResizableArray.scala:55)
# 	at scala.collection.mutable.ArrayBuffer.foreach(ArrayBuffer.scala:49)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.onNewSnapshots(ExecutorPodsAllocator.scala:339)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3$adapted(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber.org$apache$spark$scheduler$cluster$k8s$ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber$$processSnapshotsInternal(ExecutorPodsSnapshotsStoreImpl.scala:138)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber.processSnapshots(ExecutorPodsSnapshotsStoreImpl.scala:126)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl.$anonfun$addSubscriber$1(ExecutorPodsSnapshotsStoreImpl.scala:81)
# 	at java.base/java.util.concurrent.Executors$RunnableAdapter.call(Unknown Source)
# 	at java.base/java.util.concurrent.FutureTask.runAndReset(Unknown Source)
# 	at java.base/java.util.concurrent.ScheduledThreadPoolExecutor$ScheduledFutureTask.run(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(Unknown Source)
# 	at java.base/java.lang.Thread.run(Unknown Source)
# 22/07/13 15:07:43 WARN ExecutorPodsSnapshotsStoreImpl: Exception when notifying snapshot subscriber.
# io.fabric8.kubernetes.client.KubernetesClientException: Failure executing: POST at: https://kubernetes.default.svc.cluster.local/api/v1/namespaces/ke-decile-lab/pods. Message: Forbidden!Configured service account doesn't have access. Service account may have been revoked. pods "test-0358db81f7fdb3a2-exec-486" is forbidden: exceeded quota: ke-decile-lab-quota, requested: requests.cpu=2, used: requests.cpu=32, limited: requests.cpu=32.
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.requestFailure(OperationSupport.java:639)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.assertResponseCode(OperationSupport.java:576)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleResponse(OperationSupport.java:543)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleResponse(OperationSupport.java:504)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleCreate(OperationSupport.java:292)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.handleCreate(BaseOperation.java:893)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.create(BaseOperation.java:372)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.create(BaseOperation.java:86)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$requestNewExecutors$1(ExecutorPodsAllocator.scala:400)
# 	at scala.collection.immutable.Range.foreach$mVc$sp(Range.scala:158)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.requestNewExecutors(ExecutorPodsAllocator.scala:382)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$onNewSnapshots$36(ExecutorPodsAllocator.scala:346)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$onNewSnapshots$36$adapted(ExecutorPodsAllocator.scala:339)
# 	at scala.collection.mutable.ResizableArray.foreach(ResizableArray.scala:62)
# 	at scala.collection.mutable.ResizableArray.foreach$(ResizableArray.scala:55)
# 	at scala.collection.mutable.ArrayBuffer.foreach(ArrayBuffer.scala:49)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.onNewSnapshots(ExecutorPodsAllocator.scala:339)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3$adapted(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber.org$apache$spark$scheduler$cluster$k8s$ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber$$processSnapshotsInternal(ExecutorPodsSnapshotsStoreImpl.scala:138)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber.processSnapshots(ExecutorPodsSnapshotsStoreImpl.scala:126)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl.$anonfun$addSubscriber$1(ExecutorPodsSnapshotsStoreImpl.scala:81)
# 	at java.base/java.util.concurrent.Executors$RunnableAdapter.call(Unknown Source)
# 	at java.base/java.util.concurrent.FutureTask.runAndReset(Unknown Source)
# 	at java.base/java.util.concurrent.ScheduledThreadPoolExecutor$ScheduledFutureTask.run(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(Unknown Source)
# 	at java.base/java.lang.Thread.run(Unknown Source)
# 22/07/13 15:07:44 WARN ExecutorPodsSnapshotsStoreImpl: Exception when notifying snapshot subscriber.
# io.fabric8.kubernetes.client.KubernetesClientException: Failure executing: POST at: https://kubernetes.default.svc.cluster.local/api/v1/namespaces/ke-decile-lab/pods. Message: Forbidden!Configured service account doesn't have access. Service account may have been revoked. pods "test-0358db81f7fdb3a2-exec-487" is forbidden: exceeded quota: ke-decile-lab-quota, requested: requests.cpu=2, used: requests.cpu=32, limited: requests.cpu=32.
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.requestFailure(OperationSupport.java:639)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.assertResponseCode(OperationSupport.java:576)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleResponse(OperationSupport.java:543)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleResponse(OperationSupport.java:504)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleCreate(OperationSupport.java:292)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.handleCreate(BaseOperation.java:893)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.create(BaseOperation.java:372)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.create(BaseOperation.java:86)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$requestNewExecutors$1(ExecutorPodsAllocator.scala:400)
# 	at scala.collection.immutable.Range.foreach$mVc$sp(Range.scala:158)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.requestNewExecutors(ExecutorPodsAllocator.scala:382)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$onNewSnapshots$36(ExecutorPodsAllocator.scala:346)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$onNewSnapshots$36$adapted(ExecutorPodsAllocator.scala:339)
# 	at scala.collection.mutable.ResizableArray.foreach(ResizableArray.scala:62)
# 	at scala.collection.mutable.ResizableArray.foreach$(ResizableArray.scala:55)
# 	at scala.collection.mutable.ArrayBuffer.foreach(ArrayBuffer.scala:49)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.onNewSnapshots(ExecutorPodsAllocator.scala:339)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3$adapted(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber.org$apache$spark$scheduler$cluster$k8s$ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber$$processSnapshotsInternal(ExecutorPodsSnapshotsStoreImpl.scala:138)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber.processSnapshots(ExecutorPodsSnapshotsStoreImpl.scala:126)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl.$anonfun$addSubscriber$1(ExecutorPodsSnapshotsStoreImpl.scala:81)
# 	at java.base/java.util.concurrent.Executors$RunnableAdapter.call(Unknown Source)
# 	at java.base/java.util.concurrent.FutureTask.runAndReset(Unknown Source)
# 	at java.base/java.util.concurrent.ScheduledThreadPoolExecutor$ScheduledFutureTask.run(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(Unknown Source)
# 	at java.base/java.lang.Thread.run(Unknown Source)
# 22/07/13 15:07:45 WARN ExecutorPodsSnapshotsStoreImpl: Exception when notifying snapshot subscriber.
# io.fabric8.kubernetes.client.KubernetesClientException: Failure executing: POST at: https://kubernetes.default.svc.cluster.local/api/v1/namespaces/ke-decile-lab/pods. Message: Forbidden!Configured service account doesn't have access. Service account may have been revoked. pods "test-0358db81f7fdb3a2-exec-488" is forbidden: exceeded quota: ke-decile-lab-quota, requested: requests.cpu=2, used: requests.cpu=32, limited: requests.cpu=32.
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.requestFailure(OperationSupport.java:639)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.assertResponseCode(OperationSupport.java:576)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleResponse(OperationSupport.java:543)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleResponse(OperationSupport.java:504)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleCreate(OperationSupport.java:292)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.handleCreate(BaseOperation.java:893)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.create(BaseOperation.java:372)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.create(BaseOperation.java:86)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$requestNewExecutors$1(ExecutorPodsAllocator.scala:400)
# 	at scala.collection.immutable.Range.foreach$mVc$sp(Range.scala:158)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.requestNewExecutors(ExecutorPodsAllocator.scala:382)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$onNewSnapshots$36(ExecutorPodsAllocator.scala:346)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$onNewSnapshots$36$adapted(ExecutorPodsAllocator.scala:339)
# 	at scala.collection.mutable.ResizableArray.foreach(ResizableArray.scala:62)
# 	at scala.collection.mutable.ResizableArray.foreach$(ResizableArray.scala:55)
# 	at scala.collection.mutable.ArrayBuffer.foreach(ArrayBuffer.scala:49)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.onNewSnapshots(ExecutorPodsAllocator.scala:339)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3$adapted(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber.org$apache$spark$scheduler$cluster$k8s$ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber$$processSnapshotsInternal(ExecutorPodsSnapshotsStoreImpl.scala:138)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber.processSnapshots(ExecutorPodsSnapshotsStoreImpl.scala:126)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl.$anonfun$addSubscriber$1(ExecutorPodsSnapshotsStoreImpl.scala:81)
# 	at java.base/java.util.concurrent.Executors$RunnableAdapter.call(Unknown Source)
# 	at java.base/java.util.concurrent.FutureTask.runAndReset(Unknown Source)
# 	at java.base/java.util.concurrent.ScheduledThreadPoolExecutor$ScheduledFutureTask.run(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(Unknown Source)
# 	at java.base/java.lang.Thread.run(Unknown Source)
# 22/07/13 15:07:46 WARN ExecutorPodsSnapshotsStoreImpl: Exception when notifying snapshot subscriber.
# io.fabric8.kubernetes.client.KubernetesClientException: Failure executing: POST at: https://kubernetes.default.svc.cluster.local/api/v1/namespaces/ke-decile-lab/pods. Message: Forbidden!Configured service account doesn't have access. Service account may have been revoked. pods "test-0358db81f7fdb3a2-exec-489" is forbidden: exceeded quota: ke-decile-lab-quota, requested: requests.cpu=2, used: requests.cpu=32, limited: requests.cpu=32.
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.requestFailure(OperationSupport.java:639)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.assertResponseCode(OperationSupport.java:576)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleResponse(OperationSupport.java:543)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleResponse(OperationSupport.java:504)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleCreate(OperationSupport.java:292)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.handleCreate(BaseOperation.java:893)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.create(BaseOperation.java:372)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.create(BaseOperation.java:86)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$requestNewExecutors$1(ExecutorPodsAllocator.scala:400)
# 	at scala.collection.immutable.Range.foreach$mVc$sp(Range.scala:158)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.requestNewExecutors(ExecutorPodsAllocator.scala:382)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$onNewSnapshots$36(ExecutorPodsAllocator.scala:346)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$onNewSnapshots$36$adapted(ExecutorPodsAllocator.scala:339)
# 	at scala.collection.mutable.ResizableArray.foreach(ResizableArray.scala:62)
# 	at scala.collection.mutable.ResizableArray.foreach$(ResizableArray.scala:55)
# 	at scala.collection.mutable.ArrayBuffer.foreach(ArrayBuffer.scala:49)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.onNewSnapshots(ExecutorPodsAllocator.scala:339)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3$adapted(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber.org$apache$spark$scheduler$cluster$k8s$ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber$$processSnapshotsInternal(ExecutorPodsSnapshotsStoreImpl.scala:138)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber.processSnapshots(ExecutorPodsSnapshotsStoreImpl.scala:126)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl.$anonfun$addSubscriber$1(ExecutorPodsSnapshotsStoreImpl.scala:81)
# 	at java.base/java.util.concurrent.Executors$RunnableAdapter.call(Unknown Source)
# 	at java.base/java.util.concurrent.FutureTask.runAndReset(Unknown Source)
# 	at java.base/java.util.concurrent.ScheduledThreadPoolExecutor$ScheduledFutureTask.run(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(Unknown Source)
# 	at java.base/java.lang.Thread.run(Unknown Source)
# 22/07/13 15:07:47 WARN ExecutorPodsSnapshotsStoreImpl: Exception when notifying snapshot subscriber.
# io.fabric8.kubernetes.client.KubernetesClientException: Failure executing: POST at: https://kubernetes.default.svc.cluster.local/api/v1/namespaces/ke-decile-lab/pods. Message: Forbidden!Configured service account doesn't have access. Service account may have been revoked. pods "test-0358db81f7fdb3a2-exec-490" is forbidden: exceeded quota: ke-decile-lab-quota, requested: requests.cpu=2, used: requests.cpu=32, limited: requests.cpu=32.
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.requestFailure(OperationSupport.java:639)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.assertResponseCode(OperationSupport.java:576)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleResponse(OperationSupport.java:543)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleResponse(OperationSupport.java:504)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleCreate(OperationSupport.java:292)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.handleCreate(BaseOperation.java:893)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.create(BaseOperation.java:372)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.create(BaseOperation.java:86)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$requestNewExecutors$1(ExecutorPodsAllocator.scala:400)
# 	at scala.collection.immutable.Range.foreach$mVc$sp(Range.scala:158)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.requestNewExecutors(ExecutorPodsAllocator.scala:382)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$onNewSnapshots$36(ExecutorPodsAllocator.scala:346)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$onNewSnapshots$36$adapted(ExecutorPodsAllocator.scala:339)
# 	at scala.collection.mutable.ResizableArray.foreach(ResizableArray.scala:62)
# 	at scala.collection.mutable.ResizableArray.foreach$(ResizableArray.scala:55)
# 	at scala.collection.mutable.ArrayBuffer.foreach(ArrayBuffer.scala:49)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.onNewSnapshots(ExecutorPodsAllocator.scala:339)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3$adapted(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber.org$apache$spark$scheduler$cluster$k8s$ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber$$processSnapshotsInternal(ExecutorPodsSnapshotsStoreImpl.scala:138)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber.processSnapshots(ExecutorPodsSnapshotsStoreImpl.scala:126)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl.$anonfun$addSubscriber$1(ExecutorPodsSnapshotsStoreImpl.scala:81)
# 	at java.base/java.util.concurrent.Executors$RunnableAdapter.call(Unknown Source)
# 	at java.base/java.util.concurrent.FutureTask.runAndReset(Unknown Source)
# 	at java.base/java.util.concurrent.ScheduledThreadPoolExecutor$ScheduledFutureTask.run(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(Unknown Source)
# 	at java.base/java.lang.Thread.run(Unknown Source)
# 22/07/13 15:07:48 WARN ExecutorPodsSnapshotsStoreImpl: Exception when notifying snapshot subscriber.
# io.fabric8.kubernetes.client.KubernetesClientException: Failure executing: POST at: https://kubernetes.default.svc.cluster.local/api/v1/namespaces/ke-decile-lab/pods. Message: Forbidden!Configured service account doesn't have access. Service account may have been revoked. pods "test-0358db81f7fdb3a2-exec-491" is forbidden: exceeded quota: ke-decile-lab-quota, requested: requests.cpu=2, used: requests.cpu=32, limited: requests.cpu=32.
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.requestFailure(OperationSupport.java:639)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.assertResponseCode(OperationSupport.java:576)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleResponse(OperationSupport.java:543)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleResponse(OperationSupport.java:504)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleCreate(OperationSupport.java:292)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.handleCreate(BaseOperation.java:893)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.create(BaseOperation.java:372)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.create(BaseOperation.java:86)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$requestNewExecutors$1(ExecutorPodsAllocator.scala:400)
# 	at scala.collection.immutable.Range.foreach$mVc$sp(Range.scala:158)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.requestNewExecutors(ExecutorPodsAllocator.scala:382)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$onNewSnapshots$36(ExecutorPodsAllocator.scala:346)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$onNewSnapshots$36$adapted(ExecutorPodsAllocator.scala:339)
# 	at scala.collection.mutable.ResizableArray.foreach(ResizableArray.scala:62)
# 	at scala.collection.mutable.ResizableArray.foreach$(ResizableArray.scala:55)
# 	at scala.collection.mutable.ArrayBuffer.foreach(ArrayBuffer.scala:49)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.onNewSnapshots(ExecutorPodsAllocator.scala:339)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3$adapted(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber.org$apache$spark$scheduler$cluster$k8s$ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber$$processSnapshotsInternal(ExecutorPodsSnapshotsStoreImpl.scala:138)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber.processSnapshots(ExecutorPodsSnapshotsStoreImpl.scala:126)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl.$anonfun$addSubscriber$1(ExecutorPodsSnapshotsStoreImpl.scala:81)
# 	at java.base/java.util.concurrent.Executors$RunnableAdapter.call(Unknown Source)
# 	at java.base/java.util.concurrent.FutureTask.runAndReset(Unknown Source)
# 	at java.base/java.util.concurrent.ScheduledThreadPoolExecutor$ScheduledFutureTask.run(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(Unknown Source)
# 	at java.base/java.lang.Thread.run(Unknown Source)
# 22/07/13 15:07:49 WARN ExecutorPodsSnapshotsStoreImpl: Exception when notifying snapshot subscriber.
# io.fabric8.kubernetes.client.KubernetesClientException: Failure executing: POST at: https://kubernetes.default.svc.cluster.local/api/v1/namespaces/ke-decile-lab/pods. Message: Forbidden!Configured service account doesn't have access. Service account may have been revoked. pods "test-0358db81f7fdb3a2-exec-492" is forbidden: exceeded quota: ke-decile-lab-quota, requested: requests.cpu=2, used: requests.cpu=32, limited: requests.cpu=32.
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.requestFailure(OperationSupport.java:639)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.assertResponseCode(OperationSupport.java:576)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleResponse(OperationSupport.java:543)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleResponse(OperationSupport.java:504)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleCreate(OperationSupport.java:292)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.handleCreate(BaseOperation.java:893)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.create(BaseOperation.java:372)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.create(BaseOperation.java:86)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$requestNewExecutors$1(ExecutorPodsAllocator.scala:400)
# 	at scala.collection.immutable.Range.foreach$mVc$sp(Range.scala:158)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.requestNewExecutors(ExecutorPodsAllocator.scala:382)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$onNewSnapshots$36(ExecutorPodsAllocator.scala:346)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$onNewSnapshots$36$adapted(ExecutorPodsAllocator.scala:339)
# 	at scala.collection.mutable.ResizableArray.foreach(ResizableArray.scala:62)
# 	at scala.collection.mutable.ResizableArray.foreach$(ResizableArray.scala:55)
# 	at scala.collection.mutable.ArrayBuffer.foreach(ArrayBuffer.scala:49)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.onNewSnapshots(ExecutorPodsAllocator.scala:339)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3$adapted(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber.org$apache$spark$scheduler$cluster$k8s$ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber$$processSnapshotsInternal(ExecutorPodsSnapshotsStoreImpl.scala:138)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber.processSnapshots(ExecutorPodsSnapshotsStoreImpl.scala:126)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl.$anonfun$addSubscriber$1(ExecutorPodsSnapshotsStoreImpl.scala:81)
# 	at java.base/java.util.concurrent.Executors$RunnableAdapter.call(Unknown Source)
# 	at java.base/java.util.concurrent.FutureTask.runAndReset(Unknown Source)
# 	at java.base/java.util.concurrent.ScheduledThreadPoolExecutor$ScheduledFutureTask.run(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(Unknown Source)
# 	at java.base/java.lang.Thread.run(Unknown Source)
# 22/07/13 15:07:50 WARN ExecutorPodsSnapshotsStoreImpl: Exception when notifying snapshot subscriber.
# io.fabric8.kubernetes.client.KubernetesClientException: Failure executing: POST at: https://kubernetes.default.svc.cluster.local/api/v1/namespaces/ke-decile-lab/pods. Message: Forbidden!Configured service account doesn't have access. Service account may have been revoked. pods "test-0358db81f7fdb3a2-exec-493" is forbidden: exceeded quota: ke-decile-lab-quota, requested: requests.cpu=2, used: requests.cpu=32, limited: requests.cpu=32.
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.requestFailure(OperationSupport.java:639)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.assertResponseCode(OperationSupport.java:576)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleResponse(OperationSupport.java:543)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleResponse(OperationSupport.java:504)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleCreate(OperationSupport.java:292)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.handleCreate(BaseOperation.java:893)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.create(BaseOperation.java:372)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.create(BaseOperation.java:86)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$requestNewExecutors$1(ExecutorPodsAllocator.scala:400)
# 	at scala.collection.immutable.Range.foreach$mVc$sp(Range.scala:158)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.requestNewExecutors(ExecutorPodsAllocator.scala:382)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$onNewSnapshots$36(ExecutorPodsAllocator.scala:346)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$onNewSnapshots$36$adapted(ExecutorPodsAllocator.scala:339)
# 	at scala.collection.mutable.ResizableArray.foreach(ResizableArray.scala:62)
# 	at scala.collection.mutable.ResizableArray.foreach$(ResizableArray.scala:55)
# 	at scala.collection.mutable.ArrayBuffer.foreach(ArrayBuffer.scala:49)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.onNewSnapshots(ExecutorPodsAllocator.scala:339)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3$adapted(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber.org$apache$spark$scheduler$cluster$k8s$ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber$$processSnapshotsInternal(ExecutorPodsSnapshotsStoreImpl.scala:138)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber.processSnapshots(ExecutorPodsSnapshotsStoreImpl.scala:126)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl.$anonfun$addSubscriber$1(ExecutorPodsSnapshotsStoreImpl.scala:81)
# 	at java.base/java.util.concurrent.Executors$RunnableAdapter.call(Unknown Source)
# 	at java.base/java.util.concurrent.FutureTask.runAndReset(Unknown Source)
# 	at java.base/java.util.concurrent.ScheduledThreadPoolExecutor$ScheduledFutureTask.run(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(Unknown Source)
# 	at java.base/java.lang.Thread.run(Unknown Source)
# 22/07/13 15:07:51 WARN ExecutorPodsSnapshotsStoreImpl: Exception when notifying snapshot subscriber.
# io.fabric8.kubernetes.client.KubernetesClientException: Failure executing: POST at: https://kubernetes.default.svc.cluster.local/api/v1/namespaces/ke-decile-lab/pods. Message: Forbidden!Configured service account doesn't have access. Service account may have been revoked. pods "test-0358db81f7fdb3a2-exec-494" is forbidden: exceeded quota: ke-decile-lab-quota, requested: requests.cpu=2, used: requests.cpu=32, limited: requests.cpu=32.
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.requestFailure(OperationSupport.java:639)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.assertResponseCode(OperationSupport.java:576)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleResponse(OperationSupport.java:543)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleResponse(OperationSupport.java:504)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleCreate(OperationSupport.java:292)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.handleCreate(BaseOperation.java:893)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.create(BaseOperation.java:372)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.create(BaseOperation.java:86)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$requestNewExecutors$1(ExecutorPodsAllocator.scala:400)
# 	at scala.collection.immutable.Range.foreach$mVc$sp(Range.scala:158)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.requestNewExecutors(ExecutorPodsAllocator.scala:382)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$onNewSnapshots$36(ExecutorPodsAllocator.scala:346)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$onNewSnapshots$36$adapted(ExecutorPodsAllocator.scala:339)
# 	at scala.collection.mutable.ResizableArray.foreach(ResizableArray.scala:62)
# 	at scala.collection.mutable.ResizableArray.foreach$(ResizableArray.scala:55)
# 	at scala.collection.mutable.ArrayBuffer.foreach(ArrayBuffer.scala:49)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.onNewSnapshots(ExecutorPodsAllocator.scala:339)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3$adapted(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber.org$apache$spark$scheduler$cluster$k8s$ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber$$processSnapshotsInternal(ExecutorPodsSnapshotsStoreImpl.scala:138)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber.processSnapshots(ExecutorPodsSnapshotsStoreImpl.scala:126)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl.$anonfun$addSubscriber$1(ExecutorPodsSnapshotsStoreImpl.scala:81)
# 	at java.base/java.util.concurrent.Executors$RunnableAdapter.call(Unknown Source)
# 	at java.base/java.util.concurrent.FutureTask.runAndReset(Unknown Source)
# 	at java.base/java.util.concurrent.ScheduledThreadPoolExecutor$ScheduledFutureTask.run(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(Unknown Source)
# 	at java.base/java.lang.Thread.run(Unknown Source)
# 22/07/13 15:07:52 WARN ExecutorPodsSnapshotsStoreImpl: Exception when notifying snapshot subscriber.
# io.fabric8.kubernetes.client.KubernetesClientException: Failure executing: POST at: https://kubernetes.default.svc.cluster.local/api/v1/namespaces/ke-decile-lab/pods. Message: Forbidden!Configured service account doesn't have access. Service account may have been revoked. pods "test-0358db81f7fdb3a2-exec-495" is forbidden: exceeded quota: ke-decile-lab-quota, requested: requests.cpu=2, used: requests.cpu=32, limited: requests.cpu=32.
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.requestFailure(OperationSupport.java:639)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.assertResponseCode(OperationSupport.java:576)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleResponse(OperationSupport.java:543)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleResponse(OperationSupport.java:504)
# 	at io.fabric8.kubernetes.client.dsl.base.OperationSupport.handleCreate(OperationSupport.java:292)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.handleCreate(BaseOperation.java:893)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.create(BaseOperation.java:372)
# 	at io.fabric8.kubernetes.client.dsl.base.BaseOperation.create(BaseOperation.java:86)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$requestNewExecutors$1(ExecutorPodsAllocator.scala:400)
# 	at scala.collection.immutable.Range.foreach$mVc$sp(Range.scala:158)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.requestNewExecutors(ExecutorPodsAllocator.scala:382)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$onNewSnapshots$36(ExecutorPodsAllocator.scala:346)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$onNewSnapshots$36$adapted(ExecutorPodsAllocator.scala:339)
# 	at scala.collection.mutable.ResizableArray.foreach(ResizableArray.scala:62)
# 	at scala.collection.mutable.ResizableArray.foreach$(ResizableArray.scala:55)
# 	at scala.collection.mutable.ArrayBuffer.foreach(ArrayBuffer.scala:49)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.onNewSnapshots(ExecutorPodsAllocator.scala:339)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsAllocator.$anonfun$start$3$adapted(ExecutorPodsAllocator.scala:117)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber.org$apache$spark$scheduler$cluster$k8s$ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber$$processSnapshotsInternal(ExecutorPodsSnapshotsStoreImpl.scala:138)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl$SnapshotsSubscriber.processSnapshots(ExecutorPodsSnapshotsStoreImpl.scala:126)
# 	at org.apache.spark.scheduler.cluster.k8s.ExecutorPodsSnapshotsStoreImpl.$anonfun$addSubscriber$1(ExecutorPodsSnapshotsStoreImpl.scala:81)
# 	at java.base/java.util.concurrent.Executors$RunnableAdapter.call(Unknown Source)
# 	at java.base/java.util.concurrent.FutureTask.runAndReset(Unknown Source)
# 	at java.base/java.util.concurrent.ScheduledThreadPoolExecutor$ScheduledFutureTask.run(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(Unknown Source)
# 	at java.base/java.lang.Thread.run(Unknown Source)
# [Stage 266:==================================================(1202 + -2) / 1200]
# +-------------------+------------------------+---------+---------+-----------------+
# |visit_occurrence_id|measurement_source_value|Max_value|Min_value|       Mean_value|
# +-------------------+------------------------+---------+---------+-----------------+
# |          112304711|      ECG - QTC Interval|    429.0|    429.0|            429.0|
# |          108854665|      ECG - QTC Interval|    421.0|    421.0|            421.0|
# |          117003266|      ECG - QTC Interval|    451.0|    451.0|            451.0|
# |          268987732|      ECG - QTC Interval|    442.0|    442.0|            442.0|
# |          177833976|      ECG - QTC Interval|    434.0|    434.0|            434.0|
# |          268245323|      ECG - QTC Interval|    443.0|    443.0|            443.0|
# |           28256750|      ECG - QTC Interval|    411.0|    411.0|            411.0|
# |           60641581|      ECG - QTC Interval|    452.0|    452.0|            452.0|
# |          101079276|      ECG - QTC Interval|    440.0|    440.0|            440.0|
# |           53842921|      ECG - QTC Interval|    451.0|    451.0|            451.0|
# |          126551394|      ECG - QTC Interval|    393.0|    389.0|            391.0|
# |          114779553|      ECG - QTC Interval|    428.0|    428.0|            428.0|
# |          124425713|      ECG - QTC Interval|    430.0|    428.0|            429.0|
# |          242926792|      ECG - QTC Interval|    442.0|    442.0|            442.0|
# |           70848360|      ECG - QTC Interval|    434.0|    428.0|431.6666666666667|
# |          230859626|      ECG - QTC Interval|    415.0|    415.0|            415.0|
# |          293103537|      ECG - QTC Interval|    493.0|    493.0|            493.0|
# |          288642574|      ECG - QTC Interval|    439.0|    439.0|            439.0|
# |           81289333|      ECG - QTC Interval|    409.0|    409.0|            409.0|
# |          183505585|      ECG - QTC Interval|    435.0|    435.0|            435.0|
# +-------------------+------------------------+---------+---------+-----------------+
# only showing top 20 rows
# [Stage 266:==================================================(1202 + -2) / 1200]
